# %%
available = ['avinasht/finbert_flang-bert','avinasht/finbert_Synonym-wordnet','avinasht/bert-base-uncased_flang-bert',
             'avinasht/bert-base-uncased_Synonym-wordnet','avinasht/finbert_roberta-base',
             'avinasht/finbert_bert-base-uncased','avinasht/bert-base-uncased_roberta-base','avinasht/bert-base-uncased_bert-base-uncased'
            ]

# %%
a = ['avinasht/electra-base-discriminator_bert-base-uncased',
'avinasht/electra-base-discriminator_roberta-base',
'avinasht/FLANG-BERT_bert-base-uncased',
'avinasht/FLANG-BERT_roberta-base',
'avinasht/FLANG-ELECTRA_bert-base-uncased',
'avinasht/FLANG-BERT_flang-bert',
'avinasht/FLANG-BERT_Synonym-wordnet',
'avinasht/electra-base-discriminator_flang-bert',
'avinasht/electra-base-discriminator_Synonym-wordnet']

# %%
set(available).intersection(set(a))
# Out:
# set()

# %%
path = 'D:\OneDrive - NITT\Custom_Download\FLANG-BERT_Synonym-wordnet.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#       index  Sentiment                                               Text  \
# 0         0          1  According to Gran , the company has no plans t...
# 1         1          1  Technopolis plans to develop in stages an area...
# 2         2          0  The international electronic industry company ...
# 3         3          2  With the new production plant the company woul...
# 4         4          2  According to the company 's updated strategy f...
# ...     ...        ...                                                ...
# 8004   4838          0  Net sales of the Paper segment decreased to EU...
# 8005   4838          0  Net sales of the Paper segment decreased to EU...
# 8006   4839          0  Sales in Finland decrease by ten. 5% in Januar...
# 8007   4839          0  Cut rate sale in Republic of finland decreased...
# 8008   4839          0  Sales in Republic of finland lessen by tenner....
#
#              0         1         2         3         4         5         6  \
# ...

# %%
import optuna
from optuna import Trial
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import optuna
#       2 from optuna import Trial
#
# ModuleNotFoundError: No module named 'optuna'

# %%
# !pip install optuna
# Out:
# ...
#   Using cached optuna-3.5.0-py3-none-any.whl (413 kB)
# ...
#   Using cached alembic-1.13.1-py3-none-any.whl (233 kB)
# ...
#   Using cached colorlog-6.8.2-py3-none-any.whl (11 kB)
# ...
#   Using cached Mako-1.3.2-py3-none-any.whl (78 kB)
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\avitr\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\avitr\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\avitr\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'c:\\users\\avitr\\anaconda3\\lib\\site-packages\\PyYAML-5.4.1.dist-info\\METADATA'

# %%
pip install pycaret[models] --user
# Out:
# ...
#   Obtaining dependency information for pycaret[models] from https://files.pythonhosted.org/packages/c7/d8/4e703f17f17d7d7764fe6d586872e787ce3a248640221f5f2d586f671eee/pycaret-3.3.0-py3-none-any.whl.metadata
#   Using cached pycaret-3.3.0-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached pyod-1.1.3-py3-none-any.whl
# ...
#   Obtaining dependency information for imbalanced-learn>=0.12.0 from https://files.pythonhosted.org/packages/92/e8/86c36e1b13007ca9c89381adac6c078cfc8fb71841a76c08a3fe3eca91d3/imbalanced_learn-0.12.0-py3-none-any.whl.metadata
#   Using cached imbalanced_learn-0.12.0-py3-none-any.whl.metadata (8.2 kB)
# ...
#   Obtaining dependency information for category-encoders>=2.4.0 from https://files.pythonhosted.org/packages/7f/e5/79a62e5c9c9ddbfa9ff5222240d408c1eeea4e38741a0dc8343edc7ef1ec/category_encoders-2.6.3-py2.py3-none-any.whl.metadata
#   Using cached category_encoders-2.6.3-py2.py3-none-any.whl.metadata (8.0 kB)
# ...

# %%
import pycaret
pycaret.__version__
# Out:
# '3.3.0'
