# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.drop(columns=['Unnamed: 0','policy_id'],axis=1,inplace=True)

# %%
def get_months(x):
    ym = x.split('and')
    if len(ym) == 2:
        years = int(ym[0].split()[0])
        months = int(ym[1].split()[0])
    elif len(ym) == 1 and 'month' in ym[0]:
        months = int(ym[0].split()[0])
        years = 0
    elif len(ym) == 1 and 'year' in ym[0]:
        years = int(ym[0].split()[0])
        months = 0
    return years*12 + months

# %%
df['age_of_car']  = df['age_of_car'].apply(get_months)

# %%
for col in df:
    df[col] = df[col].replace({'Yes':1,'No':0})

# %%
X_train = df.drop('age_of_policyholder',axis=1)
y_train = df['age_of_policyholder']

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Columns to apply StandardScaler and OneHotEncoder
numeric_cols = list(set(X_train) - set(X_train.select_dtypes('O')))
categorical_cols = list(set(X_train.select_dtypes('O')))

# Define preprocessing steps for numeric and categorical columns
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),  # Impute missing values
    ('scaler', StandardScaler())  # Standard scaling
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),  # Impute missing values
    ('onehot', OneHotEncoder(handle_unknown='ignore'))  # One-hot encoding
])

# Combine preprocessing steps using ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_cols),
        ('cat', categorical_transformer, categorical_cols)
    ],
    remainder='passthrough'
)

# Apply preprocessing to the entire dataset
X_train = preprocessor.fit_transform(X_train)

# %%
X_train.shape
# Out:
# (40000, 110)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor

# %%
param = {'alpha': 0.9,
 'ccp_alpha': 0.0,
 'criterion': 'friedman_mse',
 'init': None,
 'learning_rate': 0.04264031156015375,
 'loss': 'squared_error',
 'max_depth': 3,
 'max_features': 0.7588282465072769,
 'max_leaf_nodes': None,
 'min_impurity_decrease': 0.00962114482009193,
 'min_samples_leaf': 3,
 'min_samples_split': 3,
 'min_weight_fraction_leaf': 0.0,
 'n_estimators': 229,
 'n_iter_no_change': None,
 'random_state': 42,
 'subsample': 0.8981042826479537,
 'tol': 0.0001,
 'validation_fraction': 0.1,
 'verbose': 0,
 'warm_start': False}

# this param does not makes much difference
# Use decision tree for classification

reg = GradientBoostingRegressor(**param)


reg.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.04264031156015375,
#                           loss='squared_error', max_depth=3,
#                           max_features=0.7588282465072769, max_leaf_nodes=None,
#                           min_impurity_decrease=0.00962114482009193,
#                           min_samples_leaf=3, min_samples_split=3,
#                           min_weight_fraction_leaf=0.0, n_estimators=229,
#                           n_iter_no_change=None, random_state=42,
#                           subsample=0.8981042826479537, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test.drop(columns=['Unnamed: 0','policy_id'],axis=1,inplace=True)

# %%
df_test['age_of_car']  = df_test['age_of_car'].apply(get_months)

for col in df_test:
    df_test[col] = df_test[col].replace({'Yes':1,'No':0})

X_test = df_test.drop('age_of_policyholder',axis=1)
y_test = df_test['age_of_policyholder']

X_test = preprocessor.transform(X_test)

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 90.82739469501759

# %%
# 1) check correlation
# try pycaret

# %%
from sklearn.linear_model import LogisticRegression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from category_encoders import OrdinalEncoder, OneHotEncoder
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay,f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.pipeline import make_pipeline

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.drop(columns=['Unnamed: 0','policy_id'],axis=1,inplace=True)
df_test.drop(columns=['Unnamed: 0','policy_id'],axis=1,inplace=True)

# %%
def get_months(x):
    ym = x.split('and')
    if len(ym) == 2:
        years = int(ym[0].split()[0])
        months = int(ym[1].split()[0])
    elif len(ym) == 1 and 'month' in ym[0]:
        months = int(ym[0].split()[0])
        years = 0
    elif len(ym) == 1 and 'year' in ym[0]:
        years = int(ym[0].split()[0])
        months = 0
    return years*12 + months

# %%
df_train['age_of_car']  = df_train['age_of_car'].apply(get_months)
df_test['age_of_car']  = df_test['age_of_car'].apply(get_months)

# %%
for col in df_train:
    df_train[col] = df_train[col].replace({'Yes':1,'No':0})
    df_test[col] = df_test[col].replace({'Yes':1,'No':0})

# %%
X_train = df_train.drop('is_claim',axis=1)
y_train = df_train['is_claim']

# %%
X_test = df_test.drop('is_claim',axis=1)
y_test = df_test['is_claim']

# %%
from imblearn.over_sampling import RandomOverSampler
sampler = RandomOverSampler(random_state=1)
X_train_over, y_train_over = sampler.fit_resample(X_train,y_train)

# %%
X_train_over['is_claim'] = y_train_over

# %%
lr = make_pipeline(OneHotEncoder(),
                   LogisticRegression())
dt = make_pipeline(OrdinalEncoder(),
                  DecisionTreeClassifier(random_state=1))
rf = make_pipeline(OrdinalEncoder(),
                  RandomForestClassifier(random_state=1))
gb = make_pipeline(OrdinalEncoder(),
                  GradientBoostingClassifier(random_state=1))

# %%
model_list = [("lr", lr),("dt", dt),("rf", rf),("gb", gb)]

# %%
for name, model in model_list:
    
    model.fit(X_train_over, y_train_over)
    
    y_pred = model.predict(X_test)
    
    score = f1_score(y_test, y_pred,average='macro')
    print(f"The test accuracy score of {name} is {score}")
# Out:
# C:\Users\avitr\anaconda3\envs\test_env\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# The test accuracy score of lr is 0.417769709840323
# The test accuracy score of dt is 0.5072867175377134
# The test accuracy score of rf is 0.5042491766705003
# The test accuracy score of gb is 0.4420553641615713

# %%
import pycaret
from pycaret.classification import *
from pycaret.classification import predict_model

# %%
df_train = pd.read_csv('train1.csv')
df_test = pd.read_csv('test1.csv')

# %%
s = setup(df_train, target = 'target', session_id = 42, fold=5,n_jobs=-1,
          verbose=False)

# best = compare_models(verbose=1)
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_f039a_row5_col0, #T_f039a_row5_col1, #T_f039a_row5_col2, #T_f039a_row5_col3, #T_f039a_row5_col4, #T_f039a_row5_col5, #T_f039a_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f039a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f039a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f039a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f039a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f039a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f039a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f039a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f039a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f039a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f039a_row0_col0" class="data row0 col0" >0.8648</td>
#       <td id="T_f039a_row0_col1" class="data row0 col1" >0.5081</td>
#       <td id="T_f039a_row0_col2" class="data row0 col2" >0.1003</td>
#       <td id="T_f039a_row0_col3" class="data row0 col3" >0.0732</td>
#       <td id="T_f039a_row0_col4" class="data row0 col4" >0.0846</td>
#       <td id="T_f039a_row0_col5" class="data row0 col5" >0.0136</td>
#       <td id="T_f039a_row0_col6" class="data row0 col6" >0.0138</td>
#     </tr>
#     <tr>
#       <th id="T_f039a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f039a_row1_col0" class="data row1 col0" >0.8752</td>
#       <td id="T_f039a_row1_col1" class="data row1 col1" >0.5302</td>
#       <td id="T_f039a_row1_col2" class="data row1 col2" >0.1375</td>
#       <td id="T_f039a_row1_col3" class="data row1 col3" >0.1076</td>
#       <td id="T_f039a_row1_col4" class="data row1 col4" >0.1208</td>
#       <td id="T_f039a_row1_col5" class="data row1 col5" >0.0547</td>
#       <td id="T_f039a_row1_col6" class="data row1 col6" >0.0551</td>
#     </tr>
#     <tr>
#       <th id="T_f039a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f039a_row2_col0" class="data row2 col0" >0.8577</td>
#       <td id="T_f039a_row2_col1" class="data row2 col1" >0.5043</td>
#       <td id="T_f039a_row2_col2" class="data row2 col2" >0.1003</td>
#       <td id="T_f039a_row2_col3" class="data row2 col3" >0.0676</td>
#       <td id="T_f039a_row2_col4" class="data row2 col4" >0.0807</td>
#       <td id="T_f039a_row2_col5" class="data row2 col5" >0.0068</td>
#       <td id="T_f039a_row2_col6" class="data row2 col6" >0.0069</td>
#     </tr>
#     <tr>
#       <th id="T_f039a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f039a_row3_col0" class="data row3 col0" >0.8664</td>
#       <td id="T_f039a_row3_col1" class="data row3 col1" >0.4996</td>
#       <td id="T_f039a_row3_col2" class="data row3 col2" >0.0714</td>
#       <td id="T_f039a_row3_col3" class="data row3 col3" >0.0558</td>
#       <td id="T_f039a_row3_col4" class="data row3 col4" >0.0627</td>
#       <td id="T_f039a_row3_col5" class="data row3 col5" >-0.0081</td>
#       <td id="T_f039a_row3_col6" class="data row3 col6" >-0.0082</td>
#     </tr>
#     <tr>
#       <th id="T_f039a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f039a_row4_col0" class="data row4 col0" >0.8707</td>
#       <td id="T_f039a_row4_col1" class="data row4 col1" >0.5179</td>
#       <td id="T_f039a_row4_col2" class="data row4 col2" >0.1171</td>
#       <td id="T_f039a_row4_col3" class="data row4 col3" >0.0899</td>
#       <td id="T_f039a_row4_col4" class="data row4 col4" >0.1017</td>
#       <td id="T_f039a_row4_col5" class="data row4 col5" >0.0334</td>
#       <td id="T_f039a_row4_col6" class="data row4 col6" >0.0337</td>
#     </tr>
#     <tr>
#       <th id="T_f039a_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_f039a_row5_col0" class="data row5 col0" >0.8670</td>
#       <td id="T_f039a_row5_col1" class="data row5 col1" >0.5120</td>
#       <td id="T_f039a_row5_col2" class="data row5 col2" >0.1053</td>
#       <td id="T_f039a_row5_col3" class="data row5 col3" >0.0788</td>
#       <td id="T_f039a_row5_col4" class="data row5 col4" >0.0901</td>
#       <td id="T_f039a_row5_col5" class="data row5 col5" >0.0201</td>
#       <td id="T_f039a_row5_col6" class="data row5 col6" >0.0203</td>
#     </tr>
#     <tr>
#       <th id="T_f039a_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_f039a_row6_col0" class="data row6 col0" >0.0059</td>
#       <td id="T_f039a_row6_col1" class="data row6 col1" >0.0109</td>
#       <td id="T_f039a_row6_col2" class="data row6 col2" >0.0218</td>
#       <td id="T_f039a_row6_col3" class="data row6 col3" >0.0181</td>
#       <td id="T_f039a_row6_col4" class="data row6 col4" >0.0197</td>
#       <td id="T_f039a_row6_col5" class="data row6 col5" >0.0218</td>
#       <td id="T_f039a_row6_col6" class="data row6 col6" >0.0220</td>
#     </tr>
#   </tbody>
# </table>

# %%
dt
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, random_state=42, splitter='best')

# %%
s = predict_model(tuned_dt,data=df_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_15e98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15e98_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_15e98_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_15e98_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_15e98_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_15e98_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_15e98_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_15e98_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_15e98_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15e98_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15e98_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_15e98_row0_col1" class="data row0 col1" >0.8694</td>
#       <td id="T_15e98_row0_col2" class="data row0 col2" >0.5081</td>
#       <td id="T_15e98_row0_col3" class="data row0 col3" >0.0909</td>
#       <td id="T_15e98_row0_col4" class="data row0 col4" >0.0740</td>
#       <td id="T_15e98_row0_col5" class="data row0 col5" >0.0816</td>
#       <td id="T_15e98_row0_col6" class="data row0 col6" >0.0121</td>
#       <td id="T_15e98_row0_col7" class="data row0 col7" >0.0121</td>
#     </tr>
#   </tbody>
# </table>

# %%
score = f1_score(s['target'], s['prediction_label'],average='macro')
score
# Out:
# 0.5056385219787966

# %%
# pip install tune-sklearn ray[tune]

# %%
# tune model tune-sklearn
# tuned_dt = tune_model(best, search_library = 'tune-sklearn', search_algorithm = 'hyperopt')

# %%
tuned_dt = tune_model(dt, search_library = 'scikit-optimize',early_stopping=True,
                     optimize='f1',n_iter=100)
# Out:
# <style type="text/css">
# #T_99d78_row5_col0, #T_99d78_row5_col1, #T_99d78_row5_col2, #T_99d78_row5_col3, #T_99d78_row5_col4, #T_99d78_row5_col5, #T_99d78_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_99d78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99d78_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_99d78_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_99d78_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_99d78_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_99d78_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_99d78_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_99d78_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99d78_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99d78_row0_col0" class="data row0 col0" >0.9129</td>
#       <td id="T_99d78_row0_col1" class="data row0 col1" >0.5480</td>
#       <td id="T_99d78_row0_col2" class="data row0 col2" >0.0487</td>
#       <td id="T_99d78_row0_col3" class="data row0 col3" >0.0983</td>
#       <td id="T_99d78_row0_col4" class="data row0 col4" >0.0651</td>
#       <td id="T_99d78_row0_col5" class="data row0 col5" >0.0249</td>
#       <td id="T_99d78_row0_col6" class="data row0 col6" >0.0265</td>
#     </tr>
#     <tr>
#       <th id="T_99d78_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99d78_row1_col0" class="data row1 col0" >0.9195</td>
#       <td id="T_99d78_row1_col1" class="data row1 col1" >0.5517</td>
#       <td id="T_99d78_row1_col2" class="data row1 col2" >0.0344</td>
#       <td id="T_99d78_row1_col3" class="data row1 col3" >0.0952</td>
#       <td id="T_99d78_row1_col4" class="data row1 col4" >0.0505</td>
#       <td id="T_99d78_row1_col5" class="data row1 col5" >0.0181</td>
#       <td id="T_99d78_row1_col6" class="data row1 col6" >0.0207</td>
#     </tr>
#     <tr>
#       <th id="T_99d78_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99d78_row2_col0" class="data row2 col0" >0.9195</td>
#       <td id="T_99d78_row2_col1" class="data row2 col1" >0.5763</td>
#       <td id="T_99d78_row2_col2" class="data row2 col2" >0.0372</td>
#       <td id="T_99d78_row2_col3" class="data row2 col3" >0.1016</td>
#       <td id="T_99d78_row2_col4" class="data row2 col4" >0.0545</td>
#       <td id="T_99d78_row2_col5" class="data row2 col5" >0.0218</td>
#       <td id="T_99d78_row2_col6" class="data row2 col6" >0.0248</td>
#     </tr>
#     <tr>
#       <th id="T_99d78_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99d78_row3_col0" class="data row3 col0" >0.9145</td>
#       <td id="T_99d78_row3_col1" class="data row3 col1" >0.5475</td>
#       <td id="T_99d78_row3_col2" class="data row3 col2" >0.0286</td>
#       <td id="T_99d78_row3_col3" class="data row3 col3" >0.0671</td>
#       <td id="T_99d78_row3_col4" class="data row3 col4" >0.0401</td>
#       <td id="T_99d78_row3_col5" class="data row3 col5" >0.0029</td>
#       <td id="T_99d78_row3_col6" class="data row3 col6" >0.0032</td>
#     </tr>
#     <tr>
#       <th id="T_99d78_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99d78_row4_col0" class="data row4 col0" >0.9141</td>
#       <td id="T_99d78_row4_col1" class="data row4 col1" >0.5424</td>
#       <td id="T_99d78_row4_col2" class="data row4 col2" >0.0486</td>
#       <td id="T_99d78_row4_col3" class="data row4 col3" >0.1030</td>
#       <td id="T_99d78_row4_col4" class="data row4 col4" >0.0660</td>
#       <td id="T_99d78_row4_col5" class="data row4 col5" >0.0271</td>
#       <td id="T_99d78_row4_col6" class="data row4 col6" >0.0292</td>
#     </tr>
#     <tr>
#       <th id="T_99d78_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_99d78_row5_col0" class="data row5 col0" >0.9161</td>
#       <td id="T_99d78_row5_col1" class="data row5 col1" >0.5532</td>
#       <td id="T_99d78_row5_col2" class="data row5 col2" >0.0395</td>
#       <td id="T_99d78_row5_col3" class="data row5 col3" >0.0930</td>
#       <td id="T_99d78_row5_col4" class="data row5 col4" >0.0553</td>
#       <td id="T_99d78_row5_col5" class="data row5 col5" >0.0189</td>
#       <td id="T_99d78_row5_col6" class="data row5 col6" >0.0209</td>
#     </tr>
#     <tr>
#       <th id="T_99d78_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_99d78_row6_col0" class="data row6 col0" >0.0028</td>
#       <td id="T_99d78_row6_col1" class="data row6 col1" >0.0119</td>
#       <td id="T_99d78_row6_col2" class="data row6 col2" >0.0080</td>
#       <td id="T_99d78_row6_col3" class="data row6 col3" >0.0132</td>
#       <td id="T_99d78_row6_col4" class="data row6 col4" >0.0097</td>
#       <td id="T_99d78_row6_col5" class="data row6 col5" >0.0086</td>
#       <td id="T_99d78_row6_col6" class="data row6 col6" >0.0093</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
pip install scikit-optimize
# Out:
# Requirement already satisfied: scikit-optimize in c:\users\avitr\appdata\roaming\python\python310\site-packages (0.10.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from scikit-optimize) (1.2.0)
# Requirement already satisfied: pyaml>=16.9 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from scikit-optimize) (23.12.0)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from scikit-optimize) (1.24.4)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from scikit-optimize) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from scikit-optimize) (1.4.1.post1)
# Requirement already satisfied: packaging>=21.3 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from scikit-optimize) (23.2)
# Requirement already satisfied: PyYAML in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# tuned_dt = tune_model(best, search_library = 'optuna')

# %%
pip install pycaret[tuners] --user
# Out:
# Requirement already satisfied: pycaret[tuners] in c:\users\avitr\appdata\roaming\python\python310\site-packages (3.3.0)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (8.12.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (8.0.4)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (4.65.0)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (1.24.4)
# Requirement already satisfied: pandas<2.2.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (1.4.2)
# Requirement already satisfied: jinja2>=3 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (3.1.2)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (1.10.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (1.2.0)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (1.4.1.post1)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\avitr\appdata\roaming\python\python310\site-packages (from pycaret[tuners]) (1.1.3)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\avitr\appdata\roaming\python\python310\site-packages (from pycaret[tuners]) (0.12.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\avitr\appdata\roaming\python\python310\site-packages (from pycaret[tuners]) (2.6.3)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\avitr\appdata\roaming\python\python310\site-packages (from pycaret[tuners]) (4.3.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (0.57.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (2.31.0)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (5.9.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (2.1.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (6.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (5.7.0)
# Requirement already satisfied: cloudpickle in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (2.0.2)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\avitr\appdata\roaming\python\python310\site-packages (from pycaret[tuners]) (3.5.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\avitr\appdata\roaming\python\python310\site-packages (from pycaret[tuners]) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\avitr\appdata\roaming\python\python310\site-packages (from pycaret[tuners]) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (5.19.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\avitr\appdata\roaming\python\python310\site-packages (from pycaret[tuners]) (0.9.2)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pycaret[tuners]) (0.14.0)
# Requirement already satisfied: sktime>=0.26.0 in c:\users\avitr\appdata\roaming\python\python310\site-packages (from pycaret[tuners]) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\avitr\appdata\roaming\python\python310\site-packages (from pycaret[tuners]) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\avitr\appdata\roaming\python\python310\site-packages (from pycaret[tuners]) (2.0.4)
# Collecting hyperopt>=0.2.7 (from pycaret[tuners])
#   Obtaining dependency information for hyperopt>=0.2.7 from https://files.pythonhosted.org/packages/b6/cd/5b3334d39276067f54618ce0d0b48ed69d91352fbf137468c7095170d0e5/hyperopt-0.2.7-py2.py3-none-any.whl.metadata
#   Using cached hyperopt-0.2.7-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting optuna>=3.0.0 (from pycaret[tuners])
#   Obtaining dependency information for optuna>=3.0.0 from https://files.pythonhosted.org/packages/15/da/68883911855d8b4d521f9a370e4e6aab8232b91c1d8d5a8348c4680c6642/optuna-3.6.1-py3-none-any.whl.metadata
#   Using cached optuna-3.6.1-py3-none-any.whl.metadata (17 kB)
# Collecting scikit-optimize>=0.9.0 (from pycaret[tuners])
#   Obtaining dependency information for scikit-optimize>=0.9.0 from https://files.pythonhosted.org/packages/90/0e/15deb91b3db0003843e34e72fa865e1d92013781d986fdc65483c99a9f69/scikit_optimize-0.10.1-py2.py3-none-any.whl.metadata
#   Using cached scikit_optimize-0.10.1-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tune-sklearn>=0.2.1 (from pycaret[tuners])
#   Obtaining dependency information for tune-sklearn>=0.2.1 from https://files.pythonhosted.org/packages/d9/48/05dd77618ccd92c5439f23bf472501378f081b163aea5ee60af51ec4c1d7/tune_sklearn-0.5.0-py3-none-any.whl.metadata
#   Using cached tune_sklearn-0.5.0-py3-none-any.whl.metadata (12 kB)
# Collecting ray[tune]>=1.0.0 (from pycaret[tuners])
#   Obtaining dependency information for ray[tune]>=1.0.0 from https://files.pythonhosted.org/packages/59/94/e8d55a131ba8e74e4826da58209a8f4dbfe1f7c819eb54b64d4d39f2dd14/ray-2.10.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached ray-2.10.0-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from category-encoders>=2.4.0->pycaret[tuners]) (0.5.3)
# Requirement already satisfied: packaging in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from deprecation>=2.1.0->pycaret[tuners]) (23.2)
# Requirement already satisfied: six in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from hyperopt>=0.2.7->pycaret[tuners]) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from hyperopt>=0.2.7->pycaret[tuners]) (3.1)
# Collecting future (from hyperopt>=0.2.7->pycaret[tuners])
#   Obtaining dependency information for future from https://files.pythonhosted.org/packages/da/71/ae30dadffc90b9006d77af76b393cb9dfbfc9629f339fc1574a1c52e6806/future-1.0.0-py3-none-any.whl.metadata
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: py4j in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from hyperopt>=0.2.7->pycaret[tuners]) (0.10.9.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret[tuners]) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from importlib-metadata>=4.12.0->pycaret[tuners]) (3.11.0)
# Requirement already satisfied: backcall in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipython>=5.5.0->pycaret[tuners]) (0.2.0)
# Requirement already satisfied: decorator in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipython>=5.5.0->pycaret[tuners]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipython>=5.5.0->pycaret[tuners]) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipython>=5.5.0->pycaret[tuners]) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipython>=5.5.0->pycaret[tuners]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipython>=5.5.0->pycaret[tuners]) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipython>=5.5.0->pycaret[tuners]) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipython>=5.5.0->pycaret[tuners]) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipython>=5.5.0->pycaret[tuners]) (5.7.1)
# Requirement already satisfied: colorama in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipython>=5.5.0->pycaret[tuners]) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipywidgets>=7.6.5->pycaret[tuners]) (6.19.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipywidgets>=7.6.5->pycaret[tuners]) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipywidgets>=7.6.5->pycaret[tuners]) (3.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from matplotlib<3.8.0->pycaret[tuners]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from matplotlib<3.8.0->pycaret[tuners]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from matplotlib<3.8.0->pycaret[tuners]) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from matplotlib<3.8.0->pycaret[tuners]) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from matplotlib<3.8.0->pycaret[tuners]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from matplotlib<3.8.0->pycaret[tuners]) (2.8.2)
# Requirement already satisfied: fastjsonschema in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from nbformat>=4.2.0->pycaret[tuners]) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from nbformat>=4.2.0->pycaret[tuners]) (4.21.1)
# Requirement already satisfied: jupyter-core in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from nbformat>=4.2.0->pycaret[tuners]) (5.3.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from numba>=0.55.0->pycaret[tuners]) (0.40.0)
# Collecting alembic>=1.5.0 (from optuna>=3.0.0->pycaret[tuners])
#   Obtaining dependency information for alembic>=1.5.0 from https://files.pythonhosted.org/packages/7f/50/9fb3a5c80df6eb6516693270621676980acd6d5a9a7efdbfa273f8d616c7/alembic-1.13.1-py3-none-any.whl.metadata
#   Using cached alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna>=3.0.0->pycaret[tuners])
#   Obtaining dependency information for colorlog from https://files.pythonhosted.org/packages/f3/18/3e867ab37a24fdf073c1617b9c7830e06ec270b1ea4694a624038fc40a03/colorlog-6.8.2-py3-none-any.whl.metadata
#   Using cached colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from optuna>=3.0.0->pycaret[tuners]) (1.4.39)
# Requirement already satisfied: PyYAML in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from optuna>=3.0.0->pycaret[tuners]) (6.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pandas<2.2.0->pycaret[tuners]) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from plotly>=5.14.0->pycaret[tuners]) (8.2.2)
# Requirement already satisfied: dash>=2.9.0 in c:\users\avitr\appdata\roaming\python\python310\site-packages (from plotly-resampler>=0.8.3.1->pycaret[tuners]) (2.15.0)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret[tuners]) (3.9.14)
# Requirement already satisfied: tsdownsample==0.1.2 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret[tuners]) (0.1.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pmdarima>=2.0.4->pycaret[tuners]) (3.0.8)
# Requirement already satisfied: urllib3 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pmdarima>=2.0.4->pycaret[tuners]) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from pmdarima>=2.0.4->pycaret[tuners]) (68.0.0)
# Requirement already satisfied: click>=7.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ray[tune]>=1.0.0->pycaret[tuners]) (8.1.7)
# Requirement already satisfied: filelock in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ray[tune]>=1.0.0->pycaret[tuners]) (3.9.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ray[tune]>=1.0.0->pycaret[tuners]) (1.0.3)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ray[tune]>=1.0.0->pycaret[tuners]) (4.23.4)
# Requirement already satisfied: aiosignal in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ray[tune]>=1.0.0->pycaret[tuners]) (1.2.0)
# Requirement already satisfied: frozenlist in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ray[tune]>=1.0.0->pycaret[tuners]) (1.3.3)
# Collecting tensorboardX>=1.9 (from ray[tune]>=1.0.0->pycaret[tuners])
#   Obtaining dependency information for tensorboardX>=1.9 from https://files.pythonhosted.org/packages/44/71/f3e7c9b2ab67e28c572ab4e9d5fa3499e0d252650f96d8a3a03e26677f53/tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata
#   Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ray[tune]>=1.0.0->pycaret[tuners]) (11.0.0)
# Requirement already satisfied: fsspec in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ray[tune]>=1.0.0->pycaret[tuners]) (2023.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from requests>=2.27.1->pycaret[tuners]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from requests>=2.27.1->pycaret[tuners]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from requests>=2.27.1->pycaret[tuners]) (2023.7.22)
# Requirement already satisfied: pyaml>=16.9 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from scikit-optimize>=0.9.0->pycaret[tuners]) (23.12.0)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from sktime>=0.26.0->pycaret[tuners]) (0.7.2)
# Collecting Mako (from alembic>=1.5.0->optuna>=3.0.0->pycaret[tuners])
#   Obtaining dependency information for Mako from https://files.pythonhosted.org/packages/c6/c9/9cd84cbd5816aa8bee5fd5a00f857efd636ec30586848d571b67baf0b868/Mako-1.3.3-py3-none-any.whl.metadata
#   Using cached Mako-1.3.3-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in c:\users\avitr\appdata\roaming\python\python310\site-packages (from alembic>=1.5.0->optuna>=3.0.0->pycaret[tuners]) (4.9.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[tuners]) (2.2.2)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[tuners]) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[tuners]) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[tuners]) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[tuners]) (5.0.0)
# Requirement already satisfied: retrying in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[tuners]) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[tuners]) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[tuners]) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[tuners]) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[tuners]) (7.4.9)
# Requirement already satisfied: pyzmq>=17 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[tuners]) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[tuners]) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret[tuners]) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[tuners]) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[tuners]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[tuners]) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[tuners]) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret[tuners]) (0.2.5)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from sqlalchemy>=1.3.0->optuna>=3.0.0->pycaret[tuners]) (2.0.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret[tuners]) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret[tuners]) (305.1)
# Requirement already satisfied: executing in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret[tuners]) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret[tuners]) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret[tuners]) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret[tuners]) (2.0.1)
# Requirement already satisfied: entrypoints in c:\users\avitr\anaconda3\envs\test_env\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[tuners]) (0.4)
# Using cached hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
# Using cached optuna-3.6.1-py3-none-any.whl (380 kB)
# Using cached scikit_optimize-0.10.1-py2.py3-none-any.whl (107 kB)
# Using cached tune_sklearn-0.5.0-py3-none-any.whl (42 kB)
# Using cached alembic-1.13.1-py3-none-any.whl (233 kB)
# Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Using cached colorlog-6.8.2-py3-none-any.whl (11 kB)
# Using cached future-1.0.0-py3-none-any.whl (491 kB)
# Using cached ray-2.10.0-cp310-cp310-win_amd64.whl (25.4 MB)
# Using cached Mako-1.3.3-py3-none-any.whl (78 kB)
# Installing collected packages: tensorboardX, Mako, future, colorlog, hyperopt, alembic, scikit-optimize, optuna, ray, tune-sklearn
# Successfully installed Mako-1.3.3 alembic-1.13.1 colorlog-6.8.2 future-1.0.0 hyperopt-0.2.7 optuna-3.6.1 ray-2.10.0 scikit-optimize-0.10.1 tensorboardX-2.6.2.2 tune-sklearn-0.5.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script mako-render.exe is installed in 'C:\Users\avitr\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts futurize.exe and pasteurize.exe are installed in 'C:\Users\avitr\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script hyperopt-mongo-worker.exe is installed in 'C:\Users\avitr\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script alembic.exe is installed in 'C:\Users\avitr\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script optuna.exe is installed in 'C:\Users\avitr\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts ray.exe, rllib.exe, serve.exe and tune.exe are installed in 'C:\Users\avitr\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !pip install optuna

# %%
best
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='squared_error',
#                           max_depth=3, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_samples_leaf=1,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=100, n_iter_no_change=None,
#                           random_state=42, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
                          init=None, learning_rate=0.1, loss='squared_error',
                          max_depth=3, max_features=None, max_leaf_nodes=None,
                          min_impurity_decrease=0.0, min_samples_leaf=1,
                          min_samples_split=2, min_weight_fraction_leaf=0.0,
                          n_estimators=100, n_iter_no_change=None,
                          random_state=42, subsample=1.0, tol=0.0001,
                          validation_fraction=0.1, verbose=0, warm_start=False)

# %%
s = predict_model(tuned_dt,data=df_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f988e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f988e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f988e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f988e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f988e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f988e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f988e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f988e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f988e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f988e_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_f988e_row0_col1" class="data row0 col1" >7.7689</td>
#       <td id="T_f988e_row0_col2" class="data row0 col2" >91.0181</td>
#       <td id="T_f988e_row0_col3" class="data row0 col3" >9.5403</td>
#       <td id="T_f988e_row0_col4" class="data row0 col4" >0.0601</td>
#       <td id="T_f988e_row0_col5" class="data row0 col5" >0.2477</td>
#       <td id="T_f988e_row0_col6" class="data row0 col6" >0.2209</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_dt.get_params()
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.04264031156015375,
#  'loss': 'squared_error',
#  'max_depth': 3,
#  'max_features': 0.7588282465072769,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.00962114482009193,
#  'min_samples_leaf': 3,
#  'min_samples_split': 3,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 229,
#  'n_iter_no_change': None,
#  'random_state': 42,
#  'subsample': 0.8981042826479537,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
score = f1_score(s['is_claim'], s['prediction_label'],average='macro')
score
# Out:
# 0.49907075577802096

# %%
df_train
# Out:
#        policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0                 54          63                   37           C9
# 1                 36           8                   42           C3
# 2                 79           4                   37           C5
# 3                 46           0                   37           C9
# 4                 66          63                   36          C10
# ...              ...         ...                  ...          ...
# 39995             25          12                   34          C10
# 39996             11          37                   30           C8
# 39997             96          96                   44           C8
# 39998             61          25                   60           C7
# 39999             94          33                   38          C19
#
#        population_density  make segment model fuel_type      max_torque  ...  \
# 0                   17804     3      C2    M4    Diesel   250Nm@2750rpm  ...
# 1                    4076     1       A    M1       CNG    60Nm@3500rpm  ...
# 2                   34738     1       A    M1       CNG    60Nm@3500rpm  ...
# 3                   17804     1      B1    M8       CNG  82.1Nm@3400rpm  ...
# 4                   73430     3      C2    M4    Diesel   250Nm@2750rpm  ...
# ...                   ...   ...     ...   ...       ...             ...  ...
# 39995               73430     1       A    M1       CNG    60Nm@3500rpm  ...
# 39996                8794     1      B2    M6    Petrol   113Nm@4400rpm  ...
# 39997                8794     3      C2    M4    Diesel   250Nm@2750rpm  ...
# 39998                6112     1      B2    M6    Petrol   113Nm@4400rpm  ...
# 39999               27742     3      C2    M4    Diesel   250Nm@2750rpm  ...
#
#       is_brake_assist is_power_door_locks  is_central_locking  \
# 0                   1                   1                   1
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   1                   1
# 4                   1                   1                   1
# ...               ...                 ...                 ...
# 39995               0                   0                   0
# 39996               1                   1                   1
# 39997               1                   1                   1
# 39998               1                   1                   1
# 39999               1                   1                   1
#
#        is_power_steering  is_driver_seat_height_adjustable  \
# 0                      1                                 1
# 1                      1                                 0
# 2                      1                                 0
# 3                      1                                 0
# 4                      1                                 1
# ...                  ...                               ...
# 39995                  1                                 0
# 39996                  1                                 1
# 39997                  1                                 1
# 39998                  1                                 1
# 39999                  1                                 1
#
#        is_day_night_rear_view_mirror  is_ecw  is_speed_alert ncap_rating  \
# 0                                  0       1               1           3
# 1                                  0       0               1           0
# 2                                  0       0               1           0
# 3                                  0       1               1           2
# 4                                  0       1               1           3
# ...                              ...     ...             ...         ...
# 39995                              0       0               1           0
# 39996                              1       1               1           2
# 39997                              0       1               1           3
# 39998                              1       1               1           2
# 39999                              0       1               1           3
#
#        is_claim
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 39995         0
# 39996         0
# 39997         0
# 39998         0
# 39999         1
#
# [40000 rows x 43 columns]

# %%
param = {'criterion': 'gini',
     'max_depth': 50,
     'max_features': 70,
     'min_samples_leaf': 1,
     'min_samples_split': 6,
     'splitter': 'best'}
    
    param1 = {'splitter': 'best',
     'min_samples_split': 4,
     'min_samples_leaf': 1,
     'max_features': 86,
     'max_depth': 39,
     'criterion': 'gini'}
    
    param2 = {'objective': 'binary:logistic',
     'use_label_encoder': True,
     'base_score': 0.5,
     'booster': 'gbtree',
     'colsample_bylevel': 1,
     'colsample_bynode': 1,
     'colsample_bytree': 0.8267970059231334,
     'enable_categorical': False,
     'gamma': 0,
     'gpu_id': -1,
     'importance_type': None,
     'interaction_constraints': '',
     'learning_rate': 0.15117171590296455,
     'max_delta_step': 0,
     'max_depth': 11,
     'min_child_weight': 1,
     'missing': float('nan'),
     'monotone_constraints': '()',
     'n_estimators': 300,
     'n_jobs': -1,
     'num_parallel_tree': 1,
     'predictor': 'auto',
     'random_state': 42,
     'reg_alpha': 1e-10,
     'reg_lambda': 0.3295926053124784,
     'scale_pos_weight': 1.0,
     'subsample': 1.0,
     'tree_method': 'auto',
     'validate_parameters': 1,
     'verbosity': 0}
