# %% [markdown]
# <span class="alert alert-success" style="display: block; text-align: center;">
#
# ## FNCE30012: Foundations of Fintech
# ## Assignment 3: Using GENAI at Scale
#
# </span>
#
# <span class="alert alert-info" style="display: inline-block;">
# All questions must be completed and submitted via JupyterHub (any other submissions will not be marked). The assignment notebook contains certain pre-defined variables. A submission that renames these variables will attract zero marks. Calculations involving decimal numbers should be precise to 3 decimal places (e.g., if the answer is 4.122229, then one should use 4.123 instead of 4.1).
#
# This notebook provides cells where you can enter your solutions. You are allowed to add extra cells; however, you should not remove any existing cells.
#
# Please use the **ED** forum to ask any queries regarding this assignment.
#
# **Late submission penalties**
# - 10% of the maximum mark per day the assessment task is overdue.
# - Assignments submitted 10 days after the deadline will not be graded and will receive a grade of zero.
# - Exceeding word limits: Assessment tasks should not vary more than 10% from the required word count (where relevant).
#
# **Assignment Extensions**
# - Faculty extensions policy can be found here: [http://policy.unimelb.edu.au/MPF1326#section-4.37](http://policy.unimelb.edu.au/MPF1326#section-4.37)
# - Requests for an assignment extension should be submitted here: [http://go.unimelb.edu.au/yh9n](http://go.unimelb.edu.au/yh9n)
#
# **Submission**
# This assignment should be submitted via the JupyterHub system.
#
# **Plagiarism declaration**
# By submitting work for assessment, I hereby declare that I understand the University's policy on academic integrity and statement on the use of artificial intelligence software. In accordance with these documents, I declare that the work submitted is original and solely my work, and that I have not been assisted by a third party (collusion) apart from where the submitted work is for a designated collaborative task, in which case the individual contributions are indicated. I also declare that I have not used any writing tools or sources without proper acknowledgement (plagiarism). Where the submitted work is a computer program or code, I further declare that any copied code is declared in comments identifying the source at the start of the program or in a header file, that comments inline identify the start and end of the copied code, and that any modifications to code sources elsewhere are commented upon as to the nature of the modification.
#
# <hr/>
#
# **Important:** It is important that you follow the assignment submission instructions as per "How to submit assignments on JupyterHub" available under Modules/Assessment on Canvas or under [FAQs](https://edstem.org/au/courses/17695/discussion/?category=FAQs) on Ed.
#
# <span class="label label-danger text-uppercase">Note</span>: The assignment will ask you to follow certain precise instructions such as storing results in predefined variable names, or reading CSV files into dataframes with specific names. Failure to follow these instructions would attract penalty.
# </span>
#
# <span class="alert alert-danger"  style="display: inline-block;">
#     <span class="label label-danger text-uppercase">Note</span>
#     <span>
#         Write your answers in <strong>this notebook</strong> only <em>within</em> the provided cells. <strong>Do not</strong> create additional cells by duplicating/copying existing cells. <br/>
#         You may keep a copy of this base notebook as reference to original file and to compare that you haven't accidentally duplicated cells or changed the order of these cells. However, note that additional notebooks and copies aren't marked. <strong>Filename matters</strong>.
#     </span>
# </span>

# %% [markdown]
# <span class="alert alert-info" style="display: block;">
#
# **Associated Data Files:** We will use a variety of files for this assignment:
#
# * In the `data/` directory, you will find the full 10K report of 10 different firms in the US, in the form of an HTML/XML file.
#
# </span>

# %% [markdown]
# ### Predefined Package Imports

# %%
"""Import Required Libraries - No need to duplicate or reimport; 
This is a Read-Only cell. Simply execute this cell"""
import requests
import tqdm
from bs4 import BeautifulSoup
import google.generativeai as genai
import re
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import your additional packages in the cell below
# Further imports are not required, but you may use additional packages if you wish.

# %%
"""Your own additional imports go here"""
# BEGIN - YOUR CODE GOES HERE
import os
import unicodedata

pass
# END - YOUR CODE GOES HERE

# %% [markdown]
# <hr style="height:1px; width:85%">

# %% [markdown]
# ## Question 1 [1 mark]
# Configure the Google Gemini AI with your own key. In the assignment, please ensure that you have input your
# API key below. Then, create a model object that can be used to generate content from a prompt with `gemini-1.5-flash`. You should use the given variable to store the model.
#
# <span class="label label-warning text-uppercase">Note</span> You will need your own personal API key to complete the assignment. Markers will use their own key, hence **DO NOT** store/reveal it permanently in this notebook
#
# See https://ai.google.dev/gemini-api/docs/api-key on how to get your own key

# %%
"""This is a Read-Only Cell. 
Remember to execute this cell at least once per execution/session of your Python Kernel.
You will have to re-run this cell, if you restart your kernel."""

GOOGLE_GEMINI_API_KEY = get_secure_env('GOOGLE_GEMINI_API_KEY')

# %%
"""Predefined Variables - Do Not Change their Name;
This is a Read-Only cell. Remember to execute this cell once"""
model = None

# %%
"""Populate the variables shown above with appropriate values here"""
# BEGIN - YOUR CODE GOES HERE

model = genai.configure(api_key=GOOGLE_GEMINI_API_KEY)

pass
# END - YOUR CODE GOES HERE

# %%
# AIzaSyCKYCSXSXCk7KMitSJVYthQMulzozlbkOM

# %% [markdown]
# <hr style="height:1px; width:85%">

# %% [markdown]
# ## Question 2 [1 mark]
# Write a function that loads the entire text contained in a file and use it to load Amazon's latest 10K report (in `data`). You should use the given variable to store the data.

# %%
"""Predefined Variables - Do Not Change their Name;
This is a Read-Only cell. Remember to execute this cell once"""
html_content = None

# %%
"""Populate the variables shown above with appropriate values here"""
# BEGIN - YOUR CODE GOES HERE

# BEGIN - YOUR CODE GOES HERE
file_path = "data/AMZN_latest_10K.html"  # Correct file name

# Open the file and read its contents into html_content
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()
# END - YOUR CODE GOES HERE


pass

# END - YOUR CODE GOES HERE

# %%
"""This is a Read-Only cell. Execute this cell to display your contents"""
try:
    display_xml(html_content)
except:
    print(f"Oops! The universe is missing something.")
# Out:
# <html xmlns:ixt="http://www.xbrl.org/inlineXBRL/transformation/2020-02-12" xmlns:srt="http://fasb.org/srt/2023" xmlns:dei="http://xbrl.sec.gov/dei/2023" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xbrli="http://www.xbrl.org/2003/instance" xmlns:xbrldi="http://xbrl.org/2006/xbrldi" xmlns:link="http://www.xbrl.org/2003/linkbase" xmlns="http://www.w3.org/1999/xhtml" xmlns:country="http://xbrl.sec.gov/country/2023" xmlns:iso4217="http://www.xbrl.org/2003/iso4217" xmlns:amzn="http://www.amazon.com/20231231" xmlns:ix="http://www.xbrl.org/2013/inlineXBRL" xmlns:us-gaap="http://fasb.org/us-gaap/2023" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:ixt-sec="http://www.sec.gov/inlineXBRL/transformation/2015-08-31" xmlns:ecd="http://xbrl.sec.gov/ecd/2023" xml:lang="en-US"><head>
#
#
# ...

# %% [markdown]
# <hr style="height:1px; width:85%">

# %% [markdown]
# ## Question 3 [1 mark]
# Write a function that removes all the HTML tags to make the content of the 10K ready to be processed by an LLM.
#
# Apply it to the previously loaded 10K.
#
# You should use the given variable to store the resulting text data.
#
# <span class="label label-info text-uppercase">Hint</span> *Keep it simple.*

# %%
"""Predefined Variables - Do Not Change their Name;
This is a Read-Only cell. Remember to execute this cell once"""
plain_text = None

# %%
"""Populate the variables shown above with appropriate values here"""
# BEGIN - YOUR CODE GOES HERE

soup = BeautifulSoup(html_content, 'html.parser')
plain_text = soup.get_text(separator='\n') 


# new part
plain_text_2 = unicodedata.normalize('NFKD', plain_text).encode('ascii', 'ignore').decode('utf-8')
plain_text = re.sub(r'[^\x00-\x7F]+', ' ', plain_text_2)

pass
# END - YOUR CODE GOES HERE

# %%
"""This is a Read-Only cell. Execute this cell to display your contents"""
try:
    display_xml(plain_text)
except:
    print(f"Oops! The universe is missing something.")
# Out:
# <p>amzn-20231231
# false
# 2023
# FY
# 0001018724
# http://fasb.org/us-gaap/2023#OtherAssetsNoncurrent
# http://fasb.org/us-gaap/2023#OtherAssetsNoncurrent
# P3Y
# P1Y
# P1Y
# http://fasb.org/us-gaap/2023#PropertyPlantAndEquipmentAndFinanceLeaseRightOfUseAssetAfterAccumulatedDepreciationAndAmortization
# http://fasb.org/us-gaap/2023#PropertyPlantAndEquipmentAndFinanceLeaseRightOfUseAssetAfterAccumulatedDepreciationAndAmortization
# http://fasb.org/us-gaap/2023#AccruedLiabilitiesCurrent
# http://fasb.org/us-gaap/2023#AccruedLiabilitiesCurrent
# http://fasb.org/us-gaap/2023#AccruedLiabilitiesCurrent
# http://fasb.org/us-gaap/2023#AccruedLiabilitiesCurrent
# http://www.amazon.com/20231231#LeaseLiabilityNoncurrent
# http://www.amazon.com/20231231#LeaseLiabilityNoncurrent
# http://www.amazon.com/20231231#LeaseLiabilityNoncurrent
# http://www.amazon.com/20231231#LeaseLiabilityNoncurrent
# http://fasb.org/us-gaap/2023#AccruedLiabilitiesCurrent
# ...

# %% [markdown]
# <hr style="height:1px; width:85%">

# %% [markdown]
# ## Question 4 [5 marks]
#
# Write (in your code) a string that contains a prompt to give to an LLM. The goal of the prompt is to read the 10K report of the firm and find how the company views AI-related **Risk** and **Opportunity**. Additionally, the prompt should produce a third section on **Investment**, summarizing the investment in AI planned by the firm (if any) and clearly expressing in billions of dollars the latest year of investment in AI.
#
# The prompt should:
# 1. Explain the task to the LLM.
# 2. Ask the LLM to produce small sections (a few sentences each) on the three topics mentioned above.
# 3. Include a way for you to easily check the information is genuine and the LLM did not hallucinate.
# 4. Be designed to easily extract the three sections and the total investment from the model's answer.
#
# Remember that Gemini gives you 15 free API calls per minute, so design and debug your code accordingly. You should use the given variable to store your prompt.

# %%
"""Predefined Variables - Do Not Change their Name;
This is a Read-Only cell. Remember to execute this cell once"""
prompt = None

# %%
"""Populate the variables shown above with appropriate values here"""
# BEGIN - YOUR CODE GOES HERE

prompt = """
You are tasked with analyzing the company's 10-K report to identify and summarize three key areas related to AI:

1. **AI-Related Risk**: Please summarize the main risks the company has identified concerning AI technologies. This summary should be a few sentences long.

2. **AI-Related Opportunity**: Summarize the main opportunities the company sees in AI technologies. This should also be a few sentences long.

3. **AI Investment**: Provide a summary of the company's latest investments in AI. Specifically, include the total dollar amount of AI investment in the latest year, expressed in billions of dollars.

Additionally, I need you to:
- Clearly separate each section for easy identification.
- Ensure that the information you provide is accurate and genuine by only referencing data directly from the report.
- Include a brief verification statement for each section to confirm the information is based on the 10-K report.

Please structure your response as follows:
1. AI-Related Risk: [Your summary]
2. AI-Related Opportunity: [Your summary]
3. AI Investment: [Your summary and investment amount in billions of dollars]

Make sure each summary is concise and clearly structured.
"""

pass
# END - YOUR CODE GOES HERE

# %% [markdown]
# <hr style="height:1px; width:85%">

# %% [markdown]
# ## Question 5 [1 mark]
#
# Use Gemini to process the prompt and extract the text of the model's answer. You should use the given variable to store the extracted text.

# %%
"""Predefined Variables - Do Not Change their Name;
This is a Read-Only cell. Remember to execute this cell once"""
response_text = None

# %%
"""Populate the variables shown above with appropriate values here"""
# BEGIN - YOUR CODE GOES HERE
# Assuming the model has already been configured and the correct method is `predict`
response = genai.model.predict(prompt=prompt)

# Extract the text from the response
response_text = response['text']  # Adjust the key name if necessary
# END - YOUR CODE GOES HERE


pass
# END - YOUR CODE GOES HERE
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3244492/616308149.py in <module>
#       2 # BEGIN - YOUR CODE GOES HERE
#       3 # Assuming the model has already been configured and the correct method is `predict`
# ----> 4 response = genai.model.predict(prompt=prompt)
#       5
#       6 # Extract the text from the response
#
# AttributeError: module 'google.generativeai' has no attribute 'model'

# %%
"""This is a Read-Only cell. Execute this cell to display your contents"""
try:
    print(response_text)
except:
    print(f"Oops! The universe is missing something.")

# %% [markdown]
# <hr style="height:1px; width:85%">

# %% [markdown]
# ## Question 6 [2 marks]
#
# Write code to parse the three sections and the investment value from the prompt. By parsing, we mean extracting each individual section into separate Python variables.
#
# If you cannot do it trivially, you may need to go back to your prompt and design it to make this task easier.
#
# Put the extracted sections in a Series called `extracted_info` (replacing the `None` in the example given).

# %%
"""Predefined Variables - Do Not Change their Name;
This is a Read-Only cell. Remember to execute this cell once"""
extracted_info = pd.Series({
    'Risk': None,
    'Opportunity': None,
    'Investment': None,
    'Investment Value (Billion USD)': None
})

# %%
"""Populate the variables shown above with appropriate values here"""
# BEGIN - YOUR CODE GOES HERE
pass
# END - YOUR CODE GOES HERE

# %%
"""This is a Read-Only cell. Execute this cell to display your contents"""
try:
    display(extracted_info)
except:
    print(f"Oops! The universe is missing something.")

# %% [markdown]
# <hr style="height:1px; width:85%">

# %% [markdown]
# ## Question 7 [2 mark]
#
# Write a loop that goes over the 10 firms in `data/` and runs the analysis you coded above. That is, for each firm:
# 1. Load the entire 10K.
# 2. Remove the HTML tags.
# 3. Create a prompt to analyze the AI view (same as before).
# 4. Use Gemini's latest model to process the prompt.
# 5. Parse the `extracted_info` Series.
#
# Then save all the vectors together and organize them into a single DataFrame (using the code given) that you should save as `10k_extracted_info.csv`.
#
#
# *Hint: You just need to fill in the blanks below.*

# %%
"""Predefined Variables - Do Not Change their Name;
This is a Read-Only cell. Remember to execute this cell once"""
tickers = ['NVDA', 'GOOGL', 'MSFT', 'AMZN', 'META', 'TSLA', 'IBM', 'INTC', 'CRM', 'ORCL']
all_info = []

# %%
"""Populate the variables shown above with appropriate values here"""
for tic in tqdm.tqdm(tickers, desc='Extracting information'):
    extracted_info = None # Populate it below; See above for column names
    # BEGIN - YOUR CODE GOES HERE
    pass
    # END - YOUR CODE GOES HERE
    all_info.append(extracted_info)

# %%
"""This is a Read-Only cell. Execute this cell to display and save your contents"""
try:
    tickers_base = ['NVDA', 'GOOGL', 'MSFT', 'AMZN', 'META', 'TSLA', 'IBM', 'INTC', 'CRM', 'ORCL']
    df = pd.DataFrame(all_info, index=tickers_base)
    df.to_csv('10k_extracted_info.csv')
    display(df)
except:
    print(f"Oops! The universe is missing something.")

# %% [markdown]
# <hr style="height:1px; width:85%">

# %% [markdown]
# ## Question 8 [3 marks]
# Answer all the questions below in the next markdown cell with 100 words or less per question.
#
# 1. Do you believe the model accurately summarizes the companies' views of AI as expressed in their 10K report? Why or why not?
#
# 2. Does the Investment Value (Billion USD) cell provide a reliable and comparable estimation of the AI investment of each company? Why or why not?
#
# 3. Do you think GPT would have done a better or worse job at it? Argue why.

# %% [markdown]
# <span class="label label-info text-uppercase">Note</span>
# <span>Write your answer in the Markdown cell below</span>

# %% [markdown]
# #### WRITE YOUR ANSWER(S) HERE IN THIS CELL
# *You can use Markdown syntax here.*

# %% [markdown]
# <hr style="height:1px; width:85%">

# %% [markdown]
# ## Question 9 [2 marks]
#
# Write code that puts all the sections contained in `10k_extracted_info.csv` into one big prompt and asks GEMINI to rank each of the 10 companies as 'Bullish', 'Bearish', or 'Neutral' on AI and provide a brief explanation for your ranking based on the information provided.
#
# Use the template provided to save Gemini's answer into `AI_sentiment_ranking.txt`.

# %%
"""Predefined Variables - Do Not Change their Name;
This is a Read-Only cell. Remember to execute this cell once"""
ranking_text = ''

# %%
"""Populate the variables shown above with appropriate values here"""
# BEGIN - YOUR CODE GOES HERE
pass
# END - YOUR CODE GOES HERE

# %%
"""This is a Read-Only cell. Execute this cell to save your contents"""
try:
    display(ranking_text)
    with open('AI_sentiment_ranking.txt', 'w', encoding='utf-8') as file:
        file.write(ranking_text = '')
except:
    print(f"Oops! The universe is missing something.")

# %% [markdown]
# <hr style="height:1px; width:85%">

# %% [markdown]
# ## Question 10  [2 marks]
#
# Based on your model analysis, write a brief trade proposal for an investor who believes that AI is a bubble that will burst in the next year or so. The investor wants a specific trade that, as much as possible, only takes a position on this specific idea and is not exposed to other risks. They are a large investor and will require a somewhat liquid position to put tens of millions into it.
#
# Your proposal should contain:
# - A small section where you argue the logic of the trade.
# - Another section where you outline clearly the instruments you propose and in what proportion each should be traded.

# %% [markdown]
# <span class="label label-info text-uppercase">Note</span>
# <span>Write your answer in the Markdown cell below</span>

# %% [markdown]
# #### WRITE YOUR ANSWER(S) HERE IN THIS CELL
# *You can use Markdown syntax here.*

# %% [markdown]
# <div style="width: 100%; height: 1rem; border-bottom: 0.2rem dashed black; text-align: center; margin-bottom: 10px">
#   <span style="font-size: 2rem; background-color: black; color: ivory; margin-bottom: 15px; padding: 5px 10px; border-radius: 5px">
#     End of Assignment
#   </span>
# </div>
