# %%
import numpy as np 
from tqdm.notebook import tqdm
import pandas as pd 
import os

# %%
os.listdir('data')
# Out:
# ['HAM10000_images_part_1', 'HAM10000_images_part_2', 'HAM10000_metadata.csv']

# %%
# load the metadata
data = pd.read_csv('data/HAM10000_metadata.csv')

# %%
data['dx'].value_counts()
# Out:
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: dx, dtype: int64

# %%
# number of classes
data['dx'].nunique()
# Out:
# 7

# %%
# !pip install barbar pytorch-ignite
# Out:
# Collecting barbar
#   Downloading barbar-0.2.1-py3-none-any.whl (3.9 kB)
# Collecting pytorch-ignite
#   Downloading pytorch_ignite-0.4.13-py3-none-any.whl (272 kB)
#                                               0.0/272.4 kB ? eta -:--:--
#      -                                        10.2/272.4 kB ? eta -:--:--
#      -                                        10.2/272.4 kB ? eta -:--:--
#      -----                                 41.0/272.4 kB 326.8 kB/s eta 0:00:01
#      ---------                             71.7/272.4 kB 393.8 kB/s eta 0:00:01
#      ----------------                     122.9/272.4 kB 602.4 kB/s eta 0:00:01
#      -------------------------            194.6/272.4 kB 787.7 kB/s eta 0:00:01
#      ---------------------------------    256.0/272.4 kB 874.6 kB/s eta 0:00:01
#      ------------------------------------ 272.4/272.4 kB 799.3 kB/s eta 0:00:00
# Requirement already satisfied: torch<3,>=1.3 in c:\users\avitr\anaconda3\lib\site-packages (from pytorch-ignite) (1.13.1)
# Requirement already satisfied: packaging in c:\users\avitr\anaconda3\lib\site-packages (from pytorch-ignite) (23.1)
# Requirement already satisfied: typing-extensions in c:\users\avitr\anaconda3\lib\site-packages (from torch<3,>=1.3->pytorch-ignite) (4.7.1)
# Installing collected packages: barbar, pytorch-ignite
# Successfully installed barbar-0.2.1 pytorch-ignite-0.4.13
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\avitr\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\avitr\anaconda3\lib\site-packages)
# WARNING: Error parsing requirements for pyyaml: [Errno 2] No such file or directory: 'c:\\users\\avitr\\anaconda3\\lib\\site-packages\\PyYAML-5.4.1.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\avitr\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\avitr\anaconda3\lib\site-packages)

# %%
pip install -q torch-summary
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install tensorboard
# Out:
# Requirement already satisfied: tensorboard in c:\users\avitr\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\avitr\anaconda3\lib\site-packages (from tensorboard) (1.1.0)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\avitr\appdata\roaming\python\python39\site-packages (from tensorboard) (1.51.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\avitr\anaconda3\lib\site-packages (from tensorboard) (2.16.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\avitr\anaconda3\lib\site-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\avitr\anaconda3\lib\site-packages (from tensorboard) (3.4.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\avitr\anaconda3\lib\site-packages (from tensorboard) (1.24.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\avitr\appdata\roaming\python\python39\site-packages (from tensorboard) (3.19.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\avitr\anaconda3\lib\site-packages (from tensorboard) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\avitr\anaconda3\lib\site-packages (from tensorboard) (68.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\avitr\anaconda3\lib\site-packages (from tensorboard) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\avitr\anaconda3\lib\site-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\avitr\anaconda3\lib\site-packages (from tensorboard) (2.2.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\avitr\anaconda3\lib\site-packages (from tensorboard) (0.38.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\avitr\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\avitr\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\avitr\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.12.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\avitr\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\avitr\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\avitr\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard) (6.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\avitr\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\avitr\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\avitr\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\avitr\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\avitr\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\avitr\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\avitr\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\avitr\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.2.0)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\avitr\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\avitr\anaconda3\lib\site-packages)
# WARNING: Error parsing requirements for pyyaml: [Errno 2] No such file or directory: 'c:\\users\\avitr\\anaconda3\\lib\\site-packages\\PyYAML-5.4.1.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\avitr\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\avitr\anaconda3\lib\site-packages)

# %%
conda install pytorch torchvision torchaudio pytorch-cuda=12.1 -c pytorch -c nvidia

# %%
import torch
import os
import random
import torchvision
import pandas as pd
import torch.nn as nn
import numpy as np
from torchvision import transforms, datasets
from shutil import copyfile, move
from torch.utils.tensorboard import SummaryWriter
from barbar import Bar
from torchsummary import summary
from ignite.metrics import Accuracy
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, roc_auc_score

# %% [markdown]
# # split the data into train and validation

# %%
def split_data(source, training, validation, split_size):    
    files = []
    for filename in os.listdir(source):
        file = source + filename
        if os.path.getsize(file) > 0:
            files.append(filename)
        else:
            print(filename + " is zero length, so ignoring.")

    training_length = int(len(files) * split_size)
    validation_length = int(len(files) - training_length)
    shuffled_set = random.sample(files, len(files))
    training_set = shuffled_set[0:training_length]
    validation_set = shuffled_set[:validation_length]

    for filename in training_set:
        this_file = source + filename
        destination = training + filename
        copyfile(this_file, destination)

    for filename in validation_set:
        this_file = source + filename
        destination = validation + filename
        copyfile(this_file, destination)

# %% [markdown]
# # create necessary folders to store the specific images

# %%
try:
    os.mkdir('skin_models/')
    os.mkdir('HAM10000')
    os.mkdir('orig/')
    os.mkdir('orig/0.MEL/')
    os.mkdir('orig/1.NV/')
    os.mkdir('orig/2.BCC/')
    os.mkdir('orig/3.AKIEC/')
    os.mkdir('orig/4.BKL/')
    os.mkdir('orig/5.DF/')
    os.mkdir('orig/6.VASC/')

    os.mkdir('skin/')
    os.mkdir('skin/training/')
    os.mkdir('skin/validation/')
    os.mkdir('skin/training/0.MEL/')
    os.mkdir('skin/training/1.NV/')
    os.mkdir('skin/training/2.BCC/')
    os.mkdir('skin/training/3.AKIEC/')
    os.mkdir('skin/training/4.BKL/')
    os.mkdir('skin/training/5.DF/')
    os.mkdir('skin/training/6.VASC/')
    os.mkdir('skin/validation/0.MEL/')
    os.mkdir('skin/validation/1.NV/')
    os.mkdir('skin/validation/2.BCC/')
    os.mkdir('skin/validation/3.AKIEC/')
    os.mkdir('skin/validation/4.BKL/')
    os.mkdir('skin/validation/5.DF/')
    os.mkdir('skin/validation/6.VASC/')
except:
    print('Folders already created.')
# Out:
# Folders already created.

# %%
orig_all = 'HAM10000/'
source_MEL = 'orig/0.MEL/'
source_NV = 'orig/1.NV/'
source_BCC = 'orig/2.BCC/'
source_AKIEC = 'orig/3.AKIEC/'
source_BKL = 'orig/4.BKL/'
source_DF = 'orig/5.DF/'
source_VASC = 'orig/6.VASC/'

training_MEL = 'skin/training/0.MEL/'
training_NV = 'skin/training/1.NV/'
training_BCC = 'skin/training/2.BCC/'
training_AKIEC = 'skin/training/3.AKIEC/'
training_BKL = 'skin/training/4.BKL/'
training_DF = 'skin/training/5.DF/'
training_VASC = 'skin/training/6.VASC/'
validation_MEL = 'skin/validation/0.MEL/'
validation_NV = 'skin/validation/1.NV/'
validation_BCC = 'skin/validation/2.BCC/'
validation_AKIEC = 'skin/validation/3.AKIEC/'
validation_BKL = 'skin/validation/4.BKL/'
validation_DF = 'skin/validation/5.DF/'
validation_VASC = 'skin/validation/6.VASC/'

# %%
part1 = "data/HAM10000_images_part_1"
part2 = "data/HAM10000_images_part_2"

for part in [part1,part2]:
    for img in tqdm(os.listdir(part)):
        copyfile(os.path.join(part, img), os.path.join('HAM10000', img))

# %%
data
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
data.columns
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization'], dtype='object')

# %%
len(data)
# Out:
# 10015

# %%
# drop all duplicate photos by lesion_id to make all our photos iid (independant and identically distributed), 
# so that we wont overfit

data = data.drop_duplicates(subset='lesion_id')

# %%
len(data)
# Out:
# 7470

# %%
image_names = [x for x in data['image_id']]
diagnosis = [x for x in data['dx']]

# %%
print(len(image_names))
print(len(diagnosis))
# Out:
# 7470
# 7470

# %%
print(image_names[0])
print(diagnosis[0])
# Out:
# ISIC_0027419
# bkl

# %%
pd.unique(data['dx'])
# Out:
# array(['bkl', 'nv', 'df', 'mel', 'vasc', 'bcc', 'akiec'], dtype=object)

# %% [markdown]
# # Copy image to their particular locations

# %%
for index, image in tqdm(enumerate(image_names)):
    image = image + '.jpg'
    if diagnosis[index] == 'mel':
        copyfile(os.path.join(orig_all, image), os.path.join(source_MEL, image))
    elif diagnosis[index] == 'nv':
        copyfile(os.path.join(orig_all, image), os.path.join(source_NV, image))
    elif diagnosis[index] == 'bcc': 
        copyfile(os.path.join(orig_all, image), os.path.join(source_BCC, image))
    elif diagnosis[index] == 'akiec': 
        copyfile(os.path.join(orig_all, image), os.path.join(source_AKIEC, image))
    elif diagnosis[index] == 'bkl':
        copyfile(os.path.join(orig_all, image), os.path.join(source_BKL, image))
    elif diagnosis[index] == 'df':  
        copyfile(os.path.join(orig_all, image), os.path.join(source_DF, image))
    elif diagnosis[index] == 'vasc': 
        copyfile(os.path.join(orig_all, image), os.path.join(source_VASC, image))
# Out:
# 0it [00:00, ?it/s]

# %%
# Print amount of pictures for each class
print(len(os.listdir(source_MEL)))
print(len(os.listdir(source_NV)))
print(len(os.listdir(source_BCC)))
print(len(os.listdir(source_AKIEC)))
print(len(os.listdir(source_BKL)))
print(len(os.listdir(source_DF)))
print(len(os.listdir(source_VASC)))
# Out:
# 614
# 5403
# 327
# 228
# 727
# 73
# 98

# %%
# split each individual class of photos into train and val datasets 80/20%

split_size = 0.8
split_data(source_MEL, training_MEL, validation_MEL, split_size)
split_data(source_NV, training_NV, validation_NV, split_size)
split_data(source_BCC, training_BCC, validation_BCC, split_size)
split_data(source_AKIEC, training_AKIEC, validation_AKIEC, split_size)
split_data(source_BKL, training_BKL, validation_BKL, split_size)
split_data(source_DF, training_DF, validation_DF, split_size)
split_data(source_VASC, training_VASC, validation_VASC, split_size)

# %%
# Print amount of pictures for each class after split, train/val.
print(len(os.listdir(training_MEL)))
print(len(os.listdir(validation_MEL)))
print(len(os.listdir(training_NV)))
print(len(os.listdir(validation_NV)))
print(len(os.listdir(training_BCC)))
print(len(os.listdir(validation_BCC)))
print(len(os.listdir(training_AKIEC)))
print(len(os.listdir(validation_AKIEC)))
print(len(os.listdir(training_BKL)))
print(len(os.listdir(validation_BKL)))
print(len(os.listdir(training_DF)))
print(len(os.listdir(validation_DF)))
print(len(os.listdir(training_VASC)))
print(len(os.listdir(validation_VASC)))
# Out:
# 491
# 123
# 4322
# 1081
# 261
# 66
# 182
# 46
# 581
# 146
# 58
# 15
# 78
# 20

# %% [markdown]
# Inherent regularization of ResNet50 due to its Bottleneck layers and Batch normalization together with weight decay and random data augmentations is enough to prevent model from overfitting even on this imbalance dataset

# %%
traindir = r'skin/training/'
valdir = r'skin/validation/'

# %% [markdown]
# # challenging aspects:
# Dataset consists of 7470 unique skin neoplasm photos with height=450 and width=600 pixels.
# - After analyzing the images, I observed that in most cases, the skin neoplasm is positioned at the center and occupies the central 450x450 portion of the image, with only a few exceptions. Therefore, I conclude that there is no need to compress the photos along the width axis, which might result in the loss of important details, as our primary subject of interest is nearly always within the central crop. therefore for Resnet-50 to work, need to make it 240x240

# %% [markdown]
# # Data augmentation: a technique to increase the diversity in training set by applying random (but realistic) transformations

# %% [markdown]
# Resnet-50 requires input images to be of size 224 × 224
# we will first resize to 224x280 to avoid loss of info on width axis and then crop to 224x224 piece.
#
# Apply Random rotation and Horizontal/Vertical flipping. Since skin neoplasms can be in a lot of different shapes, by rotating and horizontally flipping them we will still get skin neoplasms that we would expect our model to classify correctly. These two transformations will help our model greatly. They will inflate our dataset, increase model robustness (especially since we have some classes with very small representation), help with better generalization and overfitting prevention.

# %%
train_transforms = transforms.Compose([
    transforms.Resize((224, 280)),
    transforms.CenterCrop((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomApply(transforms=[transforms.RandomRotation(degrees=(-180, 180))], p=0.99),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

val_transforms = transforms.Compose([
    transforms.Resize((224, 280)),
    torchvision.transforms.CenterCrop((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

train_dataset = datasets.ImageFolder(
    traindir, transform=train_transforms)

val_dataset = datasets.ImageFolder(
    valdir, transform=val_transforms)

# %%
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=64, shuffle=True,
    pin_memory=False, drop_last=False)

val_loader = torch.utils.data.DataLoader(
    val_dataset, batch_size=64, shuffle=True,
    pin_memory=False, drop_last=False)

# %%
print(val_dataset.class_to_idx)
print(train_dataset.class_to_idx)
# Out:
# {'0.MEL': 0, '1.NV': 1, '2.BCC': 2, '3.AKIEC': 3, '4.BKL': 4, '5.DF': 5, '6.VASC': 6}
# {'0.MEL': 0, '1.NV': 1, '2.BCC': 2, '3.AKIEC': 3, '4.BKL': 4, '5.DF': 5, '6.VASC': 6}

# %% [markdown]
# # resnet50 Model

# %%
device = 'cuda'

model = torchvision.models.resnet50(pretrained=True).to(device)

model.fc = nn.Linear(2048, 7).to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), weight_decay=0.0001)

epochs = 5 # 200 or 250 or 300

writer = SummaryWriter(log_dir='skin_logs/', filename_suffix="skin50")
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 265MB/s]

# %%
# Shows info about model
summary(model, input_size=(3, 224, 224))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            9,408
# ├─BatchNorm2d: 1-2                       128
# ├─ReLU: 1-3                              --
# ├─MaxPool2d: 1-4                         --
# ├─Sequential: 1-5                        --
# |    └─Bottleneck: 2-1                   --
# |    |    └─Conv2d: 3-1                  4,096
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Conv2d: 3-5                  16,384
# |    |    └─BatchNorm2d: 3-6             512
# |    |    └─ReLU: 3-7                    --
# |    |    └─Sequential: 3-8              16,896
# |    └─Bottleneck: 2-2                   --
# |    |    └─Conv2d: 3-9                  16,384
# |    |    └─BatchNorm2d: 3-10            128
# |    |    └─Conv2d: 3-11                 36,864
# |    |    └─BatchNorm2d: 3-12            128
# |    |    └─Conv2d: 3-13                 16,384
# |    |    └─BatchNorm2d: 3-14            512
# |    |    └─ReLU: 3-15                   --
# |    └─Bottleneck: 2-3                   --
# |    |    └─Conv2d: 3-16                 16,384
# |    |    └─BatchNorm2d: 3-17            128
# |    |    └─Conv2d: 3-18                 36,864
# |    |    └─BatchNorm2d: 3-19            128
# |    |    └─Conv2d: 3-20                 16,384
# |    |    └─BatchNorm2d: 3-21            512
# |    |    └─ReLU: 3-22                   --
# ├─Sequential: 1-6                        --
# |    └─Bottleneck: 2-4                   --
# |    |    └─Conv2d: 3-23                 32,768
# |    |    └─BatchNorm2d: 3-24            256
# |    |    └─Conv2d: 3-25                 147,456
# |    |    └─BatchNorm2d: 3-26            256
# |    |    └─Conv2d: 3-27                 65,536
# |    |    └─BatchNorm2d: 3-28            1,024
# |    |    └─ReLU: 3-29                   --
# |    |    └─Sequential: 3-30             132,096
# |    └─Bottleneck: 2-5                   --
# |    |    └─Conv2d: 3-31                 65,536
# |    |    └─BatchNorm2d: 3-32            256
# |    |    └─Conv2d: 3-33                 147,456
# |    |    └─BatchNorm2d: 3-34            256
# |    |    └─Conv2d: 3-35                 65,536
# |    |    └─BatchNorm2d: 3-36            1,024
# |    |    └─ReLU: 3-37                   --
# |    └─Bottleneck: 2-6                   --
# |    |    └─Conv2d: 3-38                 65,536
# |    |    └─BatchNorm2d: 3-39            256
# |    |    └─Conv2d: 3-40                 147,456
# |    |    └─BatchNorm2d: 3-41            256
# |    |    └─Conv2d: 3-42                 65,536
# |    |    └─BatchNorm2d: 3-43            1,024
# |    |    └─ReLU: 3-44                   --
# |    └─Bottleneck: 2-7                   --
# |    |    └─Conv2d: 3-45                 65,536
# |    |    └─BatchNorm2d: 3-46            256
# |    |    └─Conv2d: 3-47                 147,456
# |    |    └─BatchNorm2d: 3-48            256
# |    |    └─Conv2d: 3-49                 65,536
# |    |    └─BatchNorm2d: 3-50            1,024
# |    |    └─ReLU: 3-51                   --
# ├─Sequential: 1-7                        --
# |    └─Bottleneck: 2-8                   --
# |    |    └─Conv2d: 3-52                 131,072
# |    |    └─BatchNorm2d: 3-53            512
# |    |    └─Conv2d: 3-54                 589,824
# |    |    └─BatchNorm2d: 3-55            512
# |    |    └─Conv2d: 3-56                 262,144
# |    |    └─BatchNorm2d: 3-57            2,048
# |    |    └─ReLU: 3-58                   --
# |    |    └─Sequential: 3-59             526,336
# |    └─Bottleneck: 2-9                   --
# |    |    └─Conv2d: 3-60                 262,144
# |    |    └─BatchNorm2d: 3-61            512
# |    |    └─Conv2d: 3-62                 589,824
# |    |    └─BatchNorm2d: 3-63            512
# |    |    └─Conv2d: 3-64                 262,144
# |    |    └─BatchNorm2d: 3-65            2,048
# |    |    └─ReLU: 3-66                   --
# |    └─Bottleneck: 2-10                  --
# |    |    └─Conv2d: 3-67                 262,144
# |    |    └─BatchNorm2d: 3-68            512
# |    |    └─Conv2d: 3-69                 589,824
# |    |    └─BatchNorm2d: 3-70            512
# |    |    └─Conv2d: 3-71                 262,144
# |    |    └─BatchNorm2d: 3-72            2,048
# |    |    └─ReLU: 3-73                   --
# |    └─Bottleneck: 2-11                  --
# |    |    └─Conv2d: 3-74                 262,144
# |    |    └─BatchNorm2d: 3-75            512
# |    |    └─Conv2d: 3-76                 589,824
# |    |    └─BatchNorm2d: 3-77            512
# |    |    └─Conv2d: 3-78                 262,144
# |    |    └─BatchNorm2d: 3-79            2,048
# |    |    └─ReLU: 3-80                   --
# |    └─Bottleneck: 2-12                  --
# |    |    └─Conv2d: 3-81                 262,144
# |    |    └─BatchNorm2d: 3-82            512
# |    |    └─Conv2d: 3-83                 589,824
# |    |    └─BatchNorm2d: 3-84            512
# |    |    └─Conv2d: 3-85                 262,144
# |    |    └─BatchNorm2d: 3-86            2,048
# |    |    └─ReLU: 3-87                   --
# |    └─Bottleneck: 2-13                  --
# |    |    └─Conv2d: 3-88                 262,144
# |    |    └─BatchNorm2d: 3-89            512
# |    |    └─Conv2d: 3-90                 589,824
# |    |    └─BatchNorm2d: 3-91            512
# |    |    └─Conv2d: 3-92                 262,144
# |    |    └─BatchNorm2d: 3-93            2,048
# |    |    └─ReLU: 3-94                   --
# ├─Sequential: 1-8                        --
# |    └─Bottleneck: 2-14                  --
# |    |    └─Conv2d: 3-95                 524,288
# |    |    └─BatchNorm2d: 3-96            1,024
# |    |    └─Conv2d: 3-97                 2,359,296
# |    |    └─BatchNorm2d: 3-98            1,024
# |    |    └─Conv2d: 3-99                 1,048,576
# |    |    └─BatchNorm2d: 3-100           4,096
# |    |    └─ReLU: 3-101                  --
# |    |    └─Sequential: 3-102            2,101,248
# |    └─Bottleneck: 2-15                  --
# |    |    └─Conv2d: 3-103                1,048,576
# |    |    └─BatchNorm2d: 3-104           1,024
# |    |    └─Conv2d: 3-105                2,359,296
# |    |    └─BatchNorm2d: 3-106           1,024
# |    |    └─Conv2d: 3-107                1,048,576
# |    |    └─BatchNorm2d: 3-108           4,096
# |    |    └─ReLU: 3-109                  --
# |    └─Bottleneck: 2-16                  --
# |    |    └─Conv2d: 3-110                1,048,576
# |    |    └─BatchNorm2d: 3-111           1,024
# |    |    └─Conv2d: 3-112                2,359,296
# |    |    └─BatchNorm2d: 3-113           1,024
# |    |    └─Conv2d: 3-114                1,048,576
# |    |    └─BatchNorm2d: 3-115           4,096
# |    |    └─ReLU: 3-116                  --
# ├─AdaptiveAvgPool2d: 1-9                 --
# ├─Linear: 1-10                           14,343
# =================================================================
# Total params: 23,522,375
# Trainable params: 23,522,375
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            9,408
# ├─BatchNorm2d: 1-2                       128
# ├─ReLU: 1-3                              --
# ├─MaxPool2d: 1-4                         --
# ├─Sequential: 1-5                        --
# |    └─Bottleneck: 2-1                   --
# |    |    └─Conv2d: 3-1                  4,096
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Conv2d: 3-5                  16,384
# |    |    └─BatchNorm2d: 3-6             512
# |    |    └─ReLU: 3-7                    --
# |    |    └─Sequential: 3-8              16,896
# |    └─Bottleneck: 2-2                   --
# |    |    └─Conv2d: 3-9                  16,384
# |    |    └─BatchNorm2d: 3-10            128
# |    |    └─Conv2d: 3-11                 36,864
# |    |    └─BatchNorm2d: 3-12            128
# |    |    └─Conv2d: 3-13                 16,384
# |    |    └─BatchNorm2d: 3-14            512
# |    |    └─ReLU: 3-15                   --
# |    └─Bottleneck: 2-3                   --
# |    |    └─Conv2d: 3-16                 16,384
# |    |    └─BatchNorm2d: 3-17            128
# |    |    └─Conv2d: 3-18                 36,864
# |    |    └─BatchNorm2d: 3-19            128
# |    |    └─Conv2d: 3-20                 16,384
# |    |    └─BatchNorm2d: 3-21            512
# |    |    └─ReLU: 3-22                   --
# ├─Sequential: 1-6                        --
# |    └─Bottleneck: 2-4                   --
# |    |    └─Conv2d: 3-23                 32,768
# |    |    └─BatchNorm2d: 3-24            256
# |    |    └─Conv2d: 3-25                 147,456
# |    |    └─BatchNorm2d: 3-26            256
# |    |    └─Conv2d: 3-27                 65,536
# |    |    └─BatchNorm2d: 3-28            1,024
# |    |    └─ReLU: 3-29                   --
# |    |    └─Sequential: 3-30             132,096
# |    └─Bottleneck: 2-5                   --
# |    |    └─Conv2d: 3-31                 65,536
# |    |    └─BatchNorm2d: 3-32            256
# |    |    └─Conv2d: 3-33                 147,456
# |    |    └─BatchNorm2d: 3-34            256
# |    |    └─Conv2d: 3-35                 65,536
# |    |    └─BatchNorm2d: 3-36            1,024
# |    |    └─ReLU: 3-37                   --
# |    └─Bottleneck: 2-6                   --
# |    |    └─Conv2d: 3-38                 65,536
# |    |    └─BatchNorm2d: 3-39            256
# |    |    └─Conv2d: 3-40                 147,456
# |    |    └─BatchNorm2d: 3-41            256
# |    |    └─Conv2d: 3-42                 65,536
# |    |    └─BatchNorm2d: 3-43            1,024
# |    |    └─ReLU: 3-44                   --
# |    └─Bottleneck: 2-7                   --
# |    |    └─Conv2d: 3-45                 65,536
# |    |    └─BatchNorm2d: 3-46            256
# |    |    └─Conv2d: 3-47                 147,456
# |    |    └─BatchNorm2d: 3-48            256
# |    |    └─Conv2d: 3-49                 65,536
# |    |    └─BatchNorm2d: 3-50            1,024
# |    |    └─ReLU: 3-51                   --
# ├─Sequential: 1-7                        --
# |    └─Bottleneck: 2-8                   --
# |    |    └─Conv2d: 3-52                 131,072
# |    |    └─BatchNorm2d: 3-53            512
# |    |    └─Conv2d: 3-54                 589,824
# |    |    └─BatchNorm2d: 3-55            512
# |    |    └─Conv2d: 3-56                 262,144
# |    |    └─BatchNorm2d: 3-57            2,048
# |    |    └─ReLU: 3-58                   --
# |    |    └─Sequential: 3-59             526,336
# |    └─Bottleneck: 2-9                   --
# |    |    └─Conv2d: 3-60                 262,144
# |    |    └─BatchNorm2d: 3-61            512
# |    |    └─Conv2d: 3-62                 589,824
# |    |    └─BatchNorm2d: 3-63            512
# |    |    └─Conv2d: 3-64                 262,144
# |    |    └─BatchNorm2d: 3-65            2,048
# |    |    └─ReLU: 3-66                   --
# |    └─Bottleneck: 2-10                  --
# |    |    └─Conv2d: 3-67                 262,144
# |    |    └─BatchNorm2d: 3-68            512
# |    |    └─Conv2d: 3-69                 589,824
# |    |    └─BatchNorm2d: 3-70            512
# |    |    └─Conv2d: 3-71                 262,144
# |    |    └─BatchNorm2d: 3-72            2,048
# |    |    └─ReLU: 3-73                   --
# |    └─Bottleneck: 2-11                  --
# |    |    └─Conv2d: 3-74                 262,144
# |    |    └─BatchNorm2d: 3-75            512
# |    |    └─Conv2d: 3-76                 589,824
# |    |    └─BatchNorm2d: 3-77            512
# |    |    └─Conv2d: 3-78                 262,144
# |    |    └─BatchNorm2d: 3-79            2,048
# |    |    └─ReLU: 3-80                   --
# |    └─Bottleneck: 2-12                  --
# |    |    └─Conv2d: 3-81                 262,144
# |    |    └─BatchNorm2d: 3-82            512
# |    |    └─Conv2d: 3-83                 589,824
# |    |    └─BatchNorm2d: 3-84            512
# |    |    └─Conv2d: 3-85                 262,144
# |    |    └─BatchNorm2d: 3-86            2,048
# |    |    └─ReLU: 3-87                   --
# |    └─Bottleneck: 2-13                  --
# |    |    └─Conv2d: 3-88                 262,144
# |    |    └─BatchNorm2d: 3-89            512
# |    |    └─Conv2d: 3-90                 589,824
# |    |    └─BatchNorm2d: 3-91            512
# |    |    └─Conv2d: 3-92                 262,144
# |    |    └─BatchNorm2d: 3-93            2,048
# |    |    └─ReLU: 3-94                   --
# ├─Sequential: 1-8                        --
# |    └─Bottleneck: 2-14                  --
# |    |    └─Conv2d: 3-95                 524,288
# |    |    └─BatchNorm2d: 3-96            1,024
# |    |    └─Conv2d: 3-97                 2,359,296
# |    |    └─BatchNorm2d: 3-98            1,024
# |    |    └─Conv2d: 3-99                 1,048,576
# |    |    └─BatchNorm2d: 3-100           4,096
# |    |    └─ReLU: 3-101                  --
# |    |    └─Sequential: 3-102            2,101,248
# |    └─Bottleneck: 2-15                  --
# |    |    └─Conv2d: 3-103                1,048,576
# |    |    └─BatchNorm2d: 3-104           1,024
# |    |    └─Conv2d: 3-105                2,359,296
# |    |    └─BatchNorm2d: 3-106           1,024
# |    |    └─Conv2d: 3-107                1,048,576
# |    |    └─BatchNorm2d: 3-108           4,096
# |    |    └─ReLU: 3-109                  --
# |    └─Bottleneck: 2-16                  --
# |    |    └─Conv2d: 3-110                1,048,576
# |    |    └─BatchNorm2d: 3-111           1,024
# |    |    └─Conv2d: 3-112                2,359,296
# |    |    └─BatchNorm2d: 3-113           1,024
# |    |    └─Conv2d: 3-114                1,048,576
# |    |    └─BatchNorm2d: 3-115           4,096
# |    |    └─ReLU: 3-116                  --
# ├─AdaptiveAvgPool2d: 1-9                 --
# ├─Linear: 1-10                           14,343
# =================================================================
# Total params: 23,522,375
# Trainable params: 23,522,375
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# # Early stops the training if validation loss doesn't improve after a given patience

# %%
class EarlyStopping:
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when monitored metric decrease.'''
        if self.verbose:
            self.trace_func(f'Monitored metric has improved ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), f'skin_models/skinmodel50.pt') 
        self.val_loss_min = val_loss

# %% [markdown]
# # Model Training

# %%
early_stopping = EarlyStopping(patience=30, verbose=True)

for epoch in range(epochs):
    train_loss = 0.00
    val_loss = 0.00
    train_accuracy = Accuracy()
    val_accuracy = Accuracy()
    print(f'Epoch {epoch+1}')

    # Training loop
    for idx, (inputs, labels) in enumerate(Bar(train_loader)):
        model.train()
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad() 
        outputs = model(inputs) 
        loss = criterion(outputs, labels)
        loss.backward() 
        optimizer.step() 
        train_loss += loss.item()
        train_accuracy.update((nn.functional.softmax(outputs, dim=1), labels))
    print(f"Train Accuracy: {train_accuracy.compute()}")
    train_loss /= len(train_loader)
    train_loss_formated = "{:.4f}".format(train_loss)

    # Validation loop
    with torch.no_grad():
        for inputs, labels in val_loader:
            model.eval()           
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            val_accuracy.update((nn.functional.softmax(outputs, dim=1), labels))
    print(f"Val Accuracy: {val_accuracy.compute()}")
    val_loss /= len(val_loader)
    val_loss_formated = "{:.4f}".format(val_loss)
    print(f'Training Loss: {train_loss_formated}')
    print(f"Validation Loss: {val_loss_formated}")

    # TensorBoard writer 
    writer.add_scalar('Loss/train', train_loss, epoch+1)
    writer.add_scalar('Loss/val', val_loss, epoch+1)
    writer.add_scalar('Accuracy/train', train_accuracy.compute(), epoch+1)
    writer.add_scalar('Accuracy/val', val_accuracy.compute(), epoch+1)

    # Early Stopping
    early_stopping(val_loss, model)       
    if early_stopping.early_stop:
        print("Early stopping")
        break
        
# load the last checkpoint with the best model
model.load_state_dict(torch.load('skin_models/skinmodel50.pt'))
# Out:
# Epoch 1
# 5973/5973: [===============================>] - ETA 6.9s
# Train Accuracy: 0.7384898710865562
# Val Accuracy: 0.7501670006680027
# Training Loss: 0.7666
# Validation Loss: 0.7090
# Monitored metric has improved (inf --> 0.708956).  Saving model ...
# Epoch 2
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.7714716223003516
# Val Accuracy: 0.7401469605878424
# Training Loss: 0.6397
# Validation Loss: 0.7173
# EarlyStopping counter: 1 out of 50
# Epoch 3
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.7739829231541939
# Val Accuracy: 0.7768871075484302
# Training Loss: 0.6139
# Validation Loss: 0.6190
# Monitored metric has improved (0.708956 --> 0.619022).  Saving model ...
# Epoch 4
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.7841955466264858
# Val Accuracy: 0.7808951235804943
# Training Loss: 0.5881
# Validation Loss: 0.5921
# Monitored metric has improved (0.619022 --> 0.592073).  Saving model ...
# Epoch 5
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.7939059099280094
# Val Accuracy: 0.7535070140280561
# Training Loss: 0.5600
# Validation Loss: 0.7294
# EarlyStopping counter: 1 out of 50
# Epoch 6
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.7984262514649255
# Val Accuracy: 0.7775551102204409
# Training Loss: 0.5621
# Validation Loss: 0.6492
# EarlyStopping counter: 2 out of 50
# Epoch 7
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8021094927172275
# Val Accuracy: 0.7922511690046761
# Training Loss: 0.5425
# Validation Loss: 0.5630
# Monitored metric has improved (0.592073 --> 0.562964).  Saving model ...
# Epoch 8
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8031140130587644
# Val Accuracy: 0.790247160988644
# Training Loss: 0.5367
# Validation Loss: 0.5793
# EarlyStopping counter: 1 out of 50
# Epoch 9
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.8088062949941403
# Val Accuracy: 0.8042752171008684
# Training Loss: 0.5252
# Validation Loss: 0.4909
# Monitored metric has improved (0.562964 --> 0.490914).  Saving model ...
# Epoch 10
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8111501757910597
# Val Accuracy: 0.7808951235804943
# Training Loss: 0.5118
# Validation Loss: 0.6725
# EarlyStopping counter: 1 out of 50
# Epoch 11
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8148334170433618
# Val Accuracy: 0.811623246492986
# Training Loss: 0.5010
# Validation Loss: 0.5027
# EarlyStopping counter: 2 out of 50
# Epoch 12
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8158379373848987
# Val Accuracy: 0.8042752171008684
# Training Loss: 0.4932
# Validation Loss: 0.5179
# EarlyStopping counter: 3 out of 50
# Epoch 13
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8195211786372008
# Val Accuracy: 0.7702070808283233
# Training Loss: 0.4918
# Validation Loss: 0.6736
# EarlyStopping counter: 4 out of 50
# Epoch 14
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8156705173279759
# Val Accuracy: 0.7688710754843019
# Training Loss: 0.4961
# Validation Loss: 0.6653
# EarlyStopping counter: 5 out of 50
# Epoch 15
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.8156705173279759
# Val Accuracy: 0.7915831663326653
# Training Loss: 0.4953
# Validation Loss: 0.5674
# EarlyStopping counter: 6 out of 50
# Epoch 16
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8173447178972041
# Val Accuracy: 0.7835671342685371
# Training Loss: 0.4824
# Validation Loss: 0.5694
# EarlyStopping counter: 7 out of 50
# Epoch 17
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.8242089402310396
# Val Accuracy: 0.7535070140280561
# Training Loss: 0.4762
# Validation Loss: 0.7631
# EarlyStopping counter: 8 out of 50
# Epoch 18
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8220324794910431
# Val Accuracy: 0.8129592518370073
# Training Loss: 0.4767
# Validation Loss: 0.4940
# EarlyStopping counter: 9 out of 50
# Epoch 19
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8302360622802611
# Val Accuracy: 0.8256513026052105
# Training Loss: 0.4578
# Validation Loss: 0.4522
# Monitored metric has improved (0.490914 --> 0.452248).  Saving model ...
# Epoch 20
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8280596015402645
# Val Accuracy: 0.8256513026052105
# Training Loss: 0.4537
# Validation Loss: 0.4710
# EarlyStopping counter: 1 out of 50
# Epoch 21
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.832245102963335
# Val Accuracy: 0.8209752839011356
# Training Loss: 0.4467
# Validation Loss: 0.4574
# EarlyStopping counter: 2 out of 50
# Epoch 22
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.8404486857525532
# Val Accuracy: 0.8183032732130928
# Training Loss: 0.4426
# Validation Loss: 0.5148
# EarlyStopping counter: 3 out of 50
# Epoch 23
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8360957642725598
# Val Accuracy: 0.8289913159652639
# Training Loss: 0.4444
# Validation Loss: 0.4568
# EarlyStopping counter: 4 out of 50
# Epoch 24
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.8342541436464088
# Val Accuracy: 0.8203072812291249
# Training Loss: 0.4403
# Validation Loss: 0.4932
# EarlyStopping counter: 5 out of 50
# Epoch 25
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.8379373848987108
# Val Accuracy: 0.8216432865731463
# Training Loss: 0.4335
# Validation Loss: 0.4422
# Monitored metric has improved (0.452248 --> 0.442171).  Saving model ...
# Epoch 26
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8342541436464088
# Val Accuracy: 0.8169672678690715
# Training Loss: 0.4398
# Validation Loss: 0.4799
# EarlyStopping counter: 1 out of 50
# Epoch 27
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.834086723589486
# Val Accuracy: 0.8263193052772211
# Training Loss: 0.4367
# Validation Loss: 0.4675
# EarlyStopping counter: 2 out of 50
# Epoch 28
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.8407835258663988
# Val Accuracy: 0.7942551770207081
# Training Loss: 0.4236
# Validation Loss: 0.5335
# EarlyStopping counter: 3 out of 50
# Epoch 29
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.8449690272894693
# Val Accuracy: 0.802939211756847
# Training Loss: 0.4216
# Validation Loss: 0.5355
# EarlyStopping counter: 4 out of 50
# Epoch 30
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.8484848484848485
# Val Accuracy: 0.8396793587174348
# Training Loss: 0.4113
# Validation Loss: 0.4130
# Monitored metric has improved (0.442171 --> 0.413015).  Saving model ...
# Epoch 31
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8496567888833082
# Val Accuracy: 0.8343353373413493
# Training Loss: 0.4062
# Validation Loss: 0.4587
# EarlyStopping counter: 1 out of 50
# Epoch 32
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.846140967687929
# Val Accuracy: 0.8350033400133601
# Training Loss: 0.4177
# Validation Loss: 0.4258
# EarlyStopping counter: 2 out of 50
# Epoch 33
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8459735476310062
# Val Accuracy: 0.85437541750167
# Training Loss: 0.4006
# Validation Loss: 0.4197
# EarlyStopping counter: 3 out of 50
# Epoch 34
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.8523355097940734
# Val Accuracy: 0.8002672010688042
# Training Loss: 0.3923
# Validation Loss: 0.6057
# EarlyStopping counter: 4 out of 50
# Epoch 35
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8615436129248284
# Val Accuracy: 0.8082832331329325
# Training Loss: 0.3863
# Validation Loss: 0.5146
# EarlyStopping counter: 5 out of 50
# Epoch 36
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.8561861711032982
# Val Accuracy: 0.8283233132932531
# Training Loss: 0.3909
# Validation Loss: 0.4825
# EarlyStopping counter: 6 out of 50
# Epoch 37
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8593671521848317
# Val Accuracy: 0.8370073480293921
# Training Loss: 0.3884
# Validation Loss: 0.4233
# EarlyStopping counter: 7 out of 50
# Epoch 38
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.8580277917294492
# Val Accuracy: 0.8570474281897128
# Training Loss: 0.3770
# Validation Loss: 0.4134
# EarlyStopping counter: 8 out of 50
# Epoch 39
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8576929516156035
# Val Accuracy: 0.8443553774215097
# Training Loss: 0.3750
# Validation Loss: 0.4334
# EarlyStopping counter: 9 out of 50
# Epoch 40
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8630503934371337
# Val Accuracy: 0.8476953907815631
# Training Loss: 0.3730
# Validation Loss: 0.4104
# Monitored metric has improved (0.413015 --> 0.410384).  Saving model ...
# Epoch 41
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.855349070818684
# Val Accuracy: 0.8496993987975952
# Training Loss: 0.3876
# Validation Loss: 0.3770
# Monitored metric has improved (0.410384 --> 0.376978).  Saving model ...
# Epoch 42
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8590323120709861
# Val Accuracy: 0.8523714094856379
# Training Loss: 0.3687
# Validation Loss: 0.3986
# EarlyStopping counter: 1 out of 50
# Epoch 43
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.8580277917294492
# Val Accuracy: 0.8663994655978624
# Training Loss: 0.3703
# Validation Loss: 0.3634
# Monitored metric has improved (0.376978 --> 0.363407).  Saving model ...
# Epoch 44
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.8637200736648251
# Val Accuracy: 0.8583834335337341
# Training Loss: 0.3675
# Validation Loss: 0.3634
# Monitored metric has improved (0.363407 --> 0.363395).  Saving model ...
# Epoch 45
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.8625481332663653
# Val Accuracy: 0.8416833667334669
# Training Loss: 0.3616
# Validation Loss: 0.4053
# EarlyStopping counter: 1 out of 50
# Epoch 46
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.8632178134940566
# Val Accuracy: 0.8677354709418837
# Training Loss: 0.3610
# Validation Loss: 0.3503
# Monitored metric has improved (0.363395 --> 0.350348).  Saving model ...
# Epoch 47
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8715888163401976
# Val Accuracy: 0.8690714762859052
# Training Loss: 0.3481
# Validation Loss: 0.3586
# EarlyStopping counter: 1 out of 50
# Epoch 48
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.870249455884815
# Val Accuracy: 0.875751503006012
# Training Loss: 0.3395
# Validation Loss: 0.3397
# Monitored metric has improved (0.350348 --> 0.339702).  Saving model ...
# Epoch 49
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.8772810982755734
# Val Accuracy: 0.8370073480293921
# Training Loss: 0.3403
# Validation Loss: 0.4233
# EarlyStopping counter: 1 out of 50
# Epoch 50
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.8685752553155868
# Val Accuracy: 0.863059452237809
# Training Loss: 0.3420
# Validation Loss: 0.3639
# EarlyStopping counter: 2 out of 50
# Epoch 51
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.8714213962832748
# Val Accuracy: 0.8590514362057449
# Training Loss: 0.3463
# Validation Loss: 0.3645
# EarlyStopping counter: 3 out of 50
# Epoch 52
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8735978570232714
# Val Accuracy: 0.8724114896459586
# Training Loss: 0.3382
# Validation Loss: 0.3304
# Monitored metric has improved (0.339702 --> 0.330407).  Saving model ...
# Epoch 53
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.8771136782186506
# Val Accuracy: 0.8777555110220441
# Training Loss: 0.3284
# Validation Loss: 0.3038
# Monitored metric has improved (0.330407 --> 0.303826).  Saving model ...
# Epoch 54
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8771136782186506
# Val Accuracy: 0.8430193720774883
# Training Loss: 0.3154
# Validation Loss: 0.4368
# EarlyStopping counter: 1 out of 50
# Epoch 55
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.8730955968525029
# Val Accuracy: 0.8136272545090181
# Training Loss: 0.3344
# Validation Loss: 0.5630
# EarlyStopping counter: 2 out of 50
# Epoch 56
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.8734304369663486
# Val Accuracy: 0.8897795591182365
# Training Loss: 0.3249
# Validation Loss: 0.2821
# Monitored metric has improved (0.303826 --> 0.282121).  Saving model ...
# Epoch 57
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.8856521011217143
# Val Accuracy: 0.8570474281897128
# Training Loss: 0.3005
# Validation Loss: 0.3652
# EarlyStopping counter: 1 out of 50
# Epoch 58
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.883308220324795
# Val Accuracy: 0.8643954575818303
# Training Loss: 0.3158
# Validation Loss: 0.3627
# EarlyStopping counter: 2 out of 50
# Epoch 59
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.885149840950946
# Val Accuracy: 0.8383433533734135
# Training Loss: 0.3096
# Validation Loss: 0.4599
# EarlyStopping counter: 3 out of 50
# Epoch 60
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.8826385400971036
# Val Accuracy: 0.8570474281897128
# Training Loss: 0.3092
# Validation Loss: 0.3884
# EarlyStopping counter: 4 out of 50
# Epoch 61
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.8863217813494056
# Val Accuracy: 0.8724114896459586
# Training Loss: 0.3006
# Validation Loss: 0.3250
# EarlyStopping counter: 5 out of 50
# Epoch 62
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.8844801607232546
# Val Accuracy: 0.8663994655978624
# Training Loss: 0.3025
# Validation Loss: 0.3228
# EarlyStopping counter: 6 out of 50
# Epoch 63
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8864892014063285
# Val Accuracy: 0.8897795591182365
# Training Loss: 0.2975
# Validation Loss: 0.2982
# EarlyStopping counter: 7 out of 50
# Epoch 64
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.8794575590155701
# Val Accuracy: 0.8837675350701403
# Training Loss: 0.3022
# Validation Loss: 0.3135
# EarlyStopping counter: 8 out of 50
# Epoch 65
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.890674702829399
# Val Accuracy: 0.8824315297261189
# Training Loss: 0.2874
# Validation Loss: 0.3204
# EarlyStopping counter: 9 out of 50
# Epoch 66
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8864892014063285
# Val Accuracy: 0.8871075484301937
# Training Loss: 0.3006
# Validation Loss: 0.2955
# EarlyStopping counter: 10 out of 50
# Epoch 67
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8955298844801607
# Val Accuracy: 0.8997995991983968
# Training Loss: 0.2713
# Validation Loss: 0.2803
# Monitored metric has improved (0.282121 --> 0.280335).  Saving model ...
# Epoch 68
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8950276243093923
# Val Accuracy: 0.8777555110220441
# Training Loss: 0.2786
# Validation Loss: 0.3171
# EarlyStopping counter: 1 out of 50
# Epoch 69
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.8938556839109325
# Val Accuracy: 0.8904475617902472
# Training Loss: 0.2777
# Validation Loss: 0.2902
# EarlyStopping counter: 2 out of 50
# Epoch 70
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.8995479658463084
# Val Accuracy: 0.8851035404141616
# Training Loss: 0.2677
# Validation Loss: 0.2888
# EarlyStopping counter: 3 out of 50
# Epoch 71
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.895195044366315
# Val Accuracy: 0.8917835671342685
# Training Loss: 0.2733
# Validation Loss: 0.2996
# EarlyStopping counter: 4 out of 50
# Epoch 72
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.895195044366315
# Val Accuracy: 0.875751503006012
# Training Loss: 0.2759
# Validation Loss: 0.3644
# EarlyStopping counter: 5 out of 50
# Epoch 73
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9000502260170768
# Val Accuracy: 0.884435537742151
# Training Loss: 0.2618
# Validation Loss: 0.2844
# EarlyStopping counter: 6 out of 50
# Epoch 74
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9018918466432279
# Val Accuracy: 0.9011356045424181
# Training Loss: 0.2556
# Validation Loss: 0.2588
# Monitored metric has improved (0.280335 --> 0.258812).  Saving model ...
# Epoch 75
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9310229365477984
# Val Accuracy: 0.9305277221108884
# Training Loss: 0.1822
# Validation Loss: 0.1823
# EarlyStopping counter: 11 out of 50
# Epoch 113
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9268374351247279
# Val Accuracy: 0.9298597194388778
# Training Loss: 0.1858
# Validation Loss: 0.1742
# EarlyStopping counter: 12 out of 50
# Epoch 114
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9300184162062615
# Val Accuracy: 0.9198396793587175
# Training Loss: 0.1792
# Validation Loss: 0.2117
# EarlyStopping counter: 13 out of 50
# Epoch 115
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9300184162062615
# Val Accuracy: 0.884435537742151
# Training Loss: 0.1913
# Validation Loss: 0.3323
# EarlyStopping counter: 14 out of 50
# Epoch 116
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9347061778001005
# Val Accuracy: 0.9198396793587175
# Training Loss: 0.1761
# Validation Loss: 0.2042
# EarlyStopping counter: 15 out of 50
# Epoch 117
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9320274568893353
# Val Accuracy: 0.8797595190380761
# Training Loss: 0.1779
# Validation Loss: 0.3247
# EarlyStopping counter: 16 out of 50
# Epoch 118
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9372174786539428
# Val Accuracy: 0.9198396793587175
# Training Loss: 0.1603
# Validation Loss: 0.2028
# EarlyStopping counter: 17 out of 50
# Epoch 119
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9419052402477817
# Val Accuracy: 0.9452237808951236
# Training Loss: 0.1643
# Validation Loss: 0.1331
# Monitored metric has improved (0.162618 --> 0.133089).  Saving model ...
# Epoch 120
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9420726603047045
# Val Accuracy: 0.8964595858383434
# Training Loss: 0.1528
# Validation Loss: 0.3253
# EarlyStopping counter: 1 out of 50
# Epoch 121
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9372174786539428
# Val Accuracy: 0.9231796927187709
# Training Loss: 0.1557
# Validation Loss: 0.1982
# EarlyStopping counter: 2 out of 50
# Epoch 122
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9375523187677883
# Val Accuracy: 0.957247828991316
# Training Loss: 0.1642
# Validation Loss: 0.1199
# Monitored metric has improved (0.133089 --> 0.119900).  Saving model ...
# Epoch 123
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.9417378201908588
# Val Accuracy: 0.9432197728790915
# Training Loss: 0.1600
# Validation Loss: 0.1545
# EarlyStopping counter: 1 out of 50
# Epoch 124
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.939728779507785
# Val Accuracy: 0.9412157648630595
# Training Loss: 0.1509
# Validation Loss: 0.1529
# EarlyStopping counter: 2 out of 50
# Epoch 125
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9296835760924159
# Val Accuracy: 0.9318637274549099
# Training Loss: 0.1840
# Validation Loss: 0.1787
# EarlyStopping counter: 3 out of 50
# Epoch 126
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9417378201908588
# Val Accuracy: 0.9478957915831663
# Training Loss: 0.1426
# Validation Loss: 0.1355
# EarlyStopping counter: 4 out of 50
# Epoch 127
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9447513812154696
# Val Accuracy: 0.9552438209752839
# Training Loss: 0.1455
# Validation Loss: 0.1295
# EarlyStopping counter: 5 out of 50
# Epoch 128
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9487694625816173
# Val Accuracy: 0.8957915831663327
# Training Loss: 0.1386
# Validation Loss: 0.3346
# EarlyStopping counter: 6 out of 50
# Epoch 129
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.9445839611585468
# Val Accuracy: 0.9565798263193053
# Training Loss: 0.1485
# Validation Loss: 0.1195
# Monitored metric has improved (0.119900 --> 0.119456).  Saving model ...
# Epoch 130
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9395613594508622
# Val Accuracy: 0.9418837675350702
# Training Loss: 0.1562
# Validation Loss: 0.1621
# EarlyStopping counter: 1 out of 50
# Epoch 131
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9398961995647078
# Val Accuracy: 0.9452237808951236
# Training Loss: 0.1540
# Validation Loss: 0.1487
# EarlyStopping counter: 2 out of 50
# Epoch 132
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9455884815000837
# Val Accuracy: 0.9352037408149633
# Training Loss: 0.1417
# Validation Loss: 0.1708
# EarlyStopping counter: 3 out of 50
# Epoch 133
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9501088230369998
# Val Accuracy: 0.9392117568470274
# Training Loss: 0.1359
# Validation Loss: 0.1739
# EarlyStopping counter: 4 out of 50
# Epoch 134
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9427423405323958
# Val Accuracy: 0.9231796927187709
# Training Loss: 0.1477
# Validation Loss: 0.2026
# EarlyStopping counter: 5 out of 50
# Epoch 135
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.944416541101624
# Val Accuracy: 0.9392117568470274
# Training Loss: 0.1415
# Validation Loss: 0.1552
# EarlyStopping counter: 6 out of 50
# Epoch 136
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9486020425246945
# Val Accuracy: 0.8750835003340013
# Training Loss: 0.1442
# Validation Loss: 0.4892
# EarlyStopping counter: 7 out of 50
# Epoch 137
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9541269044031475
# Val Accuracy: 0.9565798263193053
# Training Loss: 0.1206
# Validation Loss: 0.1129
# Monitored metric has improved (0.119456 --> 0.112864).  Saving model ...
# Epoch 138
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9507785032646912
# Val Accuracy: 0.9111556446225785
# Training Loss: 0.1330
# Validation Loss: 0.2961
# EarlyStopping counter: 1 out of 50
# Epoch 139
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9464255817846978
# Val Accuracy: 0.9619238476953907
# Training Loss: 0.1413
# Validation Loss: 0.1093
# Monitored metric has improved (0.112864 --> 0.109252).  Saving model ...
# Epoch 140
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9576427255985267
# Val Accuracy: 0.9345357381429525
# Training Loss: 0.1168
# Validation Loss: 0.1765
# EarlyStopping counter: 1 out of 50
# Epoch 141
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9477649422400803
# Val Accuracy: 0.9111556446225785
# Training Loss: 0.1378
# Validation Loss: 0.2342
# EarlyStopping counter: 2 out of 50
# Epoch 142
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9445839611585468
# Val Accuracy: 0.9291917167668671
# Training Loss: 0.1476
# Validation Loss: 0.1813
# EarlyStopping counter: 3 out of 50
# Epoch 143
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9400636196216307
# Val Accuracy: 0.9318637274549099
# Training Loss: 0.1657
# Validation Loss: 0.1922
# EarlyStopping counter: 4 out of 50
# Epoch 144
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.951783023606228
# Val Accuracy: 0.9632598530394122
# Training Loss: 0.1318
# Validation Loss: 0.1100
# EarlyStopping counter: 5 out of 50
# Epoch 145
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.9576427255985267
# Val Accuracy: 0.9345357381429525
# Training Loss: 0.1135
# Validation Loss: 0.1571
# EarlyStopping counter: 6 out of 50
# Epoch 146
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9584798258831408
# Val Accuracy: 0.9539078156312625
# Training Loss: 0.1125
# Validation Loss: 0.1276
# EarlyStopping counter: 7 out of 50
# Epoch 147
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9465930018416207
# Val Accuracy: 0.9625918503674015
# Training Loss: 0.1486
# Validation Loss: 0.1079
# Monitored metric has improved (0.109252 --> 0.107908).  Saving model ...
# Epoch 148
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.9432446007031643
# Val Accuracy: 0.9198396793587175
# Training Loss: 0.1474
# Validation Loss: 0.2160
# EarlyStopping counter: 1 out of 50
# Epoch 149
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9609911267369831
# Val Accuracy: 0.9452237808951236
# Training Loss: 0.1041
# Validation Loss: 0.1601
# EarlyStopping counter: 1 out of 50
# Epoch 169
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9616608069646744
# Val Accuracy: 0.9665998663994656
# Training Loss: 0.1003
# Validation Loss: 0.0863
# Monitored metric has improved (0.087714 --> 0.086294).  Saving model ...
# Epoch 170
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9676879290138959
# Val Accuracy: 0.9759519038076152
# Training Loss: 0.0884
# Validation Loss: 0.0594
# Monitored metric has improved (0.086294 --> 0.059385).  Saving model ...
# Epoch 171
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.9636698476477482
# Val Accuracy: 0.9612558450233801
# Training Loss: 0.0967
# Validation Loss: 0.1106
# EarlyStopping counter: 1 out of 50
# Epoch 172
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9589820860539092
# Val Accuracy: 0.9498997995991983
# Training Loss: 0.1136
# Validation Loss: 0.1607
# EarlyStopping counter: 2 out of 50
# Epoch 173
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.9624979072492885
# Val Accuracy: 0.9465597862391449
# Training Loss: 0.1013
# Validation Loss: 0.1253
# EarlyStopping counter: 3 out of 50
# Epoch 174
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9695295496400469
# Val Accuracy: 0.9438877755511023
# Training Loss: 0.0889
# Validation Loss: 0.1425
# EarlyStopping counter: 4 out of 50
# Epoch 175
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9640046877615939
# Val Accuracy: 0.9011356045424181
# Training Loss: 0.0951
# Validation Loss: 0.3886
# EarlyStopping counter: 5 out of 50
# Epoch 176
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9701992298677381
# Val Accuracy: 0.9385437541750167
# Training Loss: 0.0906
# Validation Loss: 0.2097
# EarlyStopping counter: 6 out of 50
# Epoch 177
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9666834086723589
# Val Accuracy: 0.9552438209752839
# Training Loss: 0.0954
# Validation Loss: 0.1288
# EarlyStopping counter: 7 out of 50
# Epoch 178
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9675205089569731
# Val Accuracy: 0.9632598530394122
# Training Loss: 0.0832
# Validation Loss: 0.0917
# EarlyStopping counter: 8 out of 50
# Epoch 179
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.965678888330822
# Val Accuracy: 0.9378757515030061
# Training Loss: 0.0987
# Validation Loss: 0.2078
# EarlyStopping counter: 9 out of 50
# Epoch 180
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9618282270215972
# Val Accuracy: 0.9605878423513694
# Training Loss: 0.1063
# Validation Loss: 0.1185
# EarlyStopping counter: 10 out of 50
# Epoch 181
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9681901891846644
# Val Accuracy: 0.9565798263193053
# Training Loss: 0.0859
# Validation Loss: 0.1313
# EarlyStopping counter: 11 out of 50
# Epoch 182
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9626653273062112
# Val Accuracy: 0.9452237808951236
# Training Loss: 0.1001
# Validation Loss: 0.1246
# EarlyStopping counter: 12 out of 50
# Epoch 183
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9645069479323622
# Val Accuracy: 0.9752839011356046
# Training Loss: 0.1016
# Validation Loss: 0.0683
# EarlyStopping counter: 13 out of 50
# Epoch 184
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9624979072492885
# Val Accuracy: 0.9665998663994656
# Training Loss: 0.0956
# Validation Loss: 0.0820
# EarlyStopping counter: 14 out of 50
# Epoch 185
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9683576092415871
# Val Accuracy: 0.9639278557114228
# Training Loss: 0.0884
# Validation Loss: 0.0975
# EarlyStopping counter: 15 out of 50
# Epoch 186
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9589820860539092
# Val Accuracy: 0.9405477621910487
# Training Loss: 0.1098
# Validation Loss: 0.1691
# EarlyStopping counter: 16 out of 50
# Epoch 187
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9621630671354429
# Val Accuracy: 0.9378757515030061
# Training Loss: 0.1114
# Validation Loss: 0.1901
# EarlyStopping counter: 17 out of 50
# Epoch 188
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.957307885484681
# Val Accuracy: 0.978623914495658
# Training Loss: 0.1217
# Validation Loss: 0.0678
# EarlyStopping counter: 18 out of 50
# Epoch 189
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.965678888330822
# Val Accuracy: 0.9625918503674015
# Training Loss: 0.0922
# Validation Loss: 0.1063
# EarlyStopping counter: 19 out of 50
# Epoch 190
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9686924493554327
# Val Accuracy: 0.9772879091516367
# Training Loss: 0.0922
# Validation Loss: 0.0578
# Monitored metric has improved (0.059385 --> 0.057765).  Saving model ...
# Epoch 191
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9611585467939059
# Val Accuracy: 0.9325317301269205
# Training Loss: 0.1086
# Validation Loss: 0.1903
# EarlyStopping counter: 1 out of 50
# Epoch 192
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.9675205089569731
# Val Accuracy: 0.9665998663994656
# Training Loss: 0.0903
# Validation Loss: 0.0853
# EarlyStopping counter: 2 out of 50
# Epoch 193
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9703666499246609
# Val Accuracy: 0.9686038744154977
# Training Loss: 0.0861
# Validation Loss: 0.0845
# EarlyStopping counter: 3 out of 50
# Epoch 194
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9718734304369664
# Val Accuracy: 0.9832999331997327
# Training Loss: 0.0798
# Validation Loss: 0.0442
# Monitored metric has improved (0.057765 --> 0.044210).  Saving model ...
# Epoch 195
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.9730453708354261
# Val Accuracy: 0.9826319305277221
# Training Loss: 0.0738
# Validation Loss: 0.0499
# EarlyStopping counter: 1 out of 50
# Epoch 196
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9676879290138959
# Val Accuracy: 0.9452237808951236
# Training Loss: 0.0951
# Validation Loss: 0.1621
# EarlyStopping counter: 2 out of 50
# Epoch 197
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9606562866231374
# Val Accuracy: 0.9545758183032732
# Training Loss: 0.1027
# Validation Loss: 0.1112
# EarlyStopping counter: 3 out of 50
# Epoch 198
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9651766281600536
# Val Accuracy: 0.9759519038076152
# Training Loss: 0.0999
# Validation Loss: 0.0592
# EarlyStopping counter: 4 out of 50
# Epoch 199
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9708689100954294
# Val Accuracy: 0.9519038076152304
# Training Loss: 0.0918
# Validation Loss: 0.1494
# EarlyStopping counter: 5 out of 50
# Epoch 200
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9658463083877449
# Val Accuracy: 0.9498997995991983
# Training Loss: 0.0941
# Validation Loss: 0.1559
# EarlyStopping counter: 6 out of 50
# Epoch 201
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9676879290138959
# Val Accuracy: 0.9832999331997327
# Training Loss: 0.0915
# Validation Loss: 0.0457
# EarlyStopping counter: 7 out of 50
# Epoch 202
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9753892516323456
# Val Accuracy: 0.9779559118236473
# Training Loss: 0.0691
# Validation Loss: 0.0646
# EarlyStopping counter: 8 out of 50
# Epoch 203
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9707014900385066
# Val Accuracy: 0.9565798263193053
# Training Loss: 0.0795
# Validation Loss: 0.1158
# EarlyStopping counter: 9 out of 50
# Epoch 204
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9722082705508119
# Val Accuracy: 0.9679358717434869
# Training Loss: 0.0794
# Validation Loss: 0.0812
# EarlyStopping counter: 10 out of 50
# Epoch 205
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9693621295831241
# Val Accuracy: 0.9218436873747495
# Training Loss: 0.0806
# Validation Loss: 0.2511
# EarlyStopping counter: 11 out of 50
# Epoch 206
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9790724928846476
# Val Accuracy: 0.9812959251837008
# Training Loss: 0.0579
# Validation Loss: 0.0586
# EarlyStopping counter: 25 out of 50
# Epoch 244
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9802444332831073
# Val Accuracy: 0.9752839011356046
# Training Loss: 0.0579
# Validation Loss: 0.0586
# EarlyStopping counter: 26 out of 50
# Epoch 245
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9730453708354261
# Val Accuracy: 0.9766199064796259
# Training Loss: 0.0765
# Validation Loss: 0.0539
# EarlyStopping counter: 27 out of 50
# Epoch 246
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9732127908923489
# Val Accuracy: 0.9719438877755511
# Training Loss: 0.0757
# Validation Loss: 0.0786
# EarlyStopping counter: 28 out of 50
# Epoch 247
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9775657123723422
# Val Accuracy: 0.9873079492317969
# Training Loss: 0.0638
# Validation Loss: 0.0358
# EarlyStopping counter: 29 out of 50
# Epoch 248
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9713711702661979
# Val Accuracy: 0.9772879091516367
# Training Loss: 0.0833
# Validation Loss: 0.0704
# EarlyStopping counter: 30 out of 50
# Epoch 249
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9762263519169596
# Val Accuracy: 0.9452237808951236
# Training Loss: 0.0710
# Validation Loss: 0.1868
# EarlyStopping counter: 31 out of 50
# Epoch 250
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9676879290138959
# Val Accuracy: 0.969939879759519
# Training Loss: 0.0898
# Validation Loss: 0.0768
# EarlyStopping counter: 32 out of 50
# Epoch 251
# 5973/5973: [===============================>] - ETA 1.0s
# Train Accuracy: 0.9676879290138959
# Val Accuracy: 0.9532398129592519
# Training Loss: 0.0882
# Validation Loss: 0.1742
# EarlyStopping counter: 33 out of 50
# Epoch 252
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9753892516323456
# Val Accuracy: 0.9592518370073481
# Training Loss: 0.0695
# Validation Loss: 0.1139
# EarlyStopping counter: 34 out of 50
# Epoch 253
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9780679725431106
# Val Accuracy: 0.978623914495658
# Training Loss: 0.0655
# Validation Loss: 0.0584
# EarlyStopping counter: 35 out of 50
# Epoch 254
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9812489536246443
# Val Accuracy: 0.9826319305277221
# Training Loss: 0.0575
# Validation Loss: 0.0474
# EarlyStopping counter: 36 out of 50
# Epoch 255
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9817512137954126
# Val Accuracy: 0.969939879759519
# Training Loss: 0.0548
# Validation Loss: 0.1224
# EarlyStopping counter: 37 out of 50
# Epoch 256
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9755566716892684
# Val Accuracy: 0.9759519038076152
# Training Loss: 0.0661
# Validation Loss: 0.0687
# EarlyStopping counter: 38 out of 50
# Epoch 257
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9728779507785033
# Val Accuracy: 0.9739478957915831
# Training Loss: 0.0763
# Validation Loss: 0.0661
# EarlyStopping counter: 39 out of 50
# Epoch 258
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9718734304369664
# Val Accuracy: 0.9799599198396793
# Training Loss: 0.0787
# Validation Loss: 0.0530
# EarlyStopping counter: 40 out of 50
# Epoch 259
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9758915118031141
# Val Accuracy: 0.9712758851035405
# Training Loss: 0.0667
# Validation Loss: 0.0778
# EarlyStopping counter: 41 out of 50
# Epoch 260
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9737150510631174
# Val Accuracy: 0.9812959251837008
# Training Loss: 0.0722
# Validation Loss: 0.0483
# EarlyStopping counter: 42 out of 50
# Epoch 261
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9794073329984933
# Val Accuracy: 0.9612558450233801
# Training Loss: 0.0618
# Validation Loss: 0.1035
# EarlyStopping counter: 43 out of 50
# Epoch 262
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9784028126569563
# Val Accuracy: 0.9672678690714763
# Training Loss: 0.0651
# Validation Loss: 0.0814
# EarlyStopping counter: 44 out of 50
# Epoch 263
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9773982923154194
# Val Accuracy: 0.9726118904475618
# Training Loss: 0.0685
# Validation Loss: 0.0689
# EarlyStopping counter: 45 out of 50
# Epoch 264
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9752218315754227
# Val Accuracy: 0.9752839011356046
# Training Loss: 0.0687
# Validation Loss: 0.0653
# EarlyStopping counter: 46 out of 50
# Epoch 265
# 5973/5973: [===============================>] - ETA 1.2s
# Train Accuracy: 0.9747195714046543
# Val Accuracy: 0.9873079492317969
# Training Loss: 0.0713
# Validation Loss: 0.0321
# EarlyStopping counter: 47 out of 50
# Epoch 266
# 5973/5973: [===============================>] - ETA 0.9s
# Train Accuracy: 0.9675205089569731
# Val Accuracy: 0.9619238476953907
# Training Loss: 0.0870
# Validation Loss: 0.0958
# EarlyStopping counter: 48 out of 50
# Epoch 267
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9802444332831073
# Val Accuracy: 0.9832999331997327
# Training Loss: 0.0579
# Validation Loss: 0.0505
# EarlyStopping counter: 49 out of 50
# Epoch 268
# 5973/5973: [===============================>] - ETA 1.1s
# Train Accuracy: 0.9725431106646576
# Val Accuracy: 0.9859719438877755
# Training Loss: 0.0776
# Validation Loss: 0.0440
# EarlyStopping counter: 50 out of 50
# Early stopping
# <All keys matched successfully>

# %%
num_classes = 7

predlist = torch.zeros(0,dtype=torch.long, device='cpu')
lbllist = torch.zeros(0,dtype=torch.long, device='cpu')
predlistauc = torch.zeros(0,dtype=torch.long, device='cpu')
with torch.no_grad():
    for i, (inputs, classes) in enumerate(val_loader):
        model.eval()
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)

        # Append batch prediction results
        predlist=torch.cat([predlist,preds.view(-1).cpu()])
        lbllist=torch.cat([lbllist,classes.view(-1).cpu()])
        predlistauc = torch.cat([predlistauc,nn.functional.softmax(outputs, dim=1).cpu()])
predlist = predlist.numpy()
lbllist = lbllist.numpy()
predlistauc = predlistauc.numpy()

# Confusion matrix, classification report and AUC
conf_mat=confusion_matrix(lbllist, predlist)
target_names = ['MEL','NV','BCC','AKIEC','BKL','DF','VASC',]
ConfusionMatrixDisplay(conf_mat, display_labels=target_names).plot(values_format="d")
print(classification_report(lbllist, predlist, target_names=target_names))
lbllist_one_hot = nn.functional.one_hot(torch.tensor([lbllist]), num_classes=num_classes)
every_auc = roc_auc_score(lbllist_one_hot.view([predlistauc.shape[0], predlistauc.shape[1]]), 
                                          predlistauc, multi_class='ovr', average=None)
for i, every in enumerate(target_names):
    print(f'AUC of class {every} = {every_auc[i]}')
# Out:
#               precision    recall  f1-score   support
#
#          MEL       0.99      0.94      0.97       123
#           NV       0.99      1.00      0.99      1081
#          BCC       0.99      1.00      0.99        66
#        AKIEC       1.00      0.98      0.99        46
#          BKL       0.99      0.98      0.99       146
#           DF       1.00      1.00      1.00        15
#         VASC       0.95      1.00      0.98        20
#
#     accuracy                           0.99      1497
#    macro avg       0.99      0.99      0.99      1497
# weighted avg       0.99      0.99      0.99      1497
#
# AUC of class MEL = 0.9998284043975811
# AUC of class NV = 0.9997998647975521
# AUC of class BCC = 1.0
# AUC of class AKIEC = 0.9999700356575675
# AUC of class BKL = 0.9999138132078723
# AUC of class DF = 1.0
# AUC of class VASC = 1.0
# /tmp/ipykernel_27/905154233.py:27: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /usr/local/src/pytorch/torch/csrc/utils/tensor_new.cpp:245.)
#   lbllist_one_hot = nn.functional.one_hot(torch.tensor([lbllist]), num_classes=num_classes)

# %% [markdown]
# # For better validation robustness lets spin validation dataset with random rotations and horizontal flip and then check the metrics again

# %%
val_transforms = transforms.Compose([
    transforms.Resize((224, 280)),
    torchvision.transforms.CenterCrop((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomApply(transforms=[transforms.RandomRotation(degrees=(-180, 180))], p=0.99),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])


val_dataset = datasets.ImageFolder(
    valdir, transform=val_transforms)

val_loader = torch.utils.data.DataLoader(
    val_dataset, batch_size=64, shuffle=True,
    pin_memory=False, drop_last=False)

# %%
num_classes = 7

predlist=torch.zeros(0,dtype=torch.long, device='cpu')
lbllist=torch.zeros(0,dtype=torch.long, device='cpu')
predlistauc = torch.zeros(0,dtype=torch.long, device='cpu')
for n in range(5):
    with torch.no_grad():
        for i, (inputs, classes) in enumerate(val_loader):
            model.eval()
            inputs = inputs.to(device)
            classes = classes.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            # Append batch prediction results
            predlist=torch.cat([predlist,preds.view(-1).cpu()])
            lbllist=torch.cat([lbllist,classes.view(-1).cpu()])
            predlistauc = torch.cat([predlistauc,nn.functional.softmax(outputs, dim=1).cpu()])
predlist = predlist.numpy()
lbllist = lbllist.numpy()
predlistauc = predlistauc.numpy() 

# Confusion matrix, classification report and AUC
conf_mat=confusion_matrix(lbllist, predlist)
target_names = ['MEL','NV','BCC','AKIEC','BKL','DF','VASC',]
ConfusionMatrixDisplay(conf_mat, display_labels=target_names).plot(values_format="d")
print(classification_report(lbllist, predlist, target_names=target_names))
lbllist_one_hot = nn.functional.one_hot(torch.tensor([lbllist]), num_classes=num_classes)
every_auc = roc_auc_score(lbllist_one_hot.view([predlistauc.shape[0], predlistauc.shape[1]]), 
                                          predlistauc, multi_class='ovr', average=None)
for i, every in enumerate(target_names):
    print(f'AUC of class {every} = {every_auc[i]}')
# Out:
#               precision    recall  f1-score   support
#
#          MEL       0.98      0.94      0.96       615
#           NV       0.99      1.00      1.00      5405
#          BCC       1.00      0.98      0.99       330
#        AKIEC       0.98      0.98      0.98       230
#          BKL       0.97      0.99      0.98       730
#           DF       1.00      1.00      1.00        75
#         VASC       1.00      1.00      1.00       100
#
#     accuracy                           0.99      7485
#    macro avg       0.99      0.98      0.99      7485
# weighted avg       0.99      0.99      0.99      7485
#
# AUC of class MEL = 0.9996142057490444
# AUC of class NV = 0.9997927488792429
# AUC of class BCC = 0.999987294326917
# AUC of class AKIEC = 0.9999370748808918
# AUC of class BKL = 0.9998523670948968
# AUC of class DF = 1.0
# AUC of class VASC = 1.0

# %% [markdown]
# In the end we were able to achieve 99% average F1 score and AUCs close to 100%!
# And what is interesting, even on 2 classes with smallest representations (only 78 and 58 training images) we still were able to achieve 100 F1 score in both cases.
# I believe that the most important reason for the perfect result is well chosen data augmentations that helped not only to enrich our dataset, but also prevent overfitting.
