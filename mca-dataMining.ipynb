# %%
import pandas as pd

# %%
df = pd.read_csv('D:\OneDrive - NITT\Custom_Download\MCA-2nd_DataMining - Sheet1.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\O'
# <>:1: SyntaxWarning: invalid escape sequence '\O'
# C:\Users\avitr\AppData\Local\Temp\ipykernel_22364\2199822744.py:1: SyntaxWarning: invalid escape sequence '\O'
#   df = pd.read_csv('D:\OneDrive - NITT\Custom_Download\MCA-2nd_DataMining - Sheet1.csv')

# %%
df
# Out:
#     Roll Number  Unnamed: 1  31-7-2024(10Q)  7-8-2024(6Q)  14-8-2024 (7Q)  \
# 0     205123001         2.0            10.0           6.0             7.0
# 1     205123003         0.5             5.0           NaN             4.0
# 2     205123005         2.0            10.0           6.0             6.0
# 3     205123007         NaN             NaN           NaN             3.0
# 4     205123009         1.5             NaN           6.0             7.0
# 5     205123011         0.5             5.0           6.0             NaN
# 6     205123013         4.0            10.0           NaN             6.0
# 7     205123015         0.5            10.0           6.0             7.0
# 8     205123017         NaN             5.0           3.0             7.0
# 9     205123019         0.0             5.0           3.0             NaN
# 10    205123021         0.5            10.0           6.0             5.0
# 11    205123023         1.0            10.0           3.0             6.0
# ...

# %%
df = df.rename(columns={'Unnamed: 1': 'Weekly_20', '06/11/2024(LAB_FINAL_EXAM)': 'EndSem_30'})

# %%
df.Weekly_20 = df.Weekly_20*4

# %%
df.EndSem_30 = df.EndSem_30*5.5

# %%
df = df.rename(columns={'31-7-2024(10Q)': 'Weekly1_20'})

# %%
df.Weekly1_20 = df.Weekly1_20*2

# %%
df.to_csv('mca_dm.csv',index=False)

# %%
df = pd.read_csv('mca_dm.csv')

# %%
df['11-9-2024 (1Q)'] = df['11-9-2024 (1Q)']*11

# %%
df['CT1'] = df[['7-8-2024(6Q)' ,'14-8-2024 (7Q)' ,'28-8-2024 (6Q)' ,'11-9-2024 (1Q)']].sum(axis=1)

# %%
df = df[['Roll Number','Weekly_20','Weekly1_20','EndSem_30','CT1']]

# %%
df.columns = ['Roll Number', 'Weekly1_20', 'Weekly2_20','EndSem_30' ,'CT1_30']

# %%
import numpy as np

# %%
df.Weekly1_20 = np.where(df.Weekly1_20==0,4,df.Weekly1_20)
# Out:
# C:\Users\avitr\AppData\Local\Temp\ipykernel_22364\543228424.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Weekly1_20 = np.where(df.Weekly1_20==0,4,df.Weekly1_20)

# %%
df.Weekly1_20 = np.where(df.Weekly1_20==0,4,df.Weekly1_20)
# Out:
#     Roll Number  Weekly1_20  Weekly2_20  EndSem_30  CT1_30
# 0     205123001           8          20      27.50    30.0
# 1     205123003           2          10      27.50    23.0
# 2     205123005           8          20      27.50    28.0
# 3     205123007           8          10      16.50    22.9
# 4     205123009           6          18      27.50    30.0
# 5     205123011           2          10      27.50    28.0
# 6     205123013          16          20      27.50    25.9
# 7     205123015           2          20      27.50    28.0
# 8     205123017          12          10      27.50    26.0
# 9     205123019           4          10      27.50    25.0
# 10    205123021           2          20      22.00    28.0
# 11    205123023           4          20      22.00    25.0
# 12    205123025           8          10      27.50    26.0
# 13    205123027           2          20      16.50    28.0
# 14    205123029          12          20      27.50    21.0
# ...

# %%
df['Total'] = df[['Weekly1_20', 'Weekly2_20','EndSem_30' ,'CT1_30']].sum(axis=1)
# Out:
# C:\Users\avitr\AppData\Local\Temp\ipykernel_22364\3011901590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total'] = df[['Weekly1_20', 'Weekly2_20','EndSem_30' ,'CT1_30']].sum(axis=1)

# %%
df = df.sort_values('Total',ascending=False)

# %%
df.to_csv('Final_mca_dm.csv',index=False)

# %%
df.Total.mean()
# Out:
# 74.51140350877192

# %%
df.EndSem_30 = df.EndSem_30.round()

# %%
df = df.astype(int)

# %%
df['Total'] = df[['Weekly1_20', 'Weekly2_20','EndSem_30' ,'CT1_30']].sum(axis=1)

# %%
df
# Out:
#     Roll Number  Weekly1_20  Weekly2_20  EndSem_30  CT1_30  Total
# 47    205123095          16          20         28      29     93
# 35    205123071          12          20         28      30     90
# 6     205123013          16          20         28      25     89
# 19    205123039          12          18         28      30     88
# 0     205123001           8          20         28      30     86
# 16    205123033           8          20         28      30     86
# 39    205123079          16          20         22      26     84
# 52    205123105           8          20         28      29     85
# 31    205123063          12          20         28      25     85
# 15    205123031          12          20         28      24     84
# 2     205123005           8          20         28      28     84
# 29    205123059          10          16         28      30     84
# 54    205123109           6          20         28      29     83
# ...

# %%
df = df.sort_values('Total',ascending=False)

# %%
df.to_csv('Final_mca_dm.csv',index=False)

# %%
df
# Out:
#     Roll Number  Weekly1_20  Weekly2_20  EndSem_30  CT1_30  Total
# 47    205123095          16          20         28      29     93
# 35    205123071          12          20         28      30     90
# 6     205123013          16          20         28      25     89
# 19    205123039          12          18         28      30     88
# 0     205123001           8          20         28      30     86
# 16    205123033           8          20         28      30     86
# 52    205123105           8          20         28      29     85
# 31    205123063          12          20         28      25     85
# 39    205123079          16          20         22      26     84
# 15    205123031          12          20         28      24     84
# 2     205123005           8          20         28      28     84
# 29    205123059          10          16         28      30     84
# 54    205123109           6          20         28      29     83
# ...

# %%
import json
with open('final_words.json', 'r') as json_file:
    final_dict = json.load(json_file)

# %%
import pandas as pd

# %%
len(final_dict)
# Out:
# 434920

# %%
pd.DataFrame(list(final_dict)).to_csv('junk.csv',index=False)
