# %%
# https://github.com/brandonwz/ml4gfinal

# %%
# %%writefile train.py
from hmnet import ConvTransNet, BetterConvNet, BetterConvPoolNet, SimpleConvNet, TransformerNoConv
from data_reader import HisModDataset

import torch
import torch.nn as nn

import scipy
from sklearn import metrics

import numpy as np

import matplotlib.pyplot as plt

import os, sys

from timeit import default_timer

#Use a trial name that hasn't been used before -- models will get saved here 
TRIAL_NAME = "11betterConv2geneTest"
TRIAL_DIR = "./checkpoints/" + TRIAL_NAME

print("====== GPU Info ======")

print("cuda available:", torch.cuda.is_available())

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("device:", DEVICE)

print("======================")

MAIN_DIR = "./ProcessedData/"

def train(
	hmnet, 
	train_loader, 
	val_loader, 
	checkpoint_name = "", 
	epoch = 10
	):

	optim = torch.optim.Adam(hmnet.parameters(), amsgrad=True)

	checkpoint = "./checkpoints/" + checkpoint_name

	min_val_mse = float('inf')

	torch.set_grad_enabled(True)
	hmnet.train()

	print("train...")
	c = 0
	for i in range(epoch):
		start_time = default_timer()
		for x1, x2, y in train_loader:

			x1 = x1.to(DEVICE)
			x2 = x2.to(DEVICE)
			y = y.to(DEVICE)

			#Take diff of gene seq feature tensors 
			input_mat = x1 - x2
			input_mat = input_mat.float()

			pred = hmnet(input_mat)
			pred = pred.squeeze()

			loss = nn.MSELoss()

			y = y.float()
			y = y.squeeze()

			out = loss(pred, y)

			out.backward()

			optim.step()
			optim.zero_grad()

		mse, r2, _ = eval(val_loader, hmnet)

		epoch_time = default_timer() - start_time
		print("epoch:", (i+1))
		print("time taken:", epoch_time)
		print("val pcc:", r2)

		#Save model with best performance on validation set in terms of MSE
		if(mse < min_val_mse):
			min_val_mse = mse
			torch.save(hmnet.state_dict(), checkpoint)

		torch.set_grad_enabled(True)
		hmnet.train()	

	print("finished training")

	#Load and return best model across epochs
	hmnet.load_state_dict(torch.load(checkpoint))

	return hmnet

#Evaluates model on dataset
def eval(test_data, model):
	torch.set_grad_enabled(False)
	model.eval()
	pred_list = []; label_list = []
	for x1, x2, y in test_data:

		x1 = x1.to(DEVICE)
		x2 = x2.to(DEVICE)
		y = y.to(DEVICE)

		input_mat = x1 - x2
		input_mat = input_mat.float()

		pred = model(input_mat)
		y = y.float()

		pred_list.append(pred.squeeze().item())
		label_list.append(y.squeeze().item())

	pred_list = np.array(pred_list)
	label_list = np.array(label_list)

	#print(pred_list[0:10])

	#From https://github.com/QData/DeepDiffChrome
	R2,p=scipy.stats.pearsonr(label_list, pred_list)
	MSE=metrics.mean_squared_error(label_list, pred_list)
	return MSE, R2, p

def graph_results(pccs):
	labels = ["E123-E003", 
	"E116-E003", 
	"E123-E116", 
	"E003-E005", 
	"E003-E006",
	"E006-E007",
	"E005-E006",
	"E003-E004",
	"E004-E006",
	"E037-E038"]

	ticks = np.arange(10) + 1

	plt.figure()
	plt.xticks(ticks, labels, rotation = 45)
	plt.plot(ticks, pccs, linestyle='dashed', marker='o')
	plt.ylabel("Pearson Correlation Coefficient")
	plt.xlabel("Cell Pairs")
	plt.ylim(0, 1)
	plt.show()


if __name__ == '__main__':
	cell_pairs = [
	["E123", "E003"],
	["E116", "E003"],
	["E123", "E116"],
	["E003", "E005"],
	["E003", "E006"],
	["E006", "E007"],
	["E005", "E006"],
	["E003", "E004"],
	["E004", "E006"],
	["E037", "E038"]
	]

	#Make sure trial name is unique
	if(os.path.exists(TRIAL_DIR)):
		print("Error: trial already exists. Please choose a different name.")
		sys.exit()
	else:
		os.makedirs(TRIAL_DIR)

	for cell_pair in cell_pairs:
		TRIAL_PAIR_NAME = TRIAL_NAME + "_" + cell_pair[0] + "_" + cell_pair[1]
		TRIAL_SAVE = TRIAL_NAME + "/" + TRIAL_PAIR_NAME
		
		print("=======CELL PAIR: " + str(cell_pair) + "========")
		
		cellA_expr_file = cell_pair[0] + ".expr.csv"
		cellA_file = cell_pair[0] + ".train.csv"
		cellB_file = cell_pair[1] + ".train.csv"
		cellB_expr_file = cell_pair[1] + ".expr.csv"

		cellA_val = cell_pair[0] + ".valid.csv"
		cellB_val = cell_pair[1] + ".valid.csv"

		hmnet = ConvTransNet() #BetterConvNet() #Change me to one of the available models
		hmnet = hmnet.to(DEVICE)

		print("loading data...")

		#Load train data
		dataset = HisModDataset(
			cellA_file, 
			cellA_expr_file, 
			cellB_file, 
			cellB_expr_file, 
			MAIN_DIR
		)
		
		#Load val data
		val_data = HisModDataset(
			cellA_val, 
			cellA_expr_file, 
			cellB_val, 
			cellB_expr_file, 
			MAIN_DIR
		)

		print("data loaded!")

		dataloader = torch.utils.data.DataLoader(dataset)
		val_loader = torch.utils.data.DataLoader(val_data)

		hmnet = train(hmnet, dataloader, val_loader = val_loader, checkpoint_name = TRIAL_SAVE)

		MSE, R2, p = eval(dataloader, hmnet)
		print("eval on train set:", R2, p)

		cellA_expr_file = cell_pair[0] + ".expr.csv"
		cellA_file = cell_pair[0] + ".test.csv"
		cellB_file = cell_pair[1] + ".test.csv"
		cellB_expr_file = cell_pair[1] + ".expr.csv"

		#Load test data 
		dataset = HisModDataset(
			cellA_file, 
			cellA_expr_file, 
			cellB_file, 
			cellB_expr_file, 
			MAIN_DIR, 
			ignore_B = False
		)

		dataloader = torch.utils.data.DataLoader(dataset)


		MSE, R2, p = eval(dataloader, hmnet)
		print("eval on test set: ", R2, p)

# %%
import os
import sys
import torch
class HisModDataset(torch.utils.data.Dataset):
    def __init__(
                self, 
                cellA_file, 
                cellA_expr_file, 
                cellB_file, 
                cellB_expr_file, 
                main_dir, 
                ignore_B=False,
                shuffle_cols = False #experimental
                ):
        
        print('in constructor')

        cell_cols = ["A", "B", "C", "D", "E", "F"] #dummy cols
        expr_cols = ["A", "B"] #dummy cols 

        #read in data into dataframes
        cellA_df = pd.read_csv(main_dir + cellA_file, names=cell_cols)
        cellB_df = pd.read_csv(main_dir + cellB_file, names=cell_cols)
        cellA_expr_df = pd.read_csv(main_dir + cellA_expr_file, names=expr_cols)
        cellB_expr_df = pd.read_csv(main_dir + cellB_expr_file, names=expr_cols)

        #200 entries per gene
        self.offset = 200
        self.length = len(cellA_df)//self.offset

        #all cols except one with gene info
        hm_cols = ["B", "C", "D", "E", "F"]

        #convert to tensor
        self.cellA_tensor = torch.tensor(cellA_df[hm_cols].values)
        self.cellB_tensor = torch.tensor(cellB_df[hm_cols].values)

        #using expr file, maps gene id -> expr value
        self.gene_to_valA = dict(zip(cellA_expr_df.A, cellA_expr_df.B))
        self.gene_to_valB = dict(zip(cellB_expr_df.A, cellB_expr_df.B))

        #extract gene info col from the train/test/val data
        self.geneA_names = cellA_df["A"]
        self.geneB_names = cellB_df["A"]

        self.ignore_B = ignore_B
        self.shuffle_cols = shuffle_cols

    def __getitem__(self, idx):
        print('in get items',idx)
        idx = idx*self.offset

        #find the relevant slice of the tensor based on the id
        tensorA = self.cellA_tensor[idx:idx+self.offset]
        tensorB = self.cellB_tensor[idx:idx+self.offset]

        #transpose b/c data is initially 200x5
        tensorA = torch.transpose(tensorA, 0, 1)
        tensorB = torch.transpose(tensorB, 0, 1)

        if(self.shuffle_cols): #experimental
            tensorA = tensorA[:, torch.randperm(tensorA.size()[1])]
            tensorB = tensorB[:, torch.randperm(tensorB.size()[1])]

        #just takes the first gene window id corresponding to the 
        #group of 200 and uses it to find the gene id
        geneA = self.geneA_names[idx].split("_")[0]
        geneB = self.geneB_names[idx].split("_")[0]

        #print(geneA); print(geneB) #<-- should be the same

        #Get the expression values for cell A and cell B
        cA = self.gene_to_valA[geneA]
        cB = self.gene_to_valB[geneB]

        if(self.ignore_B):
            return tensorA, tensorB, cA

		#Find the log-fold change
        label = self.getlabel(cA, cB) 

        return tensorA, tensorB, label[0]

    def __len__(self):
        return self.length

	#From https://github.com/QData/DeepDiffChrome/blob/master/data.py
    def getlabel(self, c1,c2):
        print('in get label')
        # get log fold change of expression

        label1=math.log((float(c1)+1.0),2)
        label2=math.log((float(c2)+1.0),2)
        label=[]
        label.append(label1)
        label.append(label2)

        fold_change=(float(c2)+1.0)/(float(c1)+1.0)
        log_fold_change=math.log((fold_change),2)
        return (log_fold_change, label)

# %%
import os
import sys
import pandas as pd
# from data_reader import HisModDataset
TRIAL_NAME = "11awawqswa21aas"
TRIAL_DIR = "./checkpoints/" + TRIAL_NAME
MAIN_DIR = "./ProcessedData/"
cell_pairs = [
                ["E123", "E003"]
#                 ["E116", "E003"],
#                 ["E123", "E116"],
#                 ["E003", "E005"],
#                 ["E003", "E006"],
#                 ["E006", "E007"],
#                 ["E005", "E006"],
#                 ["E003", "E004"],
#                 ["E004", "E006"],
#                 ["E037", "E038"]
            ]

#Make sure trial name is unique
if(os.path.exists(TRIAL_DIR)):
    print("Error: trial already exists. Please choose a different name.")
    sys.exit()
else:
    os.makedirs(TRIAL_DIR)

for cell_pair in cell_pairs:
    TRIAL_PAIR_NAME = TRIAL_NAME + "_" + cell_pair[0] + "_" + cell_pair[1]
    TRIAL_SAVE = TRIAL_NAME + "/" + TRIAL_PAIR_NAME

    print("=======CELL PAIR: " + str(cell_pair) + "========")

    cellA_expr_file = cell_pair[0] + ".expr.csv"
    cellA_file = cell_pair[0] + ".train.csv"
    cellB_file = cell_pair[1] + ".train.csv"
    cellB_expr_file = cell_pair[1] + ".expr.csv"

    cellA_val = cell_pair[0] + ".valid.csv"
    cellB_val = cell_pair[1] + ".valid.csv"

#     hmnet = ConvTransNet() #BetterConvNet() #Change me to one of the available models
#     hmnet = hmnet.to(DEVICE)

    print("loading data...")

    #Load train data
    dataset = HisModDataset(
        cellA_file, 
        cellA_expr_file, 
        cellB_file, 
        cellB_expr_file, 
        MAIN_DIR
    )

#     #Load val data
#     val_data = HisModDataset(
#         cellA_val, 
#         cellA_expr_file, 
#         cellB_val, 
#         cellB_expr_file, 
#         MAIN_DIR
#     )

    print("data loaded!")
# Out:
# =======CELL PAIR: ['E123', 'E003']========
# loading data...
# in constructor
# data loaded!

# %%
dataloader1 = torch.utils.data.DataLoader(dataset)

# %%
import math

# %%
for x1, x2, y in dataloader1:
    print(y)
# Out:
# in get items 0
# in get label
# tensor([2.7388], dtype=torch.float64)
# in get items 1
# in get label
# tensor([1.2595], dtype=torch.float64)
# in get items 2
# in get label
# tensor([-7.9794], dtype=torch.float64)
# in get items 3
# in get label
# tensor([1.5605], dtype=torch.float64)
# in get items 4
# in get label
# tensor([3.0940], dtype=torch.float64)
# in get items 5
# in get label
# tensor([-0.2579], dtype=torch.float64)
# in get items 6
# in get label
# tensor([-0.6517], dtype=torch.float64)
# in get items 7
# in get label
# tensor([5.9305], dtype=torch.float64)
# in get items 8
# in get label
# tensor([-0.2507], dtype=torch.float64)
# in get items 9
# in get label
# tensor([-1.7564], dtype=torch.float64)
# in get items 10
# in get label
# tensor([-0.5049], dtype=torch.float64)
# in get items 11
# in get label
# tensor([-0.6534], dtype=torch.float64)
# in get items 12
# in get label
# tensor([-2.5250], dtype=torch.float64)
# in get items 13
# in get label
# tensor([-0.7851], dtype=torch.float64)
# in get items 14
# in get label
# tensor([0.0951], dtype=torch.float64)
# in get items 15
# in get label
# tensor([-0.6169], dtype=torch.float64)
# in get items 16
# in get label
# tensor([0.3259], dtype=torch.float64)
# in get items 17
# in get label
# tensor([-2.0072], dtype=torch.float64)
# in get items 18
# in get label
# tensor([0.7895], dtype=torch.float64)
# in get items 19
# in get label
# tensor([0.5952], dtype=torch.float64)
# in get items 20
# in get label
# tensor([-0.1812], dtype=torch.float64)
# in get items 21
# in get label
# tensor([-1.9071], dtype=torch.float64)
# in get items 22
# in get label
# tensor([-3.6760], dtype=torch.float64)
# in get items 23
# in get label
# tensor([-1.5718], dtype=torch.float64)
# in get items 24
# in get label
# tensor([-4.1917], dtype=torch.float64)
# in get items 25
# in get label
# tensor([-4.7362], dtype=torch.float64)
# in get items 26
# in get label
# tensor([6.0858], dtype=torch.float64)
# in get items 27
# in get label
# tensor([-0.1642], dtype=torch.float64)
# in get items 28
# in get label
# tensor([10.2252], dtype=torch.float64)
# in get items 29
# in get label
# tensor([12.0379], dtype=torch.float64)
# in get items 30
# in get label
# tensor([-0.7812], dtype=torch.float64)
# in get items 31
# in get label
# tensor([-1.2370], dtype=torch.float64)
# in get items 32
# in get label
# tensor([1.1381], dtype=torch.float64)
# in get items 33
# in get label
# tensor([1.9072], dtype=torch.float64)
# in get items 34
# in get label
# tensor([5.1699], dtype=torch.float64)
# in get items 35
# in get label
# tensor([0.4854], dtype=torch.float64)
# in get items 36
# in get label
# tensor([3.8074], dtype=torch.float64)
# in get items 37
# in get label
# tensor([1.5196], dtype=torch.float64)
# in get items 38
# in get label
# tensor([-1.8745], dtype=torch.float64)
# in get items 39
# in get label
# tensor([-0.0457], dtype=torch.float64)
# in get items 40
# in get label
# tensor([-0.4482], dtype=torch.float64)
# in get items 41
# in get label
# tensor([0.1836], dtype=torch.float64)
# in get items 42
# in get label
# tensor([9.0224], dtype=torch.float64)
# in get items 43
# in get label
# tensor([-0.1028], dtype=torch.float64)
# in get items 44
# in get label
# tensor([0.8266], dtype=torch.float64)
# in get items 45
# in get label
# tensor([-6.8486], dtype=torch.float64)
# in get items 46
# in get label
# tensor([5.1470], dtype=torch.float64)
# in get items 47
# in get label
# tensor([5.0312], dtype=torch.float64)
# in get items 48
# in get label
# tensor([6.1756], dtype=torch.float64)
# in get items 49
# in get label
# tensor([-1.4793], dtype=torch.float64)
# in get items 50
# in get label
# tensor([0.8193], dtype=torch.float64)
# in get items 51
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 52
# in get label
# tensor([-0.8513], dtype=torch.float64)
# in get items 53
# in get label
# tensor([3.5850], dtype=torch.float64)
# in get items 54
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 55
# in get label
# tensor([0.3465], dtype=torch.float64)
# in get items 56
# in get label
# tensor([2.3219], dtype=torch.float64)
# in get items 57
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 58
# in get label
# tensor([1.1500], dtype=torch.float64)
# in get items 59
# in get label
# tensor([-0.0188], dtype=torch.float64)
# in get items 60
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 61
# in get label
# tensor([-3.5755], dtype=torch.float64)
# in get items 62
# in get label
# tensor([7.4000], dtype=torch.float64)
# in get items 63
# in get label
# tensor([7.2901], dtype=torch.float64)
# in get items 64
# in get label
# tensor([7.5267], dtype=torch.float64)
# in get items 65
# in get label
# tensor([0.6139], dtype=torch.float64)
# in get items 66
# in get label
# tensor([4.7891], dtype=torch.float64)
# in get items 67
# in get label
# tensor([1.5850], dtype=torch.float64)
# in get items 68
# in get label
# tensor([-1.5071], dtype=torch.float64)
# in get items 69
# in get label
# tensor([0.1627], dtype=torch.float64)
# in get items 70
# in get label
# tensor([-1.7084], dtype=torch.float64)
# in get items 71
# in get label
# tensor([0.6521], dtype=torch.float64)
# in get items 72
# in get label
# tensor([6.4206], dtype=torch.float64)
# in get items 73
# in get label
# tensor([3.1876], dtype=torch.float64)
# in get items 74
# in get label
# tensor([-1.0542], dtype=torch.float64)
# in get items 75
# in get label
# tensor([-0.6707], dtype=torch.float64)
# in get items 76
# in get label
# tensor([-1.2104], dtype=torch.float64)
# in get items 77
# in get label
# tensor([-1.2206], dtype=torch.float64)
# in get items 78
# in get label
# tensor([-0.9071], dtype=torch.float64)
# in get items 79
# in get label
# tensor([-0.5171], dtype=torch.float64)
# in get items 80
# in get label
# tensor([-1.0603], dtype=torch.float64)
# in get items 81
# in get label
# tensor([-2.5942], dtype=torch.float64)
# in get items 82
# in get label
# tensor([1.5850], dtype=torch.float64)
# in get items 83
# in get label
# tensor([-1.3865], dtype=torch.float64)
# in get items 84
# in get label
# tensor([1.6677], dtype=torch.float64)
# in get items 85
# in get label
# tensor([0.7644], dtype=torch.float64)
# in get items 86
# in get label
# tensor([11.1666], dtype=torch.float64)
# in get items 87
# in get label
# tensor([-0.9635], dtype=torch.float64)
# in get items 88
# in get label
# tensor([-1.1966], dtype=torch.float64)
# in get items 89
# in get label
# tensor([1.1297], dtype=torch.float64)
# in get items 90
# in get label
# tensor([1.4495], dtype=torch.float64)
# in get items 91
# in get label
# tensor([-1.1970], dtype=torch.float64)
# in get items 92
# in get label
# tensor([7.5999], dtype=torch.float64)
# in get items 93
# in get label
# tensor([-0.8448], dtype=torch.float64)
# in get items 94
# in get label
# tensor([-1.5642], dtype=torch.float64)
# in get items 95
# in get label
# tensor([-0.8828], dtype=torch.float64)
# in get items 96
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 97
# in get label
# tensor([-2.8495], dtype=torch.float64)
# in get items 98
# in get label
# tensor([-1.5559], dtype=torch.float64)
# in get items 99
# in get label
# tensor([-1.5394], dtype=torch.float64)
# in get items 100
# in get label
# tensor([-2.4345], dtype=torch.float64)
# in get items 101
# in get label
# tensor([9.5088], dtype=torch.float64)
# in get items 102
# in get label
# tensor([-1.7500], dtype=torch.float64)
# in get items 103
# in get label
# tensor([-1.1888], dtype=torch.float64)
# in get items 104
# in get label
# tensor([2.4594], dtype=torch.float64)
# in get items 105
# in get label
# tensor([1.0063], dtype=torch.float64)
# in get items 106
# in get label
# tensor([0.2579], dtype=torch.float64)
# in get items 107
# in get label
# tensor([-0.5995], dtype=torch.float64)
# in get items 108
# in get label
# tensor([1.1615], dtype=torch.float64)
# in get items 109
# in get label
# tensor([-1.1044], dtype=torch.float64)
# in get items 110
# in get label
# tensor([0.1668], dtype=torch.float64)
# in get items 111
# in get label
# tensor([0.4556], dtype=torch.float64)
# in get items 112
# in get label
# tensor([10.4846], dtype=torch.float64)
# in get items 113
# in get label
# tensor([0.6739], dtype=torch.float64)
# in get items 114
# in get label
# tensor([-0.0027], dtype=torch.float64)
# in get items 115
# in get label
# tensor([-0.5567], dtype=torch.float64)
# in get items 116
# in get label
# tensor([1.7729], dtype=torch.float64)
# in get items 117
# in get label
# tensor([-0.2679], dtype=torch.float64)
# in get items 118
# in get label
# tensor([-2.0930], dtype=torch.float64)
# in get items 119
# in get label
# tensor([10.7151], dtype=torch.float64)
# in get items 120
# in get label
# tensor([1.9334], dtype=torch.float64)
# in get items 121
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 122
# in get label
# tensor([-0.8834], dtype=torch.float64)
# in get items 123
# in get label
# tensor([-1.5125], dtype=torch.float64)
# in get items 124
# in get label
# tensor([-0.2278], dtype=torch.float64)
# in get items 125
# in get label
# tensor([-0.1036], dtype=torch.float64)
# in get items 126
# in get label
# tensor([0.7295], dtype=torch.float64)
# in get items 127
# in get label
# tensor([-1.5408], dtype=torch.float64)
# in get items 128
# in get label
# tensor([-0.3390], dtype=torch.float64)
# in get items 129
# in get label
# tensor([-1.3489], dtype=torch.float64)
# in get items 130
# in get label
# tensor([5.7925], dtype=torch.float64)
# in get items 131
# in get label
# tensor([0.0148], dtype=torch.float64)
# in get items 132
# in get label
# tensor([2.3219], dtype=torch.float64)
# in get items 133
# in get label
# tensor([1.5510], dtype=torch.float64)
# in get items 134
# in get label
# tensor([-0.3188], dtype=torch.float64)
# in get items 135
# in get label
# tensor([-0.1556], dtype=torch.float64)
# in get items 136
# in get label
# tensor([6.2605], dtype=torch.float64)
# in get items 137
# in get label
# tensor([2.5294], dtype=torch.float64)
# in get items 138
# in get label
# tensor([1.], dtype=torch.float64)
# in get items 139
# in get label
# tensor([-1.3264], dtype=torch.float64)
# in get items 140
# in get label
# tensor([1.8853], dtype=torch.float64)
# in get items 141
# in get label
# tensor([-15.8511], dtype=torch.float64)
# in get items 142
# in get label
# tensor([0.6862], dtype=torch.float64)
# in get items 143
# in get label
# tensor([-0.1496], dtype=torch.float64)
# in get items 144
# in get label
# tensor([5.7115], dtype=torch.float64)
# in get items 145
# in get label
# tensor([-0.5988], dtype=torch.float64)
# in get items 146
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 147
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 148
# in get label
# tensor([0.0422], dtype=torch.float64)
# in get items 149
# in get label
# tensor([-0.8601], dtype=torch.float64)
# in get items 150
# in get label
# tensor([0.0478], dtype=torch.float64)
# in get items 151
# in get label
# tensor([2.0563], dtype=torch.float64)
# in get items 152
# in get label
# tensor([7.6606], dtype=torch.float64)
# in get items 153
# in get label
# tensor([4.5087], dtype=torch.float64)
# in get items 154
# in get label
# tensor([-1.5980], dtype=torch.float64)
# in get items 155
# in get label
# tensor([-2.7703], dtype=torch.float64)
# in get items 156
# in get label
# tensor([2.3643], dtype=torch.float64)
# in get items 157
# in get label
# tensor([1.1331], dtype=torch.float64)
# in get items 158
# in get label
# tensor([-0.3521], dtype=torch.float64)
# in get items 159
# in get label
# tensor([-0.3800], dtype=torch.float64)
# in get items 160
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 161
# in get label
# tensor([-2.1676], dtype=torch.float64)
# in get items 162
# in get label
# tensor([6.3707], dtype=torch.float64)
# in get items 163
# in get label
# tensor([-0.4813], dtype=torch.float64)
# in get items 164
# in get label
# tensor([-0.2400], dtype=torch.float64)
# in get items 165
# in get label
# tensor([-0.1651], dtype=torch.float64)
# in get items 166
# in get label
# tensor([6.2854], dtype=torch.float64)
# in get items 167
# in get label
# tensor([1.], dtype=torch.float64)
# in get items 168
# in get label
# tensor([2.1263], dtype=torch.float64)
# in get items 169
# in get label
# tensor([-1.3140], dtype=torch.float64)
# in get items 170
# in get label
# tensor([2.3219], dtype=torch.float64)
# in get items 171
# in get label
# tensor([1.5510], dtype=torch.float64)
# in get items 172
# in get label
# tensor([-0.5850], dtype=torch.float64)
# in get items 173
# in get label
# tensor([7.7482], dtype=torch.float64)
# in get items 174
# in get label
# tensor([-0.0850], dtype=torch.float64)
# in get items 175
# in get label
# tensor([0.2400], dtype=torch.float64)
# in get items 176
# in get label
# tensor([-0.6860], dtype=torch.float64)
# in get items 177
# in get label
# tensor([-1.0408], dtype=torch.float64)
# in get items 178
# in get label
# tensor([-1.1876], dtype=torch.float64)
# in get items 179
# in get label
# tensor([11.7611], dtype=torch.float64)
# in get items 180
# in get label
# tensor([-1.2503], dtype=torch.float64)
# in get items 181
# in get label
# tensor([2.1313], dtype=torch.float64)
# in get items 182
# in get label
# tensor([1.1635], dtype=torch.float64)
# in get items 183
# in get label
# tensor([3.9439], dtype=torch.float64)
# in get items 184
# in get label
# tensor([-1.0795], dtype=torch.float64)
# in get items 185
# in get label
# tensor([2.6562], dtype=torch.float64)
# in get items 186
# in get label
# tensor([0.9236], dtype=torch.float64)
# in get items 187
# in get label
# tensor([-1.2154], dtype=torch.float64)
# in get items 188
# in get label
# tensor([0.0047], dtype=torch.float64)
# in get items 189
# in get label
# tensor([0.4406], dtype=torch.float64)
# in get items 190
# in get label
# tensor([2.9200], dtype=torch.float64)
# in get items 191
# in get label
# tensor([9.0365], dtype=torch.float64)
# in get items 192
# in get label
# tensor([-0.7641], dtype=torch.float64)
# in get items 193
# in get label
# tensor([5.8999], dtype=torch.float64)
# in get items 194
# in get label
# tensor([-1.7067], dtype=torch.float64)
# in get items 195
# in get label
# tensor([-0.0918], dtype=torch.float64)
# in get items 196
# in get label
# tensor([1.7655], dtype=torch.float64)
# in get items 197
# in get label
# tensor([0.1958], dtype=torch.float64)
# in get items 198
# in get label
# tensor([-0.9007], dtype=torch.float64)
# in get items 199
# in get label
# tensor([-0.8051], dtype=torch.float64)
# in get items 200
# in get label
# tensor([-1.3174], dtype=torch.float64)
# in get items 201
# in get label
# tensor([7.0980], dtype=torch.float64)
# in get items 202
# in get label
# tensor([4.3219], dtype=torch.float64)
# in get items 203
# in get label
# tensor([-0.1559], dtype=torch.float64)
# in get items 204
# in get label
# tensor([-7.5546], dtype=torch.float64)
# in get items 205
# in get label
# tensor([-0.1405], dtype=torch.float64)
# in get items 206
# in get label
# tensor([-2.1199], dtype=torch.float64)
# in get items 207
# in get label
# tensor([-11.7224], dtype=torch.float64)
# in get items 208
# in get label
# tensor([2.4859], dtype=torch.float64)
# in get items 209
# in get label
# tensor([1.2233], dtype=torch.float64)
# in get items 210
# in get label
# tensor([-1.4381], dtype=torch.float64)
# in get items 211
# in get label
# tensor([0.3774], dtype=torch.float64)
# in get items 212
# in get label
# tensor([0.3626], dtype=torch.float64)
# in get items 213
# in get label
# tensor([6.3130], dtype=torch.float64)
# in get items 214
# in get label
# tensor([-1.6206], dtype=torch.float64)
# in get items 215
# in get label
# tensor([-1.4126], dtype=torch.float64)
# in get items 216
# in get label
# tensor([0.9997], dtype=torch.float64)
# in get items 217
# in get label
# tensor([12.3998], dtype=torch.float64)
# in get items 218
# in get label
# tensor([-1.2105], dtype=torch.float64)
# in get items 219
# in get label
# tensor([-0.8940], dtype=torch.float64)
# in get items 220
# in get label
# tensor([10.0042], dtype=torch.float64)
# in get items 221
# in get label
# tensor([-0.6413], dtype=torch.float64)
# in get items 222
# in get label
# tensor([-0.7645], dtype=torch.float64)
# in get items 223
# in get label
# tensor([1.3980], dtype=torch.float64)
# in get items 224
# in get label
# tensor([1.2131], dtype=torch.float64)
# in get items 225
# in get label
# tensor([3.5236], dtype=torch.float64)
# in get items 226
# in get label
# tensor([-1.7551], dtype=torch.float64)
# in get items 227
# in get label
# tensor([-1.1809], dtype=torch.float64)
# in get items 228
# in get label
# tensor([-4.1502], dtype=torch.float64)
# in get items 229
# in get label
# tensor([5.8124], dtype=torch.float64)
# in get items 230
# in get label
# tensor([0.6601], dtype=torch.float64)
# in get items 231
# in get label
# tensor([-0.1251], dtype=torch.float64)
# in get items 232
# in get label
# tensor([1.1884], dtype=torch.float64)
# in get items 233
# in get label
# tensor([-0.9383], dtype=torch.float64)
# in get items 234
# in get label
# tensor([-0.3359], dtype=torch.float64)
# in get items 235
# in get label
# tensor([1.0733], dtype=torch.float64)
# in get items 236
# in get label
# tensor([-0.4135], dtype=torch.float64)
# in get items 237
# in get label
# tensor([-0.9659], dtype=torch.float64)
# in get items 238
# in get label
# tensor([-1.3151], dtype=torch.float64)
# in get items 239
# in get label
# tensor([-1.6847], dtype=torch.float64)
# in get items 240
# in get label
# tensor([0.6645], dtype=torch.float64)
# in get items 241
# in get label
# tensor([-1.0886], dtype=torch.float64)
# in get items 242
# in get label
# tensor([0.7153], dtype=torch.float64)
# in get items 243
# in get label
# tensor([-0.5468], dtype=torch.float64)
# in get items 244
# in get label
# tensor([-3.0738], dtype=torch.float64)
# in get items 245
# in get label
# tensor([1.], dtype=torch.float64)
# in get items 246
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 247
# in get label
# tensor([-0.2130], dtype=torch.float64)
# in get items 248
# in get label
# tensor([-1.8074], dtype=torch.float64)
# in get items 249
# in get label
# tensor([-1.4590], dtype=torch.float64)
# in get items 250
# in get label
# tensor([0.7245], dtype=torch.float64)
# in get items 251
# in get label
# tensor([4.0041], dtype=torch.float64)
# in get items 252
# in get label
# tensor([0.5101], dtype=torch.float64)
# in get items 253
# in get label
# tensor([-0.3364], dtype=torch.float64)
# in get items 254
# in get label
# tensor([0.7790], dtype=torch.float64)
# in get items 255
# in get label
# tensor([0.1414], dtype=torch.float64)
# in get items 256
# in get label
# tensor([-1.5464], dtype=torch.float64)
# in get items 257
# in get label
# tensor([-3.8142], dtype=torch.float64)
# in get items 258
# in get label
# tensor([0.6842], dtype=torch.float64)
# in get items 259
# in get label
# tensor([1.1406], dtype=torch.float64)
# in get items 260
# in get label
# tensor([-5.5546], dtype=torch.float64)
# in get items 261
# in get label
# tensor([4.3999], dtype=torch.float64)
# in get items 262
# in get label
# tensor([6.1699], dtype=torch.float64)
# in get items 263
# in get label
# tensor([1.0793], dtype=torch.float64)
# in get items 264
# in get label
# tensor([5.2479], dtype=torch.float64)
# in get items 265
# in get label
# tensor([1.3702], dtype=torch.float64)
# in get items 266
# in get label
# tensor([-1.3610], dtype=torch.float64)
# in get items 267
# in get label
# tensor([-2.0231], dtype=torch.float64)
# in get items 268
# in get label
# tensor([2.8074], dtype=torch.float64)
# in get items 269
# in get label
# tensor([8.1040], dtype=torch.float64)
# in get items 270
# in get label
# tensor([5.4852], dtype=torch.float64)
# in get items 271
# in get label
# tensor([-1.3325], dtype=torch.float64)
# in get items 272
# in get label
# tensor([-0.3181], dtype=torch.float64)
# in get items 273
# in get label
# tensor([-0.9405], dtype=torch.float64)
# in get items 274
# in get label
# tensor([-1.7536], dtype=torch.float64)
# in get items 275
# in get label
# tensor([-1.6205], dtype=torch.float64)
# in get items 276
# in get label
# tensor([0.4900], dtype=torch.float64)
# in get items 277
# in get label
# tensor([-0.5942], dtype=torch.float64)
# in get items 278
# in get label
# tensor([0.4341], dtype=torch.float64)
# in get items 279
# in get label
# tensor([0.2203], dtype=torch.float64)
# in get items 280
# in get label
# tensor([6.8063], dtype=torch.float64)
# in get items 281
# in get label
# tensor([2.0415], dtype=torch.float64)
# in get items 282
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 283
# in get label
# tensor([0.0329], dtype=torch.float64)
# in get items 284
# in get label
# tensor([1.0062], dtype=torch.float64)
# in get items 285
# in get label
# tensor([-0.9260], dtype=torch.float64)
# in get items 286
# in get label
# tensor([-0.0335], dtype=torch.float64)
# in get items 287
# in get label
# tensor([6.1293], dtype=torch.float64)
# in get items 288
# in get label
# tensor([-0.2759], dtype=torch.float64)
# in get items 289
# in get label
# tensor([2.8074], dtype=torch.float64)
# in get items 290
# in get label
# tensor([-2.3316], dtype=torch.float64)
# in get items 291
# in get label
# tensor([9.0741], dtype=torch.float64)
# in get items 292
# in get label
# tensor([-2.0833], dtype=torch.float64)
# in get items 293
# in get label
# tensor([6.4919], dtype=torch.float64)
# in get items 294
# in get label
# tensor([3.9760], dtype=torch.float64)
# in get items 295
# in get label
# tensor([6.4959], dtype=torch.float64)
# in get items 296
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 297
# in get label
# tensor([0.1234], dtype=torch.float64)
# in get items 298
# in get label
# tensor([6.7568], dtype=torch.float64)
# in get items 299
# in get label
# tensor([-2.0875], dtype=torch.float64)
# in get items 300
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 301
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 302
# in get label
# tensor([-1.3706], dtype=torch.float64)
# in get items 303
# in get label
# tensor([4.9107], dtype=torch.float64)
# in get items 304
# in get label
# tensor([-0.6886], dtype=torch.float64)
# in get items 305
# in get label
# tensor([2.5850], dtype=torch.float64)
# in get items 306
# in get label
# tensor([3.7004], dtype=torch.float64)
# in get items 307
# in get label
# tensor([0.8399], dtype=torch.float64)
# in get items 308
# in get label
# tensor([-0.9269], dtype=torch.float64)
# in get items 309
# in get label
# tensor([-1.0255], dtype=torch.float64)
# in get items 310
# in get label
# tensor([-1.5523], dtype=torch.float64)
# in get items 311
# in get label
# tensor([-0.2918], dtype=torch.float64)
# in get items 312
# in get label
# tensor([-0.2695], dtype=torch.float64)
# in get items 313
# in get label
# tensor([-1.3275], dtype=torch.float64)
# in get items 314
# in get label
# tensor([-0.8317], dtype=torch.float64)
# in get items 315
# in get label
# tensor([0.2632], dtype=torch.float64)
# in get items 316
# in get label
# tensor([8.7846], dtype=torch.float64)
# in get items 317
# in get label
# tensor([-1.3862], dtype=torch.float64)
# in get items 318
# in get label
# tensor([-0.2002], dtype=torch.float64)
# in get items 319
# in get label
# tensor([0.1984], dtype=torch.float64)
# in get items 320
# in get label
# tensor([-1.], dtype=torch.float64)
# in get items 321
# in get label
# tensor([1.5850], dtype=torch.float64)
# in get items 322
# in get label
# tensor([-0.4164], dtype=torch.float64)
# in get items 323
# in get label
# tensor([8.2689], dtype=torch.float64)
# in get items 324
# in get label
# tensor([6.5699], dtype=torch.float64)
# in get items 325
# in get label
# tensor([-2.], dtype=torch.float64)
# in get items 326
# in get label
# tensor([13.6133], dtype=torch.float64)
# in get items 327
# in get label
# tensor([5.6724], dtype=torch.float64)
# in get items 328
# in get label
# tensor([-0.0933], dtype=torch.float64)
# in get items 329
# in get label
# tensor([-3.5805], dtype=torch.float64)
# in get items 330
# in get label
# tensor([-3.0745], dtype=torch.float64)
# in get items 331
# in get label
# tensor([6.4757], dtype=torch.float64)
# in get items 332
# in get label
# tensor([-2.0744], dtype=torch.float64)
# in get items 333
# in get label
# tensor([-0.3626], dtype=torch.float64)
# in get items 334
# in get label
# tensor([7.7246], dtype=torch.float64)
# in get items 335
# in get label
# tensor([2.0570], dtype=torch.float64)
# in get items 336
# in get label
# tensor([-0.5388], dtype=torch.float64)
# in get items 337
# in get label
# tensor([-0.8918], dtype=torch.float64)
# in get items 338
# in get label
# tensor([-0.4835], dtype=torch.float64)
# in get items 339
# in get label
# tensor([0.4854], dtype=torch.float64)
# in get items 340
# in get label
# tensor([-0.1149], dtype=torch.float64)
# in get items 341
# in get label
# tensor([-0.8707], dtype=torch.float64)
# in get items 342
# in get label
# tensor([2.], dtype=torch.float64)
# in get items 343
# in get label
# tensor([5.5684], dtype=torch.float64)
# in get items 344
# in get label
# tensor([-7.2668], dtype=torch.float64)
# in get items 345
# in get label
# tensor([5.7279], dtype=torch.float64)
# in get items 346
# in get label
# tensor([8.7674], dtype=torch.float64)
# in get items 347
# in get label
# tensor([3.5850], dtype=torch.float64)
# in get items 348
# in get label
# tensor([1.3619], dtype=torch.float64)
# in get items 349
# in get label
# tensor([0.4759], dtype=torch.float64)
# in get items 350
# in get label
# tensor([0.2525], dtype=torch.float64)
# in get items 351
# in get label
# tensor([1.3973], dtype=torch.float64)
# in get items 352
# in get label
# tensor([4.2095], dtype=torch.float64)
# in get items 353
# in get label
# tensor([1.5850], dtype=torch.float64)
# in get items 354
# in get label
# tensor([1.6008], dtype=torch.float64)
# in get items 355
# in get label
# tensor([-1.0402], dtype=torch.float64)
# in get items 356
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 357
# in get label
# tensor([0.2982], dtype=torch.float64)
# in get items 358
# in get label
# tensor([2.0028], dtype=torch.float64)
# in get items 359
# in get label
# tensor([1.8458], dtype=torch.float64)
# in get items 360
# in get label
# tensor([14.1248], dtype=torch.float64)
# in get items 361
# in get label
# tensor([-1.6035], dtype=torch.float64)
# in get items 362
# in get label
# tensor([0.5908], dtype=torch.float64)
# in get items 363
# in get label
# tensor([1.], dtype=torch.float64)
# in get items 364
# in get label
# tensor([-1.0481], dtype=torch.float64)
# in get items 365
# in get label
# tensor([10.3696], dtype=torch.float64)
# in get items 366
# in get label
# tensor([9.4367], dtype=torch.float64)
# in get items 367
# in get label
# tensor([-0.7366], dtype=torch.float64)
# in get items 368
# in get label
# tensor([-0.3427], dtype=torch.float64)
# in get items 369
# in get label
# tensor([0.4563], dtype=torch.float64)
# in get items 370
# in get label
# tensor([3.8074], dtype=torch.float64)
# in get items 371
# in get label
# tensor([3.3219], dtype=torch.float64)
# in get items 372
# in get label
# tensor([-0.6045], dtype=torch.float64)
# in get items 373
# in get label
# tensor([7.9614], dtype=torch.float64)
# in get items 374
# in get label
# tensor([12.0566], dtype=torch.float64)
# in get items 375
# in get label
# tensor([4.1468], dtype=torch.float64)
# in get items 376
# in get label
# tensor([2.9251], dtype=torch.float64)
# in get items 377
# in get label
# tensor([9.3966], dtype=torch.float64)
# in get items 378
# in get label
# tensor([-0.7636], dtype=torch.float64)
# in get items 379
# in get label
# tensor([8.5986], dtype=torch.float64)
# in get items 380
# in get label
# tensor([7.1741], dtype=torch.float64)
# in get items 381
# in get label
# tensor([1.2224], dtype=torch.float64)
# in get items 382
# in get label
# tensor([9.5666], dtype=torch.float64)
# in get items 383
# in get label
# tensor([-0.2627], dtype=torch.float64)
# in get items 384
# in get label
# tensor([0.5163], dtype=torch.float64)
# in get items 385
# in get label
# tensor([10.6222], dtype=torch.float64)
# in get items 386
# in get label
# tensor([1.7546], dtype=torch.float64)
# in get items 387
# in get label
# tensor([1.6395], dtype=torch.float64)
# in get items 388
# in get label
# tensor([5.1293], dtype=torch.float64)
# in get items 389
# in get label
# tensor([-0.7075], dtype=torch.float64)
# in get items 390
# in get label
# tensor([3.5063], dtype=torch.float64)
# in get items 391
# in get label
# tensor([8.9513], dtype=torch.float64)
# in get items 392
# in get label
# tensor([-0.0345], dtype=torch.float64)
# in get items 393
# in get label
# tensor([1.2374], dtype=torch.float64)
# in get items 394
# in get label
# tensor([-0.7759], dtype=torch.float64)
# in get items 395
# in get label
# tensor([1.2153], dtype=torch.float64)
# in get items 396
# in get label
# tensor([-1.9509], dtype=torch.float64)
# in get items 397
# in get label
# tensor([-1.0150], dtype=torch.float64)
# in get items 398
# in get label
# tensor([-3.7830], dtype=torch.float64)
# in get items 399
# in get label
# tensor([1.4627], dtype=torch.float64)
# in get items 400
# in get label
# tensor([1.1213], dtype=torch.float64)
# in get items 401
# in get label
# tensor([0.9260], dtype=torch.float64)
# in get items 402
# in get label
# tensor([5.1001], dtype=torch.float64)
# in get items 403
# in get label
# tensor([-1.4281], dtype=torch.float64)
# in get items 404
# in get label
# tensor([-1.9935], dtype=torch.float64)
# in get items 405
# in get label
# tensor([12.0035], dtype=torch.float64)
# in get items 406
# in get label
# tensor([1.0355], dtype=torch.float64)
# in get items 407
# in get label
# tensor([9.5115], dtype=torch.float64)
# in get items 408
# in get label
# tensor([7.9307], dtype=torch.float64)
# in get items 409
# in get label
# tensor([-5.3490], dtype=torch.float64)
# in get items 410
# in get label
# tensor([1.3791], dtype=torch.float64)
# in get items 411
# in get label
# tensor([1.4495], dtype=torch.float64)
# in get items 412
# in get label
# tensor([-1.5850], dtype=torch.float64)
# in get items 413
# in get label
# tensor([7.2975], dtype=torch.float64)
# in get items 414
# in get label
# tensor([6.5363], dtype=torch.float64)
# in get items 415
# in get label
# tensor([-4.4594], dtype=torch.float64)
# in get items 416
# in get label
# tensor([4.9542], dtype=torch.float64)
# in get items 417
# in get label
# tensor([-0.7032], dtype=torch.float64)
# in get items 418
# in get label
# tensor([-0.7441], dtype=torch.float64)
# in get items 419
# in get label
# tensor([-1.1980], dtype=torch.float64)
# in get items 420
# in get label
# tensor([-0.5111], dtype=torch.float64)
# in get items 421
# in get label
# tensor([-0.4928], dtype=torch.float64)
# in get items 422
# in get label
# tensor([5.4465], dtype=torch.float64)
# in get items 423
# in get label
# tensor([1.0980], dtype=torch.float64)
# in get items 424
# in get label
# tensor([10.1267], dtype=torch.float64)
# in get items 425
# in get label
# tensor([-1.6352], dtype=torch.float64)
# in get items 426
# in get label
# tensor([-1.1164], dtype=torch.float64)
# in get items 427
# in get label
# tensor([5.9773], dtype=torch.float64)
# in get items 428
# in get label
# tensor([6.3458], dtype=torch.float64)
# in get items 429
# in get label
# tensor([3.5655], dtype=torch.float64)
# in get items 430
# in get label
# tensor([8.7427], dtype=torch.float64)
# in get items 431
# in get label
# tensor([0.4750], dtype=torch.float64)
# in get items 432
# in get label
# tensor([0.3854], dtype=torch.float64)
# in get items 433
# in get label
# tensor([0.9483], dtype=torch.float64)
# in get items 434
# in get label
# tensor([3.9786], dtype=torch.float64)
# in get items 435
# in get label
# tensor([-1.4404], dtype=torch.float64)
# in get items 436
# in get label
# tensor([0.4732], dtype=torch.float64)
# in get items 437
# in get label
# tensor([0.9700], dtype=torch.float64)
# in get items 438
# in get label
# tensor([-9.8106], dtype=torch.float64)
# in get items 439
# in get label
# tensor([1.7370], dtype=torch.float64)
# in get items 440
# in get label
# tensor([3.0593], dtype=torch.float64)
# in get items 441
# in get label
# tensor([4.5015], dtype=torch.float64)
# in get items 442
# in get label
# tensor([-3.9366], dtype=torch.float64)
# in get items 443
# in get label
# tensor([-3.7289], dtype=torch.float64)
# in get items 444
# in get label
# tensor([-4.8536], dtype=torch.float64)
# in get items 445
# in get label
# tensor([1.1692], dtype=torch.float64)
# in get items 446
# in get label
# tensor([-5.8346], dtype=torch.float64)
# in get items 447
# in get label
# tensor([1.6546], dtype=torch.float64)
# in get items 448
# in get label
# tensor([0.7738], dtype=torch.float64)
# in get items 449
# in get label
# tensor([-1.7085], dtype=torch.float64)
# in get items 450
# in get label
# tensor([-0.3857], dtype=torch.float64)
# in get items 451
# in get label
# tensor([-0.2778], dtype=torch.float64)
# in get items 452
# in get label
# tensor([3.5934], dtype=torch.float64)
# in get items 453
# in get label
# tensor([9.1293], dtype=torch.float64)
# in get items 454
# in get label
# tensor([0.0227], dtype=torch.float64)
# in get items 455
# in get label
# tensor([0.9530], dtype=torch.float64)
# in get items 456
# in get label
# tensor([0.9952], dtype=torch.float64)
# in get items 457
# in get label
# tensor([3.8074], dtype=torch.float64)
# in get items 458
# in get label
# tensor([-0.4180], dtype=torch.float64)
# in get items 459
# in get label
# tensor([5.0073], dtype=torch.float64)
# in get items 460
# in get label
# tensor([-0.9663], dtype=torch.float64)
# in get items 461
# in get label
# tensor([0.1813], dtype=torch.float64)
# in get items 462
# in get label
# tensor([10.8197], dtype=torch.float64)
# in get items 463
# in get label
# tensor([2.1725], dtype=torch.float64)
# in get items 464
# in get label
# tensor([12.3496], dtype=torch.float64)
# in get items 465
# in get label
# tensor([-0.7010], dtype=torch.float64)
# in get items 466
# in get label
# tensor([-1.1671], dtype=torch.float64)
# in get items 467
# in get label
# tensor([-0.5850], dtype=torch.float64)
# in get items 468
# in get label
# tensor([6.4012], dtype=torch.float64)
# in get items 469
# in get label
# tensor([-0.6578], dtype=torch.float64)
# in get items 470
# in get label
# tensor([3.3219], dtype=torch.float64)
# in get items 471
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 472
# in get label
# tensor([1.1379], dtype=torch.float64)
# in get items 473
# in get label
# tensor([7.2192], dtype=torch.float64)
# in get items 474
# in get label
# tensor([-0.3496], dtype=torch.float64)
# in get items 475
# in get label
# tensor([-0.9129], dtype=torch.float64)
# in get items 476
# in get label
# tensor([-0.7904], dtype=torch.float64)
# in get items 477
# in get label
# tensor([-0.2036], dtype=torch.float64)
# in get items 478
# in get label
# tensor([-1.5850], dtype=torch.float64)
# in get items 479
# in get label
# tensor([-3.0237], dtype=torch.float64)
# in get items 480
# in get label
# tensor([-1.2756], dtype=torch.float64)
# in get items 481
# in get label
# tensor([-1.4455], dtype=torch.float64)
# in get items 482
# in get label
# tensor([-0.7172], dtype=torch.float64)
# in get items 483
# in get label
# tensor([-5.4634], dtype=torch.float64)
# in get items 484
# in get label
# tensor([-1.5934], dtype=torch.float64)
# in get items 485
# in get label
# tensor([-2.3661], dtype=torch.float64)
# in get items 486
# in get label
# tensor([2.3219], dtype=torch.float64)
# in get items 487
# in get label
# tensor([7.6795], dtype=torch.float64)
# in get items 488
# in get label
# tensor([-6.9000], dtype=torch.float64)
# in get items 489
# in get label
# tensor([-0.7323], dtype=torch.float64)
# in get items 490
# in get label
# tensor([-0.4038], dtype=torch.float64)
# in get items 491
# in get label
# tensor([-0.5615], dtype=torch.float64)
# in get items 492
# in get label
# tensor([2.3219], dtype=torch.float64)
# in get items 493
# in get label
# tensor([2.7676], dtype=torch.float64)
# in get items 494
# in get label
# tensor([-0.0608], dtype=torch.float64)
# in get items 495
# in get label
# tensor([1.5850], dtype=torch.float64)
# in get items 496
# in get label
# tensor([12.2715], dtype=torch.float64)
# in get items 497
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 498
# in get label
# tensor([0.4996], dtype=torch.float64)
# in get items 499
# in get label
# tensor([-1.7675], dtype=torch.float64)
# in get items 500
# in get label
# tensor([10.1931], dtype=torch.float64)
# in get items 501
# in get label
# tensor([11.4512], dtype=torch.float64)
# in get items 502
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 503
# in get label
# tensor([-0.2904], dtype=torch.float64)
# in get items 504
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 505
# in get label
# tensor([-5.6724], dtype=torch.float64)
# in get items 506
# in get label
# tensor([-0.5436], dtype=torch.float64)
# in get items 507
# in get label
# tensor([2.0315], dtype=torch.float64)
# in get items 508
# in get label
# tensor([0.2865], dtype=torch.float64)
# in get items 509
# in get label
# tensor([-2.5906], dtype=torch.float64)
# in get items 510
# in get label
# tensor([-1.5850], dtype=torch.float64)
# in get items 511
# in get label
# tensor([5.7328], dtype=torch.float64)
# in get items 512
# in get label
# tensor([-0.0782], dtype=torch.float64)
# in get items 513
# in get label
# tensor([-1.4277], dtype=torch.float64)
# in get items 514
# in get label
# tensor([2.2583], dtype=torch.float64)
# in get items 515
# in get label
# tensor([3.7004], dtype=torch.float64)
# in get items 516
# in get label
# tensor([6.1293], dtype=torch.float64)
# in get items 517
# in get label
# tensor([-2.4437], dtype=torch.float64)
# in get items 518
# in get label
# tensor([-0.1993], dtype=torch.float64)
# in get items 519
# in get label
# tensor([-0.7908], dtype=torch.float64)
# in get items 520
# in get label
# tensor([2.2617], dtype=torch.float64)
# in get items 521
# in get label
# tensor([-0.5152], dtype=torch.float64)
# in get items 522
# in get label
# tensor([-2.1837], dtype=torch.float64)
# in get items 523
# in get label
# tensor([1.9759], dtype=torch.float64)
# in get items 524
# in get label
# tensor([0.1433], dtype=torch.float64)
# in get items 525
# in get label
# tensor([-0.7573], dtype=torch.float64)
# in get items 526
# in get label
# tensor([-2.1144], dtype=torch.float64)
# in get items 527
# in get label
# tensor([0.5299], dtype=torch.float64)
# in get items 528
# in get label
# tensor([-3.9918], dtype=torch.float64)
# in get items 529
# in get label
# tensor([14.7485], dtype=torch.float64)
# in get items 530
# in get label
# tensor([-3.4789], dtype=torch.float64)
# in get items 531
# in get label
# tensor([-4.2415], dtype=torch.float64)
# in get items 532
# in get label
# tensor([7.1898], dtype=torch.float64)
# in get items 533
# in get label
# tensor([-3.0809], dtype=torch.float64)
# in get items 534
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 535
# in get label
# tensor([4.0875], dtype=torch.float64)
# in get items 536
# in get label
# tensor([-1.9570], dtype=torch.float64)
# in get items 537
# in get label
# tensor([8.1443], dtype=torch.float64)
# in get items 538
# in get label
# tensor([0.6781], dtype=torch.float64)
# in get items 539
# in get label
# tensor([-0.8544], dtype=torch.float64)
# in get items 540
# in get label
# tensor([-3.0930], dtype=torch.float64)
# in get items 541
# in get label
# tensor([-0.9038], dtype=torch.float64)
# in get items 542
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 543
# in get label
# tensor([5.3646], dtype=torch.float64)
# in get items 544
# in get label
# tensor([5.3923], dtype=torch.float64)
# in get items 545
# in get label
# tensor([2.], dtype=torch.float64)
# in get items 546
# in get label
# tensor([0.8099], dtype=torch.float64)
# in get items 547
# in get label
# tensor([-1.9180], dtype=torch.float64)
# in get items 548
# in get label
# tensor([1.1804], dtype=torch.float64)
# in get items 549
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 550
# in get label
# tensor([-1.3535], dtype=torch.float64)
# in get items 551
# in get label
# tensor([-0.6151], dtype=torch.float64)
# in get items 552
# in get label
# tensor([-4.2310], dtype=torch.float64)
# in get items 553
# in get label
# tensor([-2.5014], dtype=torch.float64)
# in get items 554
# in get label
# tensor([3.4594], dtype=torch.float64)
# in get items 555
# in get label
# tensor([-1.2730], dtype=torch.float64)
# in get items 556
# in get label
# tensor([11.7364], dtype=torch.float64)
# in get items 557
# in get label
# tensor([8.5138], dtype=torch.float64)
# in get items 558
# in get label
# tensor([-3.7898], dtype=torch.float64)
# in get items 559
# in get label
# tensor([2.2033], dtype=torch.float64)
# in get items 560
# in get label
# tensor([-3.6196], dtype=torch.float64)
# in get items 561
# in get label
# tensor([-0.3362], dtype=torch.float64)
# in get items 562
# in get label
# tensor([1.3479], dtype=torch.float64)
# in get items 563
# in get label
# tensor([1.5850], dtype=torch.float64)
# in get items 564
# in get label
# tensor([-2.5850], dtype=torch.float64)
# in get items 565
# in get label
# tensor([2.4037], dtype=torch.float64)
# in get items 566
# in get label
# tensor([-3.1699], dtype=torch.float64)
# in get items 567
# in get label
# tensor([5.5106], dtype=torch.float64)
# in get items 568
# in get label
# tensor([-2.0297], dtype=torch.float64)
# in get items 569
# in get label
# tensor([1.3176], dtype=torch.float64)
# in get items 570
# in get label
# tensor([0.9697], dtype=torch.float64)
# in get items 571
# in get label
# tensor([0.8480], dtype=torch.float64)
# in get items 572
# in get label
# tensor([0.8697], dtype=torch.float64)
# in get items 573
# in get label
# tensor([4.9505], dtype=torch.float64)
# in get items 574
# in get label
# tensor([12.8279], dtype=torch.float64)
# in get items 575
# in get label
# tensor([-0.4755], dtype=torch.float64)
# in get items 576
# in get label
# tensor([-0.8766], dtype=torch.float64)
# in get items 577
# in get label
# tensor([2.], dtype=torch.float64)
# in get items 578
# in get label
# tensor([-0.3371], dtype=torch.float64)
# in get items 579
# in get label
# tensor([0.9972], dtype=torch.float64)
# in get items 580
# in get label
# tensor([-0.6348], dtype=torch.float64)
# in get items 581
# in get label
# tensor([-3.5625], dtype=torch.float64)
# in get items 582
# in get label
# tensor([-2.2977], dtype=torch.float64)
# in get items 583
# in get label
# tensor([-1.2449], dtype=torch.float64)
# in get items 584
# in get label
# tensor([-1.0895], dtype=torch.float64)
# in get items 585
# in get label
# tensor([12.2535], dtype=torch.float64)
# in get items 586
# in get label
# tensor([9.1724], dtype=torch.float64)
# in get items 587
# in get label
# tensor([0.0477], dtype=torch.float64)
# in get items 588
# in get label
# tensor([0.0136], dtype=torch.float64)
# in get items 589
# in get label
# tensor([-0.9714], dtype=torch.float64)
# in get items 590
# in get label
# tensor([3.0734], dtype=torch.float64)
# in get items 591
# in get label
# tensor([2.1788], dtype=torch.float64)
# in get items 592
# in get label
# tensor([-0.4410], dtype=torch.float64)
# in get items 593
# in get label
# tensor([-1.2636], dtype=torch.float64)
# in get items 594
# in get label
# tensor([-3.2224], dtype=torch.float64)
# in get items 595
# in get label
# tensor([8.9844], dtype=torch.float64)
# in get items 596
# in get label
# tensor([1.1926], dtype=torch.float64)
# in get items 597
# in get label
# tensor([11.1235], dtype=torch.float64)
# in get items 598
# in get label
# tensor([-1.7000], dtype=torch.float64)
# in get items 599
# in get label
# tensor([5.7049], dtype=torch.float64)
# in get items 600
# in get label
# tensor([-2.3124], dtype=torch.float64)
# in get items 601
# in get label
# tensor([-0.9048], dtype=torch.float64)
# in get items 602
# in get label
# tensor([-4.8074], dtype=torch.float64)
# in get items 603
# in get label
# tensor([-0.0355], dtype=torch.float64)
# in get items 604
# in get label
# tensor([-3.0337], dtype=torch.float64)
# in get items 605
# in get label
# tensor([4.9634], dtype=torch.float64)
# in get items 606
# in get label
# tensor([-1.6657], dtype=torch.float64)
# in get items 607
# in get label
# tensor([-6.9944], dtype=torch.float64)
# in get items 608
# in get label
# tensor([0.3112], dtype=torch.float64)
# in get items 609
# in get label
# tensor([-0.5337], dtype=torch.float64)
# in get items 610
# in get label
# tensor([-0.4105], dtype=torch.float64)
# in get items 611
# in get label
# tensor([9.9233], dtype=torch.float64)
# in get items 612
# in get label
# tensor([-0.7916], dtype=torch.float64)
# in get items 613
# in get label
# tensor([4.9131], dtype=torch.float64)
# in get items 614
# in get label
# tensor([13.6414], dtype=torch.float64)
# in get items 615
# in get label
# tensor([12.8186], dtype=torch.float64)
# in get items 616
# in get label
# tensor([-0.2009], dtype=torch.float64)
# in get items 617
# in get label
# tensor([0.6170], dtype=torch.float64)
# in get items 618
# in get label
# tensor([-2.1849], dtype=torch.float64)
# in get items 619
# in get label
# tensor([-0.8676], dtype=torch.float64)
# in get items 620
# in get label
# tensor([-0.5161], dtype=torch.float64)
# in get items 621
# in get label
# tensor([1.2477], dtype=torch.float64)
# in get items 622
# in get label
# tensor([-0.0914], dtype=torch.float64)
# in get items 623
# in get label
# tensor([11.0319], dtype=torch.float64)
# in get items 624
# in get label
# tensor([0.0142], dtype=torch.float64)
# in get items 625
# in get label
# tensor([12.7855], dtype=torch.float64)
# in get items 626
# in get label
# tensor([0.2630], dtype=torch.float64)
# in get items 627
# in get label
# tensor([8.4402], dtype=torch.float64)
# in get items 628
# in get label
# tensor([-0.3016], dtype=torch.float64)
# in get items 629
# in get label
# tensor([4.3923], dtype=torch.float64)
# in get items 630
# in get label
# tensor([0.2230], dtype=torch.float64)
# in get items 631
# in get label
# tensor([0.0688], dtype=torch.float64)
# in get items 632
# in get label
# tensor([10.4846], dtype=torch.float64)
# in get items 633
# in get label
# tensor([-1.7609], dtype=torch.float64)
# in get items 634
# in get label
# tensor([-1.1550], dtype=torch.float64)
# in get items 635
# in get label
# tensor([-2.2102], dtype=torch.float64)
# in get items 636
# in get label
# tensor([-0.8892], dtype=torch.float64)
# in get items 637
# in get label
# tensor([-0.9080], dtype=torch.float64)
# in get items 638
# in get label
# tensor([-6.0909], dtype=torch.float64)
# in get items 639
# in get label
# tensor([-1.6895], dtype=torch.float64)
# in get items 640
# in get label
# tensor([1.2304], dtype=torch.float64)
# in get items 641
# in get label
# tensor([2.1343], dtype=torch.float64)
# in get items 642
# in get label
# tensor([9.9514], dtype=torch.float64)
# in get items 643
# in get label
# tensor([13.6129], dtype=torch.float64)
# in get items 644
# in get label
# tensor([0.7707], dtype=torch.float64)
# in get items 645
# in get label
# tensor([0.4157], dtype=torch.float64)
# in get items 646
# in get label
# tensor([6.8547], dtype=torch.float64)
# in get items 647
# in get label
# tensor([-2.0286], dtype=torch.float64)
# in get items 648
# in get label
# tensor([10.3904], dtype=torch.float64)
# in get items 649
# in get label
# tensor([-2.2092], dtype=torch.float64)
# in get items 650
# in get label
# tensor([-1.5400], dtype=torch.float64)
# in get items 651
# in get label
# tensor([-0.7004], dtype=torch.float64)
# in get items 652
# in get label
# tensor([9.0713], dtype=torch.float64)
# in get items 653
# in get label
# tensor([2.3219], dtype=torch.float64)
# in get items 654
# in get label
# tensor([1.2623], dtype=torch.float64)
# in get items 655
# in get label
# tensor([-0.2444], dtype=torch.float64)
# in get items 656
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 657
# in get label
# tensor([5.1619], dtype=torch.float64)
# in get items 658
# in get label
# tensor([0.7563], dtype=torch.float64)
# in get items 659
# in get label
# tensor([-1.2924], dtype=torch.float64)
# in get items 660
# in get label
# tensor([3.4753], dtype=torch.float64)
# in get items 661
# in get label
# tensor([10.8696], dtype=torch.float64)
# in get items 662
# in get label
# tensor([-1.9997], dtype=torch.float64)
# in get items 663
# in get label
# tensor([-1.5090], dtype=torch.float64)
# in get items 664
# in get label
# tensor([1.], dtype=torch.float64)
# in get items 665
# in get label
# tensor([1.8922], dtype=torch.float64)
# in get items 666
# in get label
# tensor([1.0189], dtype=torch.float64)
# in get items 667
# in get label
# tensor([-1.0914], dtype=torch.float64)
# in get items 668
# in get label
# tensor([1.7643], dtype=torch.float64)
# in get items 669
# in get label
# tensor([-2.9535], dtype=torch.float64)
# in get items 670
# in get label
# tensor([-1.], dtype=torch.float64)
# in get items 671
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 672
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 673
# in get label
# tensor([-1.5388], dtype=torch.float64)
# in get items 674
# in get label
# tensor([-1.5629], dtype=torch.float64)
# in get items 675
# in get label
# tensor([8.0531], dtype=torch.float64)
# in get items 676
# in get label
# tensor([-2.3896], dtype=torch.float64)
# in get items 677
# in get label
# tensor([0.4745], dtype=torch.float64)
# in get items 678
# in get label
# tensor([0.1015], dtype=torch.float64)
# in get items 679
# in get label
# tensor([10.6266], dtype=torch.float64)
# in get items 680
# in get label
# tensor([-1.2518], dtype=torch.float64)
# in get items 681
# in get label
# tensor([-0.5475], dtype=torch.float64)
# in get items 682
# in get label
# tensor([6.8512], dtype=torch.float64)
# in get items 683
# in get label
# tensor([8.9248], dtype=torch.float64)
# in get items 684
# in get label
# tensor([-0.8648], dtype=torch.float64)
# in get items 685
# in get label
# tensor([0.5193], dtype=torch.float64)
# in get items 686
# in get label
# tensor([1.3193], dtype=torch.float64)
# in get items 687
# in get label
# tensor([-1.4398], dtype=torch.float64)
# in get items 688
# in get label
# tensor([7.4873], dtype=torch.float64)
# in get items 689
# in get label
# tensor([-3.0004], dtype=torch.float64)
# in get items 690
# in get label
# tensor([12.5990], dtype=torch.float64)
# in get items 691
# in get label
# tensor([1.4184], dtype=torch.float64)
# in get items 692
# in get label
# tensor([-1.2783], dtype=torch.float64)
# in get items 693
# in get label
# tensor([0.0582], dtype=torch.float64)
# in get items 694
# in get label
# tensor([-1.1525], dtype=torch.float64)
# in get items 695
# in get label
# tensor([-0.7370], dtype=torch.float64)
# in get items 696
# in get label
# tensor([0.7370], dtype=torch.float64)
# in get items 697
# in get label
# tensor([3.0444], dtype=torch.float64)
# in get items 698
# in get label
# tensor([-7.7699], dtype=torch.float64)
# in get items 699
# in get label
# tensor([0.0955], dtype=torch.float64)
# in get items 700
# in get label
# tensor([-2.7004], dtype=torch.float64)
# in get items 701
# in get label
# tensor([-0.5850], dtype=torch.float64)
# in get items 702
# in get label
# tensor([7.6977], dtype=torch.float64)
# in get items 703
# in get label
# tensor([-0.7770], dtype=torch.float64)
# in get items 704
# ...
# in get items 3795
# in get label
# tensor([4.0199], dtype=torch.float64)
# in get items 3796
# in get label
# tensor([12.3987], dtype=torch.float64)
# in get items 3797
# in get label
# tensor([-1.5331], dtype=torch.float64)
# in get items 3798
# in get label
# tensor([-1.3359], dtype=torch.float64)
# in get items 3799
# in get label
# tensor([-2.3063], dtype=torch.float64)
# in get items 3800
# in get label
# tensor([0.1464], dtype=torch.float64)
# in get items 3801
# in get label
# tensor([-0.5455], dtype=torch.float64)
# in get items 3802
# in get label
# tensor([-0.9599], dtype=torch.float64)
# in get items 3803
# in get label
# tensor([0.0262], dtype=torch.float64)
# in get items 3804
# in get label
# tensor([-2.3432], dtype=torch.float64)
# in get items 3805
# in get label
# tensor([-0.4147], dtype=torch.float64)
# in get items 3806
# in get label
# tensor([4.3219], dtype=torch.float64)
# in get items 3807
# in get label
# tensor([-1.6640], dtype=torch.float64)
# in get items 3808
# in get label
# tensor([-0.4979], dtype=torch.float64)
# in get items 3809
# in get label
# tensor([-0.1491], dtype=torch.float64)
# in get items 3810
# in get label
# tensor([-2.3763], dtype=torch.float64)
# in get items 3811
# in get label
# tensor([8.6877], dtype=torch.float64)
# in get items 3812
# in get label
# tensor([12.9194], dtype=torch.float64)
# in get items 3813
# in get label
# tensor([8.1202], dtype=torch.float64)
# in get items 3814
# in get label
# tensor([3.], dtype=torch.float64)
# in get items 3815
# in get label
# tensor([-0.8335], dtype=torch.float64)
# in get items 3816
# in get label
# tensor([2.5850], dtype=torch.float64)
# in get items 3817
# in get label
# tensor([-2.4594], dtype=torch.float64)
# in get items 3818
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 3819
# in get label
# tensor([2.8580], dtype=torch.float64)
# in get items 3820
# in get label
# tensor([-0.4766], dtype=torch.float64)
# in get items 3821
# in get label
# tensor([-1.1932], dtype=torch.float64)
# in get items 3822
# in get label
# tensor([-0.9672], dtype=torch.float64)
# in get items 3823
# in get label
# tensor([5.4727], dtype=torch.float64)
# in get items 3824
# in get label
# tensor([-0.2638], dtype=torch.float64)
# in get items 3825
# in get label
# tensor([9.1948], dtype=torch.float64)
# in get items 3826
# in get label
# tensor([1.8731], dtype=torch.float64)
# in get items 3827
# in get label
# tensor([-6.9488], dtype=torch.float64)
# in get items 3828
# in get label
# tensor([1.4216], dtype=torch.float64)
# in get items 3829
# in get label
# tensor([2.2876], dtype=torch.float64)
# in get items 3830
# in get label
# tensor([1.3853], dtype=torch.float64)
# in get items 3831
# in get label
# tensor([10.4367], dtype=torch.float64)
# in get items 3832
# in get label
# tensor([3.4491], dtype=torch.float64)
# in get items 3833
# in get label
# tensor([4.6724], dtype=torch.float64)
# in get items 3834
# in get label
# tensor([5.1935], dtype=torch.float64)
# in get items 3835
# in get label
# tensor([-2.3771], dtype=torch.float64)
# in get items 3836
# in get label
# tensor([-0.9872], dtype=torch.float64)
# in get items 3837
# in get label
# tensor([2.3219], dtype=torch.float64)
# in get items 3838
# in get label
# tensor([3.9386], dtype=torch.float64)
# in get items 3839
# in get label
# tensor([-1.6189], dtype=torch.float64)
# in get items 3840
# in get label
# tensor([5.1028], dtype=torch.float64)
# in get items 3841
# in get label
# tensor([6.3486], dtype=torch.float64)
# in get items 3842
# in get label
# tensor([0.3705], dtype=torch.float64)
# in get items 3843
# in get label
# tensor([-1.1812], dtype=torch.float64)
# in get items 3844
# in get label
# tensor([2.4653], dtype=torch.float64)
# in get items 3845
# in get label
# tensor([1.4448], dtype=torch.float64)
# in get items 3846
# in get label
# tensor([0.3440], dtype=torch.float64)
# in get items 3847
# in get label
# tensor([-1.5596], dtype=torch.float64)
# in get items 3848
# in get label
# tensor([-1.0444], dtype=torch.float64)
# in get items 3849
# in get label
# tensor([-1.7591], dtype=torch.float64)
# in get items 3850
# in get label
# tensor([1.9268], dtype=torch.float64)
# in get items 3851
# in get label
# tensor([6.1134], dtype=torch.float64)
# in get items 3852
# in get label
# tensor([-0.4921], dtype=torch.float64)
# in get items 3853
# in get label
# tensor([5.4594], dtype=torch.float64)
# in get items 3854
# in get label
# tensor([-4.1496], dtype=torch.float64)
# in get items 3855
# in get label
# tensor([-0.7370], dtype=torch.float64)
# in get items 3856
# in get label
# tensor([-1.5088], dtype=torch.float64)
# in get items 3857
# in get label
# tensor([3.8258], dtype=torch.float64)
# in get items 3858
# in get label
# tensor([8.0444], dtype=torch.float64)
# in get items 3859
# in get label
# tensor([-0.4104], dtype=torch.float64)
# in get items 3860
# in get label
# tensor([-1.1188], dtype=torch.float64)
# in get items 3861
# in get label
# tensor([-2.0236], dtype=torch.float64)
# in get items 3862
# in get label
# tensor([6.5392], dtype=torch.float64)
# in get items 3863
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 3864
# in get label
# tensor([-1.3003], dtype=torch.float64)
# in get items 3865
# in get label
# tensor([-1.6727], dtype=torch.float64)
# in get items 3866
# in get label
# tensor([-1.5120], dtype=torch.float64)
# in get items 3867
# in get label
# tensor([1.8745], dtype=torch.float64)
# in get items 3868
# in get label
# tensor([-2.5850], dtype=torch.float64)
# in get items 3869
# in get label
# tensor([2.], dtype=torch.float64)
# in get items 3870
# in get label
# tensor([1.], dtype=torch.float64)
# in get items 3871
# in get label
# tensor([-4.0478], dtype=torch.float64)
# in get items 3872
# in get label
# tensor([-0.1918], dtype=torch.float64)
# in get items 3873
# in get label
# tensor([-0.9101], dtype=torch.float64)
# in get items 3874
# in get label
# tensor([-1.0073], dtype=torch.float64)
# in get items 3875
# in get label
# tensor([-1.4970], dtype=torch.float64)
# in get items 3876
# in get label
# tensor([6.5454], dtype=torch.float64)
# in get items 3877
# in get label
# tensor([-2.3692], dtype=torch.float64)
# in get items 3878
# in get label
# tensor([3.0200], dtype=torch.float64)
# in get items 3879
# in get label
# tensor([-0.7214], dtype=torch.float64)
# in get items 3880
# in get label
# tensor([3.3219], dtype=torch.float64)
# in get items 3881
# in get label
# tensor([-0.7108], dtype=torch.float64)
# in get items 3882
# in get label
# tensor([-0.4703], dtype=torch.float64)
# in get items 3883
# in get label
# tensor([0.1749], dtype=torch.float64)
# in get items 3884
# in get label
# tensor([0.0050], dtype=torch.float64)
# in get items 3885
# in get label
# tensor([-3.1104], dtype=torch.float64)
# in get items 3886
# in get label
# tensor([-0.2313], dtype=torch.float64)
# in get items 3887
# in get label
# tensor([8.8361], dtype=torch.float64)
# in get items 3888
# in get label
# tensor([-0.8635], dtype=torch.float64)
# in get items 3889
# in get label
# tensor([1.], dtype=torch.float64)
# in get items 3890
# in get label
# tensor([-1.8487], dtype=torch.float64)
# in get items 3891
# in get label
# tensor([3.8624], dtype=torch.float64)
# in get items 3892
# in get label
# tensor([2.3735], dtype=torch.float64)
# in get items 3893
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 3894
# in get label
# tensor([8.7124], dtype=torch.float64)
# in get items 3895
# in get label
# tensor([0.7957], dtype=torch.float64)
# in get items 3896
# in get label
# tensor([-0.3948], dtype=torch.float64)
# in get items 3897
# in get label
# tensor([3.3210], dtype=torch.float64)
# in get items 3898
# in get label
# tensor([5.2574], dtype=torch.float64)
# in get items 3899
# in get label
# tensor([2.0103], dtype=torch.float64)
# in get items 3900
# in get label
# tensor([0.5298], dtype=torch.float64)
# in get items 3901
# in get label
# tensor([-0.9443], dtype=torch.float64)
# in get items 3902
# in get label
# tensor([0.0293], dtype=torch.float64)
# in get items 3903
# in get label
# tensor([0.3409], dtype=torch.float64)
# in get items 3904
# in get label
# tensor([0.3882], dtype=torch.float64)
# in get items 3905
# in get label
# tensor([3.6783], dtype=torch.float64)
# in get items 3906
# in get label
# tensor([3.1606], dtype=torch.float64)
# in get items 3907
# in get label
# tensor([-0.0495], dtype=torch.float64)
# in get items 3908
# in get label
# tensor([-2.3986], dtype=torch.float64)
# in get items 3909
# in get label
# tensor([0.4406], dtype=torch.float64)
# in get items 3910
# in get label
# tensor([0.], dtype=torch.float64)
# in get items 3911
# in get label
# tensor([0.9313], dtype=torch.float64)
# in get items 3912
# in get label
# tensor([-3.6174], dtype=torch.float64)
# in get items 3913
# in get label
# tensor([-0.1832], dtype=torch.float64)
# in get items 3914
# in get label
# tensor([0.3759], dtype=torch.float64)
# in get items 3915
# in get label
# tensor([-0.7141], dtype=torch.float64)
# in get items 3916
# in get label
# tensor([-1.7906], dtype=torch.float64)
# in get items 3917
# in get label
# tensor([-0.6215], dtype=torch.float64)
# in get items 3918
# in get label
# tensor([-2.6674], dtype=torch.float64)
# in get items 3919
# in get label
# tensor([2.5405], dtype=torch.float64)
# in get items 3920
# in get label
# tensor([-0.6674], dtype=torch.float64)
# in get items 3921
# in get label
# tensor([0.0529], dtype=torch.float64)
# in get items 3922
# in get label
# tensor([-0.0006], dtype=torch.float64)
# in get items 3923
# in get label
# tensor([5.3974], dtype=torch.float64)
# in get items 3924
# in get label
# tensor([-0.4456], dtype=torch.float64)
# in get items 3925
# in get label
# tensor([3.4019], dtype=torch.float64)
# in get items 3926
# in get label
# tensor([1.4418], dtype=torch.float64)
# in get items 3927
# in get label
# tensor([0.4391], dtype=torch.float64)
# in get items 3928
# in get label
# tensor([0.9982], dtype=torch.float64)
# in get items 3929
# in get label
# tensor([-0.6320], dtype=torch.float64)
# in get items 3930
# in get label
# tensor([-0.1211], dtype=torch.float64)
# in get items 3931
# in get label
# tensor([7.4510], dtype=torch.float64)
# in get items 3932
# in get label
# tensor([9.2946], dtype=torch.float64)
# in get items 3933
# in get label
# tensor([3.0969], dtype=torch.float64)
# in get items 3934
# in get label
# tensor([2.5850], dtype=torch.float64)
# in get items 3935
# in get label
# tensor([-0.4150], dtype=torch.float64)
# in get items 3936
# in get label
# tensor([-1.5305], dtype=torch.float64)
# in get items 3937
# in get label
# tensor([-10.0375], dtype=torch.float64)
# in get items 3938
# in get label
# tensor([2.3720], dtype=torch.float64)
# in get items 3939
# in get label
# tensor([2.4393], dtype=torch.float64)
# in get items 3940
# in get label
# tensor([9.7817], dtype=torch.float64)
# in get items 3941
# in get label
# tensor([-1.3031], dtype=torch.float64)
# in get items 3942
# in get label
# tensor([0.0377], dtype=torch.float64)
# in get items 3943
# in get label
# tensor([-0.4285], dtype=torch.float64)
# in get items 3944
# in get label
# tensor([0.6107], dtype=torch.float64)
# in get items 3945
# in get label
# tensor([-0.0963], dtype=torch.float64)
# in get items 3946
# in get label
# tensor([-1.], dtype=torch.float64)
# in get items 3947
# in get label
# tensor([0.3349], dtype=torch.float64)
# in get items 3948
# in get label
# tensor([0.8985], dtype=torch.float64)
# in get items 3949
# in get label
# tensor([-0.9582], dtype=torch.float64)
# in get items 3950
# in get label
# tensor([-1.1651], dtype=torch.float64)
# in get items 3951
# in get label
# tensor([0.8878], dtype=torch.float64)
# in get items 3952
# in get label
# tensor([-0.0688], dtype=torch.float64)
# in get items 3953
# in get label
# tensor([-2.8412], dtype=torch.float64)
# in get items 3954
# in get label
# tensor([-0.2487], dtype=torch.float64)
# in get items 3955
# in get label
# tensor([-6.0167], dtype=torch.float64)
# in get items 3956
# in get label
# tensor([-1.1322], dtype=torch.float64)
# in get items 3957
# in get label
# tensor([1.7423], dtype=torch.float64)
# in get items 3958
# in get label
# tensor([1.], dtype=torch.float64)
# in get items 3959
# in get label
# tensor([0.3011], dtype=torch.float64)
# in get items 3960
# in get label
# tensor([5.6503], dtype=torch.float64)
# in get items 3961
# in get label
# tensor([-1.7685], dtype=torch.float64)
# in get items 3962
# in get label
# tensor([0.8107], dtype=torch.float64)
# in get items 3963
# in get label
# tensor([-2.2718], dtype=torch.float64)
# in get items 3964
# in get label
# tensor([2.5050], dtype=torch.float64)
# in get items 3965
# in get label
# tensor([1.1533], dtype=torch.float64)
# in get items 3966
# in get label
# tensor([-1.0296], dtype=torch.float64)
# in get items 3967
# in get label
# tensor([3.8786], dtype=torch.float64)
# in get items 3968
# in get label
# tensor([-0.6398], dtype=torch.float64)
# in get items 3969
# in get label
# tensor([0.1213], dtype=torch.float64)
# in get items 3970
# in get label
# tensor([-0.7069], dtype=torch.float64)
# in get items 3971
# in get label
# tensor([-2.0152], dtype=torch.float64)
# in get items 3972
# in get label
# tensor([6.3399], dtype=torch.float64)
# in get items 3973
# in get label
# tensor([-1.7004], dtype=torch.float64)
# in get items 3974
# in get label
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 for x1, x2, y in dataloader1:
#       2     print(y)
#
# File ~\anaconda3\envs\test_env\lib\site-packages\torch\utils\data\dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\anaconda3\envs\test_env\lib\site-packages\torch\utils\data\dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\anaconda3\envs\test_env\lib\site-packages\torch\utils\data\_utils\fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File ~\anaconda3\envs\test_env\lib\site-packages\torch\utils\data\_utils\collate.py:265, in default_collate(batch)
#     204 def default_collate(batch):
#     205     r"""
#     206         Function that takes in a batch of data and puts the elements within the batch
#     207         into a tensor with an additional outer dimension - batch size. The exact output type can be
#    (...)
#     263             >>> default_collate(batch)  # Handle `CustomType` automatically
#     264     """
# --> 265     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File ~\anaconda3\envs\test_env\lib\site-packages\torch\utils\data\_utils\collate.py:142, in collate(batch, collate_fn_map)
#     139 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     141 if isinstance(elem, tuple):
# --> 142     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     143 else:
#     144     try:
#
# File ~\anaconda3\envs\test_env\lib\site-packages\torch\utils\data\_utils\collate.py:142, in <listcomp>(.0)
#     139 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     141 if isinstance(elem, tuple):
# --> 142     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     143 else:
#     144     try:
#
# File ~\anaconda3\envs\test_env\lib\site-packages\torch\utils\data\_utils\collate.py:119, in collate(batch, collate_fn_map)
#     117 if collate_fn_map is not None:
#     118     if elem_type in collate_fn_map:
# --> 119         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     121     for collate_type in collate_fn_map:
#     122         if isinstance(elem, collate_type):
#
# File ~\anaconda3\envs\test_env\lib\site-packages\torch\utils\data\_utils\collate.py:162, in collate_tensor_fn(batch, collate_fn_map)
#     160     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     161     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 162 return torch.stack(batch, 0, out=out)
#
# KeyboardInterrupt:
