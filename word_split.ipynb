# %%
import pandas as pd
import numpy as np

# %%
import json
with open('final_words.json', 'r') as json_file:
    final_dict = json.load(json_file)

# %%
len(final_dict)
# Out:
# 434920

# %%
final_dict
# Out:
# {'bonneville': 54,
#  'jsergobu': 1,
#  'covidguidance': 87,
#  'eczjasnu': 1,
#  'timesupdatedmarch': 79,
#  'fijcc': 1,
#  'fpkhx': 1,
#  'impnlot': 1,
#  'vbhqye': 1,
#  'npeajeng': 1,
#  'egzh': 1,
#  'shtg': 1,
#  'ofdaily': 42,
#  'admissionsshows': 43,
#  'fpnh': 2,
#  'ylzvmgsb': 1,
#  'nhqkwmeg': 1,
#  'haieakq': 1,
#  'latbzpmv': 1,
#  'ecq': 5,
#  'dldpzd': 1,
#  'mllxdw': 1,
#  'ujtylate': 1,
#  'dcnes': 1,
#  'vanx': 1,
#  'reportinghere': 39,
#  'cahalan': 84,
#  'lisa': 159,
#  'waananen': 71,
#  'schoenfeld': 77,
#  'walkerandjosh': 44,
#  'qtcqnsj': 1,
#  'coronavirus': 1825,
#  'byjon': 47,
#  'huang': 136,
#  'jacoby': 54,
#  'johnmichael': 87,
#  'smartandalbert': 46,
#  'ppdyjq': 1,
#  'sxsqe': 1,
#  'qtgzrxs': 1,
#  'ukz': 8,
#  'itselfread': 47,
#  'ohpwcjbz': 1,
#  'vaccineis': 44,
#  'recommendedfor': 45,
#  'usuhno': 1,
#  'jyvgdwa': 1,
#  'qzmgc': 1,
#  'powmw': 1,
#  'xxabxwpj': 1,
#  'eaz': 3,
#  'completevaccinations': 42,
#  'ywyo': 1,
# ...

# %%
[k for k in final_dict if final_dict[k]==1]
# Out:
# ['jsergobu',
#  'eczjasnu',
#  'fijcc',
#  'fpkhx',
#  'impnlot',
#  'vbhqye',
#  'npeajeng',
#  'egzh',
#  'shtg',
#  'ylzvmgsb',
#  'nhqkwmeg',
#  'haieakq',
#  'latbzpmv',
#  'dldpzd',
#  'mllxdw',
#  'ujtylate',
#  'dcnes',
#  'vanx',
#  'qtcqnsj',
#  'ppdyjq',
#  'sxsqe',
#  'qtgzrxs',
#  'ohpwcjbz',
#  'usuhno',
#  'jyvgdwa',
#  'qzmgc',
#  'powmw',
#  'xxabxwpj',
#  'ywyo',
#  'ojhgfpr',
#  'dokcqp',
#  'fraturqj',
#  'ebagf',
#  'sagufh',
#  'byiri',
#  'zkfzynqr',
#  'eakhvu',
#  'agyy',
#  'kmdyog',
#  'jyfqyjrx',
#  'qjomyp',
#  'swarmpee',
#  'zunj',
#  'jvtpnpye',
#  'gcudqe',
#  'bfmmf',
#  'kxbhaor',
#  'lqtz',
#  'iavyoha',
#  'voynjyzf',
#  'jmkva',
#  'rmyvvsc',
#  'wkqwjqt',
#  'gjbhv',
#  'yqzttd',
#  'uxayi',
#  'ivdknpt',
#  'havuzrdz',
#  'xhjpiow',
#  'rdyhj',
#  'sjfjh',
#  'oztwbbh',
#  'bnzwluu',
#  'ocdq',
#  'gozmniu',
#  'scdi',
#  'bcwyqez',
#  'nqdqxtv',
#  'lgnxrbk',
#  'ukhhwf',
#  'yiuqza',
#  'hemn',
#  'tfjdynzi',
#  'yihigvkb',
#  'waaqlr',
# ...

# %%
import wordninja

text = "incompetenthired"
split_words = wordninja.split(text)
print(split_words)  # ['Times', 'Updated', 'March']

def get_split(text):
    return wordninja.split(text)
# Out:
# ['incompetent', 'hired']

# %%
from tqdm.notebook import tqdm

# %%
split_final_dict = {}
for wd in final_dict:
