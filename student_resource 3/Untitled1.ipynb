# %%
# !huggingface-cli login --token MYTOKEN
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to C:\Users\avitr\.cache\huggingface\token
# Login successful

# %%
import pandas as pd

# %%
path = r"D:\OneDrive - NITT\Custom_Download\ocr_regex.csv"

# %%
df = pd.read_csv(path)

# %%
df = df[['Extracted Text','entity_name','extracted_entities','final_prediction','prediction']]

# %%
df.to_csv('final.csv',index=False)

# %%
df['group_id']
# Out:
#          index                                         image_link  group_id  \
# 0       130222  https://m.media-amazon.com/images/I/81zMUm+tYz...    100951
# 1       109129  https://m.media-amazon.com/images/I/61LqBRZFIZ...    100951
# 2       111863  https://m.media-amazon.com/images/I/61gZ2K+Cp5...    100951
# 3       120146  https://m.media-amazon.com/images/I/71UjUOoT8o...    100951
# 4       102992  https://m.media-amazon.com/images/I/61D8tfjYoC...    100951
# ...        ...                                                ...       ...
# 131182  112315  https://m.media-amazon.com/images/I/61kGKGLkdT...    998545
# 131183  112303  https://m.media-amazon.com/images/I/61kB1tUoKw...    998545
# 131184   15683  https://m.media-amazon.com/images/I/41o7f2tQEg...    998545
# 131185  123935  https://m.media-amazon.com/images/I/71qWCl2oqO...    999167
# 131186  128438  https://m.media-amazon.com/images/I/81aFWS3dVO...    999167
#
#         entity_name       test_image  \
# ...
